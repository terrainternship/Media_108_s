# %% [markdown]
# # Техническое задание

# %% [markdown]
# **Проект:** Классификация аудиозвонков на целевые и нецелевые.

# %% [markdown]
# **Цель проекта:** Разработать нейронную сеть, способную классифицировать аудиозвонки на целевые и нецелевые на основе предоставленной базы данных и csv-таблицы с описаниями и метками классов.

# %% [markdown]
# **Введение:**
#
# Входной набор данных представляет из себя два набора файлов:
#
# > a)	[Первый набор файлов](https://drive.google.com/drive/folders/1cQWMpQkscZJbbOTxiJNy0o3nuaeIiB1P?usp=sharing) - это выгрузки в формате `CSV` с информацией по звонкам, а так же с проставленным статусом `“целевой/нецелевой”` в отдельном столбце (обратите внимание, что по проекту `“Павелецкая сити”` две выгрузки - эти наборы данных отличаются и относятся к разным наборам клиентов внутри одного и того же проекта).
#
# > b)	[Второй набор файлов](https://drive.google.com/drive/folders/1K3jGCH60uzFcsI3aj89VIXOOFEXvZxD6?usp=sharing) - аудиозаписи звонков. Они хранятся в корневом каталоге в одноимённых папках. К примеру, в папке `“Записи звонков_павелецкая сити”` лежат записи звонков по проекту `“Павелецкая Сити”`.

# %% [markdown]
# **Требования:**
#
# 1.   Нейронная сеть должна быть спроектирована и обучена для точной классификации аудиозвонков на два класса: целевые и нецелевые (с точностью `90+%`).
# 2.   Необходимо обеспечить интеграцию модели через `API`.
# 3.   Модель должна быть оптимизирована для обработки большого объёма данных.
# 4.   Код должен быть написан с соблюдением стандартов кодирования, и должна быть составлена подробная техническая документация.
# 5.   Код должен включать в себя систему журналирования для фиксации ошибок.
# 6.   Код должен принимать на вход регулярное выражение, по которому будет осуществляться проверка столбца `“теги”` в выгрузках `CSV` для определения статуса звонка `“целевой/нецелевой”`:
#
# >> a)	по проектам `“Примавера”` и `“Павелецкая сити”` наличие в столбце с тегами подстроки `“Целевой_М108“` будет равняться тому, что данный звонок целевой (пример регулярного выражения: `.*Целевой_М108.*`);
#
# >> b)	по проекту `“Хедлайнер”` - наличие в столбце с тегами подстроки `“первичный целевой“` будет равняться тому, что данный звонок целевой.
#
# 7.   После реализации необходимо иметь возможность получения поддержки по предоставленному решению в течение `2 месяцев`.

# %% [markdown]
# Список рекомендуемых параметров для звуковой записи (данный список носит информационный характер и не является обязательным):
#
# *   Эмоция (базовые 11: радость; печаль; гнев; отвращение; удивление; страдание (горе); волнение (интерес); презрение; смущение; стыд; вина).
# *   Пол.
# *   Возраст.
# *   Семантический анализ диалога (по конкретным ключевым словам и/или по тематикам диалогов).
# *   Характеристики, присутствующие в `CSV`/`XLSX` таблицах.

# %% [markdown]
# # Критерии классификации

# %% [markdown]
# Критерии `уникально-целевого` обращения:
# 1. Длительность звонка должна быть не менее `75 секунд`;
# 2. Телефонный номер абонента должен быть `уникальным`, т. е. его не должно быть в `CRM` заказчика. Либо, по нему не должно быть активности за последние `90 дней`. Исключение составляют `топовые площадки`, работающие по своим критериям (`ЦИАН`, `Яндекс.Недвижимость`, `Авито`, и т. д.);
# 3. Клиент должен знать минимальную информацию об объекте (понимать, куда он звонит): название `ЖК`, расположение, ценовую политику;
# 4. Номер абонента должен быть доступен в течение `15 дней` после совершённого звонка (при этом со стороны заказчика должно быть обеспечено `2 попытки` исходящего звонка в течение указанного срока);
# 5. Клиент должен быть `«адекватным»`. Не общаться на повышенных тонах, не употреблять ненормативную лексику и т. д.;
# 6. Клиент не должен быть повторным. Например, клиент `уже` купил квартиру и через `90 дней` решил купить машиноместо;
# 7. Заявка. В заявке должен быть указан номер телефона, а абонент при контакте с менеджером должен соответствовать всем критериям `уникально-целевого` обращения, перечисленным выше;
# 8. Озвученный общий бюджет покупки не должен быть `ниже 90%` от стоимости квартиры или коммерческого помещения, соответствующих площади/комнатности на момент обращения;
# 9. В случае, если клиент является уникальным, интересуется покупкой недвижимости, не является представителем партнёров или исполнителей и изъявил желание посетить офис продаж. При этом не обязательна фиксация уровня знания клиента об объекте в диалоге. При этом источник не должен относиться к каналам `«лидогенерация»` или `«тематические площадки»`;
# 10. Основной целью звонка клиента не должна являться покупка/аренда исключительно нежилого помещения, если это не являлось целью проводимой рекламной кампании.
#
# Критерии НЕ `уникально-целевого` (вторичного) обращения:
# 1. Клиент позвонил повторно менее чем через `3 месяца` (`90 дней`) с момента последнего обращения;
# 2. Клиент, либо члены его семьи, уже купил (купили) `квартиру`/`машиноместо`/`кладовое помещение`, и хочет (хотят) совершить ещё одну покупку. В данном случае клиент относится к показателю `LTV` (показатель прибыли, которую компания получает от одного клиента за всё время работы с ним).

# %% [markdown]
# # 11 неделя

# %% [markdown]
# ## Интеграция в `prod`

# %% [markdown]
# ### API (`whisper`) CPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.5 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-pinp1ovv
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-pinp1ovv
#   Resolved https://github.com/openai/whisper.git to commit 1cea4357687b676b293cb5473e1ade25f5b1cef7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231106) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231106) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231106) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231106) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231106) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231106) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231106-py3-none-any.whl size=801359 sha256=e604fb0a4d520f978d374b61250ecd285099c4ef3d46846ab70de95090f4c425
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n2kf0pxe/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20231106

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.8 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
from fastapi import FastAPI
from pydantic import BaseModel
import whisper

class Item(BaseModel):
  file: str

app = FastAPI()

@app.post('/predict')
async def predict(item: Item):
  whisper_model = whisper.load_model('medium')
  test_sample = whisper_model.transcribe(item.file, language='ru')
  return {'result': test_sample}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2139] using StatReload
# INFO:     Started server process [2145]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
# Тестовые данные
import pickle as pkl
import pandas as pd
with open('/content/drive/MyDrive/media108.ru/Датафреймы/total_targets_test_df.pkl', 'rb') as f:
  total_targets_test_df = pkl.load(f)
with open('/content/drive/MyDrive/media108.ru/Датафреймы/total_not_targets_test_df.pkl', 'rb') as f:
  total_not_targets_test_df = pkl.load(f)
test_targets_sample_file = '/content/drive/MyDrive/media108.ru/Датасет/' + total_targets_test_df['Файл записи звонка'].head(1).values[0]
test_not_targets_sample_file = '/content/drive/MyDrive/media108.ru/Датасет/' + total_not_targets_test_df['Файл записи звонка'].head(1).values[0]

# %%
# Целевой звонок
import requests
response = requests.post('http://127.0.0.1:8000/predict', json={'file': test_targets_sample_file})
print(response.text)
# Out:
# {"result":{"text":" Вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Добрый день. Группа компании Cartros. Лилия. Здравствуйте. Хедлайнер, да, Жика? Я бы хотела узнать. А у вас есть возможность показать готовые квартиры? Или у вас еще все на уровне только застройки? Нет, у нас есть уже в данной корпус. Давайте я вас соединю с менеджером отдела продаж. Там шоу-рум есть, где посмотреть. Отлично. Хорошо, давайте, подскажите. Подскажите, как вас зовут? Динара. Я вас соединяю с менеджером. Одну минуту. Динара, добрый день. Меня зовут Алена, менеджер проекта Headliner. Чем могу вам помочь? Здравствуйте. А я могу сейчас подъехать к вам и вы мне все покажете, что есть у вас? Да, вы можете приехать в офис подаж, шмидтерский проезд, 39, корпус водя. А вы можете мне геолокацию скинуть на вактаб? Я сейчас уже буду выезжать. И там где какая парковка? На улице? Я могу вам направить карту подъезда комплексу. Вы на автомобиле едете? Да, да. Вы можете, наверное, вбить навигатор, живой комплекс, Headliner. Все, отлично. Хорошо, тогда я сейчас. И потом я с вами могу связаться или как? Да, вы придете в офис продаж, скажете, что на встречу с менеджером. А там свободный въезд без флагбауна, без пропуска, без ничего? Нет, офис продаж находится со стороны дороги. Припаркуете автомобиль на территории комплекса, где-то рядом. Ну, не в самом комплексе, я имею в виду, где-то рядом в локации. Вот здесь, где магазин Магнит, например. Либо во внутренние въедете, здесь есть небольшая парковка. И просто ищите офис продаж. Офис продаж находится со стороны Шнитовского проезда. Со стороны Шнитова? Да, со стороны дороги. Все, приедете? Да, хорошо. Спасибо.","segments":[{"id":0,"seek":0,"start":0.0,"end":8.0,"text":" Вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора.","tokens":[50364,11886,12188,39672,5435,740,29311,585,44231,22478,2635,13,5697,25464,28221,2165,10655,4396,45832,2637,13,2608,27315,11,1070,20037,35334,25284,386,7683,13126,26250,13,50764],"temperature":0.0,"avg_logprob":-0.23432672178590452,"compression_ratio":1.600896860986547,"no_speech_prob":0.5114659667015076},{"id":1,"seek":0,"start":17.0,"end":20.0,"text":" Добрый день. Группа компании Cartros. Лилия.","tokens":[51214,3401,13829,4851,13509,13,7247,17451,40024,44231,22478,2635,13,7853,5435,681,13,51364],"temperature":0.0,"avg_logprob":-0.23432672178590452,"compression_ratio":1.600896860986547,"no_speech_prob":0.5114659667015076},{"id":2,"seek":0,"start":20.0,"end":25.0,"text":" Здравствуйте. Хедлайнер, да, Жика? Я бы хотела узнать.","tokens":[51364,17613,36359,13,9456,2229,693,32920,1135,11,8995,11,18977,17286,30,4857,2768,11515,19097,33562,1283,13,51614],"temperature":0.0,"avg_logprob":-0.23432672178590452,"compression_ratio":1.600896860986547,"no_speech_prob":0.5114659667015076},{"id":3,"seek":2500,"start":25.0,"end":33.0,"text":" А у вас есть возможность показать готовые квартиры? Или у вас еще все на уровне только застройки?","tokens":[50364,3450,1595,10655,5640,41233,21147,2209,17137,5312,37084,10461,30,34361,1595,10655,9910,4640,1470,25200,4677,9008,4396,26467,2241,30,50764],"temperature":0.0,"avg_logprob":-0.2629785378774007,"compression_ratio":1.9735099337748345,"no_speech_prob":0.26318806409835815},{"id":4,"seek":2500,"start":34.0,"end":41.0,"text":" Нет, у нас есть уже в данной корпус. Давайте я вас соединю с менеджером отдела продаж. Там шоу-рум есть, где посмотреть.","tokens":[50814,21249,11,1595,6519,5640,7520,740,19582,5007,45284,7071,13,30487,2552,10655,7425,30741,1148,776,6046,2229,1820,33370,50176,386,11354,3234,13,27451,5941,354,585,12,2711,919,5640,11,11418,38482,13,51164],"temperature":0.0,"avg_logprob":-0.2629785378774007,"compression_ratio":1.9735099337748345,"no_speech_prob":0.26318806409835815},{"id":5,"seek":2500,"start":41.0,"end":43.0,"text":" Отлично. Хорошо, давайте, подскажите.","tokens":[51164,18611,40955,13,37564,11,30412,11,4095,4218,3234,5878,13,51264] ...

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2139] using StatReload
# INFO:     Started server process [2145]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 96.4MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# INFO:     127.0.0.1:34284 - "POST /predict HTTP/1.1" 200 OK

# %%
# Нецелевой звонок
import requests
response = requests.post('http://127.0.0.1:8000/predict', json={'file': test_not_targets_sample_file})
print(response.text)
# Out:
# {"result":{"text":" Здравствуйте, вы позвонили в группу компании «Картросс». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Добрый день, группа компании «Картросс». Меня зовут Любовь. Здравствуйте, Любовь. Меня зовут Татьяна. У меня уникальный клиент. Я бы хотела пообщаться с менеджером, который у меня присоединился, но не могу дозвонить, у него абонент недоступен. А что за менеджер? Что за фамилия? Ванда Даев. Прикрепили этого. Хорошо, соединяю вас с Татьяна с отделом продаж. Сейчас любой свободный менеджер произнесть ситуацию. Оставайтесь на линии. Благодарю. Татьяна, добрый день. Меня зовут Антон. Слушаю вас. Чем могу помочь? Здравствуйте, Антон. Высказала клиента. Клиент уникальный. Хочу удачить им по квартире. У нас бюджет 20 миллионов. Плюс-минус 2 миллиона. Готовая квартира. Но можно пойти и потехать. Уже в готовом построенном доме? Да. Такое возможно? Нужно защитить отдела ипотеки. У вас по готовым домам можно пойти и потехать или нет? У нас осталась одна квартира. Однокомнатная. У нее цена минимальная 22 миллиона. Она продается по договору о купле-продаже от везлица. Скорее всего, 10 ипотек будет невозможно. Если мы говорим про другую, следующую минимальную площадь, то это одна комнатная квартира. Вот застройщика в готовом доме. Она выходит по прайсовой цене в районе 30 миллионов. Софитка она выходит около 25 миллионов 200 тысяч. Она идет по ипотеке? Да. Но там будет бюджет в районе 25 миллионов. Но зато ключи сразу. Там в квартире в готовом доме. Она без ремонта. Покупаете, получаете ключи. Можно делать ремонт. На скидку какая ставка по ипотеке? Нужно будет уточнить. Я уточню и могу вам подписаться на телефон. Я хочу предложить. Я нашла только 22 миллиона. Здесь не написано, что она по уступке. У нас не указывается на сайте. Не совсем понятно, от кого эта квартира продается. Это квартира, которая продается. Хотя тут есть даже за 20 400 тысяч. Это квартира по уступке. Она продается совместно с двукомнатной квартирой. Так получается 25 900 тысяч. Самая минимальная. 25 тысяч 250 тысяч. Понятно. Если падет ипотека, то не получится. На сайте написано про ипотеку? На сайте написано. Я сейчас уточню. Вам исключительно интересна азия ипотека. Да. Я сейчас уточню и подпишусь на ВУЗАП. Благодарю. Спасибо.","segments":[{"id":0,"seek":0,"start":0.0,"end":3.7600000000000002,"text":" Здравствуйте, вы позвонили в группу компании «Картросс».","tokens":[50364,17613,36359,11,2840,12188,39672,5435,740,29311,585,44231,4657,8169,27419,9225,461,12513,50552],"temperature":0.0,"avg_logprob":-0.28857620623933167,"compression_ratio":1.976109215017065,"no_speech_prob":0.2754083573818207},{"id":1,"seek":0,"start":3.7600000000000002,"end":5.68,"text":" Благодарим вас за звонок.","tokens":[50552,5697,25464,28221,2165,10655,4396,45832,2637,13,50648],"temperature":0.0,"avg_logprob":-0.28857620623933167,"compression_ratio":1.976109215017065,"no_speech_prob":0.2754083573818207},{"id":2,"seek":0,"start":5.68,"end":8.4,"text":" Пожалуйста, дождитесь ответа оператора.","tokens":[50648,2608,27315,11,1070,20037,35334,25284,386,7683,13126,26250,13,50784],"temperature":0.0,"avg_logprob":-0.28857620623933167,"compression_ratio":1.976109215017065,"no_speech_prob":0.2754083573818207},{"id":3,"seek":0,"start":18.52,"end":21.36,"text":" Добрый день, группа компании «Картросс». Меня зовут Любовь.","tokens":[51290,3401,13829,4851,13509,11,29311,386,44231,4657,8169,27419,9225,461,12513,47311,46376,47369,1055,678,13,51432],"temperature":0.0,"avg_logprob":-0.28857620623933167,"compression_ratio":1.976109215017065,"no_speech_prob":0.2754083573818207},{"id":4,"seek":0,"start":21.36,"end":24.36,"text":" Здравствуйте, Любовь. Меня зовут Татьяна.","tokens":[51432,17613,36359,11,47369,1055,678,13,47311,46376,3200,2209,681,1931,13,51582],"temperature":0.0,"avg_logprob":-0.28857620623933167,"compression_ratio":1.976109215017065,"no_speech_prob":0.2754083573818207},{"id":5,"seek":0,"start":24.36,"end":26.2,"text":" У меня уникальный клиент.","tokens":[51582 ...

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2139] using StatReload
# INFO:     Started server process [2145]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 96.4MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# INFO:     127.0.0.1:34284 - "POST /predict HTTP/1.1" 200 OK
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# INFO:     127.0.0.1:49520 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### API (`whisper`) GPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 69.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-nd4oun4l
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-nd4oun4l
#   Resolved https://github.com/openai/whisper.git to commit 1cea4357687b676b293cb5473e1ade25f5b1cef7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231106) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231106) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231106) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231106) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231106) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231106) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231106) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231106) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231106) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231106-py3-none-any.whl size=801359 sha256=bcba21c7dbed4acfab94900440cb1660f66ad2c9dc63c5e66b2ee9e20c904d2a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wsq1isfl/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20231106

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 9.5 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
from fastapi import FastAPI
from pydantic import BaseModel
import whisper

class Item(BaseModel):
  file: str

app = FastAPI()

@app.post('/predict')
async def predict(item: Item):
  whisper_model = whisper.load_model('large')
  test_sample = whisper_model.transcribe(item.file, language='ru')
  return {'result': test_sample}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2691] using StatReload

# %%
# Тестовые данные
import pickle as pkl
import pandas as pd
with open('/content/drive/MyDrive/media108.ru/Датафреймы/total_targets_test_df.pkl', 'rb') as f:
  total_targets_test_df = pkl.load(f)
with open('/content/drive/MyDrive/media108.ru/Датафреймы/total_not_targets_test_df.pkl', 'rb') as f:
  total_not_targets_test_df = pkl.load(f)
test_targets_sample_file = '/content/drive/MyDrive/media108.ru/Датасет/' + total_targets_test_df['Файл записи звонка'].head(1).values[0]
test_not_targets_sample_file = '/content/drive/MyDrive/media108.ru/Датасет/' + total_not_targets_test_df['Файл записи звонка'].head(1).values[0]

# %%
# Целевой звонок
import requests
response = requests.post('http://127.0.0.1:8000/predict', json={'file': test_targets_sample_file})
print(response.text)
# Out:
# {"result":{"text":" Вы позвонили в группу компании «Картрос». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Добрый день. Группа компании «Картрос» Лилия. Здравствуйте. Хедлайнер ЖК. Я бы хотела узнать, у вас есть возможность показать готовые квартиры? Или у вас еще вообще все на уровне только застройки? Нет, у нас есть уже сданные корпуса. Давайте я вас соединю с менеджером отдела продаж. Там шоу-рум есть, где посмотреть. Отлично. Хорошо, давайте. Подскажите, как вас зовут? Динара. Я вас соединяю с менеджером. Одну минуту. Динара, добрый день. Меня зовут Алена, менеджер проекта «Хедлайнер». Чем могу вам помочь? Здравствуйте. А я могу сейчас подъехать к вам, и вы мне все покажете, что есть у вас? Да, вы можете приехать в офис продаж «Шмитовский проезд», 30. А вы можете мне геолокацию скинуть на WhatsApp на этот номер? Я просто сейчас уже буду выезжать, и там где какая парковка, там на улице можно встать, правильно? Я могу вам направить карту подъезда к комплексу. Вы на автомобиле едете? Да, да, да. Вы можете, наверное, вбить навигатор «Жилой комплекс Хедлайнер». Офис продаж находится в Хедлайнере. Все, отлично. Хорошо, тогда я сейчас... И потом я с вами могу связаться, или как? Да, вы придете в офис продаж, скажете, что на встречу с менеджером, и вас проводят. А там свободный въезд, без флагбаума, без пропуска, без ничего? Нет, офис продаж находится со стороны дороги. Припаркуете автомобиль на территории комплекса, где-то рядом, ну, не в самом комплексе, я имею в виду, где-то рядом локации, вот здесь, где магазин «Магнит», например, либо во внутренней въезде здесь есть небольшая парковка, и просто ищите офис продаж. Хорошо. Офис продаж находится со стороны шмитовского проезда. Со стороны шмитовского проезда? Хорошо. Да, со стороны дороги. Все, приезжайте, Зинара. Да, все, спасибо. Хорошо.","segments":[{"id":0,"seek":0,"start":0.0,"end":7.54,"text":" Вы позвонили в группу компании «Картрос». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора.","tokens":[50365,11886,12188,39672,5435,740,29311,585,44231,4657,8169,27419,9225,12513,5697,25464,28221,2165,10655,4396,45832,2637,13,2608,27315,11,1070,20037,35334,25284,386,7683,13126,26250,13,50742],"temperature":0.0,"avg_logprob":-0.1934012215712975,"compression_ratio":1.6242774566473988,"no_speech_prob":0.15164217352867126},{"id":1,"seek":0,"start":16.94,"end":20.26,"text":" Добрый день. Группа компании «Картрос» Лилия.","tokens":[51212,3401,13829,4851,13509,13,7247,17451,40024,44231,4657,8169,27419,9225,5933,7853,5435,681,13,51378],"temperature":0.0,"avg_logprob":-0.1934012215712975,"compression_ratio":1.6242774566473988,"no_speech_prob":0.15164217352867126},{"id":2,"seek":2026,"start":20.26,"end":29.14,"text":" Здравствуйте. Хедлайнер ЖК. Я бы хотела узнать, у вас есть возможность показать готовые квартиры?","tokens":[50365,17613,36359,13,9456,2229,693,32920,1135,18977,8169,13,4857,2768,11515,19097,33562,1283,11,1595,10655,5640,41233,21147,2209,17137,5312,37084,10461,30,50809],"temperature":0.0,"avg_logprob":-0.1786506425088911,"compression_ratio":1.9910979228486647,"no_speech_prob":0.010732471011579037},{"id":3,"seek":2026,"start":30.020000000000003,"end":33.2,"text":" Или у вас еще вообще все на уровне только застройки?","tokens":[50853,34361,1595,10655,9910,14345,4640,1470,25200,4677,9008,4396,26467,2241,30,51012],"temperature":0.0,"avg_logprob":-0.1786506425088911,"compression_ratio":1.9910979228486647,"no_speech_prob":0.010732471011579037},{"id":4,"seek":2026,"start":34.540000000000006,"end":39.18000000000001,"text":" Нет, у нас есть уже сданные корпуса. Давайте я вас соединю с менеджером отдела продаж.","tokens":[51079,21249,11,1595,6519,5640,7520,48001,40194,45284,45735,13,30487,2552,10655,7425,30741,1148,776,6046,2229,1820,33370,50176,386,11354,3234,13,51311],"temperature":0.0,"avg_logprob":-0.1786506425088911,"compression_ratio":1.9910979228486647,"no_speech_prob":0.010732471011579037},{"id":5,"seek":2026,"start":39.400000000000006,"end":41. ...

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2691] using StatReload
# INFO:     Started server process [2697]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:31<00:00, 96.7MiB/s]
# INFO:     127.0.0.1:59468 - "POST /predict HTTP/1.1" 200 OK

# %%
# Нецелевой звонок
import requests
response = requests.post('http://127.0.0.1:8000/predict', json={'file': test_not_targets_sample_file})
print(response.text)
# Out:
# {"result":{"text":" Здравствуйте! Вы позвонили в группу компании «Картрос». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Добрый день, группа компании «Картрос». Меня зовут Любовь. Здравствуйте, Любовь. Меня зовут Татьяна. У меня уникальный клиент. Я бы хотела пообщаться с менеджером, которого вы прикрепили, но не могу дозвониться, у него абонент недоступен. Какой менеджер? Что за фамилия? Иван Дадаев. Прикрепили этого. Так. Хорошо. Соединяю вас, Татьяна, с отделом продаж. Сейчас любой свободный менеджер пройти ситуацию. Оставайтесь на линии. Благодарю. Добрый день. Татьяна, добрый день. Меня зовут Антон. Слушаю вас. Чем могу помочь? Антон. Уникального клиента. Клиент уникальный. Хочу вам сказать, что я очень рада, что вы пришли к нам. Хочу уточнить по квартире. У нас бюджет 2 миллиона. Ну, плюс-минус 2 миллиона, да? Нужна готовая квартира, но пойти ипотеки. Уже в готовом построенном доме? Да. Такое возможно? Нужно уточнить у отдела ипотеки, по готовым домам возможно пойти ипотеку или нет. Вот у нас осталась одна квартира. Одна комната. У нее цена минимальная 22 миллиона. Она продается по договору купли-продажи от визлица. Вот. Скорее всего, 10 ипотек им будет невозможно. Так. А если мы говорим про однокомнатную квартиру, ну, про какую-то другую, следующую минимальную площадь, то это однокомнатная квартира от застройщика в готовом доме. И она выходит у нас по прайсовой цене в районе 30 миллионов. А со скидкой она выходит около 25 миллионов 200 тысяч. Так. Но она идет по этой ипотеке, да? Ну, я думаю, да. Но там будет бюджет в районе 25 с лишним миллионов. Так. 25. Но зато ключи сразу, правильно? Там квартира в готовом уже построенном доме, да. То есть она без ремонта. Покупаете ключи, можно делать ремонт, начинать, да. Угу. Ладно. Так. А на скидку не помните, какая ставка по ипотеке? Нужно будет уточнить у моих коллег, когда делаю ипотеки. Я уточню и могу вам отписаться на ваш телефон. Да, благодарю. А то я просто сейчас хочу предложить как бы. А что предложить, я вот тоже нашла только 22. Здесь не написано, что она по уступке. Ну, у нас, к сожалению, не указывается на сайте, сам же на нашем, да. Не совсем понятно, да, от кого эта квартира продается. Квартиру вы не снили? Хотя тут вот есть даже за 20 400. Эта квартира тоже по приуступке от Фезлица идет. И она продается совместно с рядышком с ней двухкомнатной квартирой под объединение. Угу. Так, ясно. А так получается вот 25 900 самое минимальное. Там нет, 25, там 200, 250 плюс-минус такая вот цена. Ну, понятно. Ну, если пойдет, блин, плохо, что вот ипотеку, нельзя никак. А на сайте у вас где-то написано про ипотеку? На сайте написано, да. Ну, я сейчас уточню вам исключительно, вам исключительно, да, IT ипотека интересует, да? Да, да, да, совершенно. Угу. Я сейчас уточню и вам на WhatsApp отпишусь тогда, Татьяна. Да, благодарю вас, спасибо за... Всего, будем на связи. Да, отпишусь, всем спасибо.","segments":[{"id":0,"seek":0,"start":0.0,"end":8.1,"text":" Здравствуйте! Вы позвонили в группу компании «Картрос». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора.","tokens":[50365,17613,36359,0,11886,12188,39672,5435,740,29311,585,44231,4657,8169,27419,9225,12513,5697,25464,28221,2165,10655,4396,45832,2637,13,2608,27315,11,1070,20037,35334,25284,386,7683,13126,26250,13,50770],"temperature":0.0,"avg_logprob":-0.168533448250063,"compression_ratio":1.6923076923076923,"no_speech_prob":0.01882644183933735},{"id":1,"seek":0,"start":18.18,"end":21.18,"text":" Добрый день, группа компании «Картрос». Меня зовут Любовь.","tokens":[51274,3401,13829,4851,13509,11,29311,386,44231,4657,8169,27419,9225,12513,47311,46376,47369,1055,678,13,51424],"temperature":0.0,"avg_logprob":-0.168533448250063,"compression_ratio":1.6923076923076923,"no_speech_prob":0.01882644183933735},{"id":2,"seek":2118,"start":21.18,"end":32.019999999999996,"text":" Здравствуйте, Любовь. Меня зовут Татьяна. У меня уникальный клиент. Я бы хотела пообщаться с менеджером, которого вы прикрепил ...

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2691] using StatReload
# INFO:     Started server process [2697]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:31<00:00, 96.7MiB/s]
# INFO:     127.0.0.1:59468 - "POST /predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45276 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### API (`item_list` `{'text': str}`) CPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
from fastapi import FastAPI
from pydantic import BaseModel
from typing import List

class Item(BaseModel):
  text: str

app = FastAPI()

@app.post('/predict')
async def predict(data: List[Item]):
  return data
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1401] using StatReload
# INFO:     Started server process [1403]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
# Загрузка датафрейма с данными
import pandas as pd
df_good_pred = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/df_good_pred.csv')
df_good_pred.shape
# Out:
# (6921, 35)

# %%
# Тестовые данные
item_list = [{'text': x} for x in df_good_pred['whisper'].head().astype('str').values]
item_list
# Out:
# [{'text': 'безответа'},
#  {'text': 'здравствуйте'},
#  {'text': 'здравствуйте вы позвонили в компанию эмргрупп пожалуйста дождитесь ответа нашего специалиста обращаем ваше внимание что в целях улучшения качества обслуживания клиентов все разговоры записываются продолжая разговор вы соглашаетесь на обработку ваших персональных данных'},
#  {'text': 'здравствуйте'},
#  {'text': 'здравствуйте вы позвонили в группу компании картрофт благодарим вас за звонок пожалуйста дождитесь ответа оператора группа компании картрофт меня зовут елена здравствуйте здравствуйте меня интересует спедлайнер я вас сейчас соединю с одним упрадашником он жестко консультирует как вас зовут ирина александровна благодарю оставайтесь на линии здравствуйте меня зовут дарья какие вопросы по проекту ходланд слушаю вас добрый день смотрите интересует одна квартира 41 квадрат за 20 пейсов у нас есть вариант какая там площадь 4099 помоему да есть такая квартира есть интересующийся покупатель на подобную квартиру но мы не укладываемся под цену совсем немного причем хотел у вас узнать у вас вообще возможно ли есть какиенибудь сады цены еще чтонибудь чтобы я ему смог это все объяснить я скажу так что это у нас квартира от инвестора проекта и цена финальная скидки на эту квартиру не будет а сколько не хватает примерная цена 18519 они готовы уже на эту цену к сожалению у нас просто это не наш бюджет 2300 будет самый минимум и это будет такая финальная цена также у нас есть квартира от нашего отдела  на этапе строительства он в корпусе уже возведен ключи через полтора года однокомнатная будет 17800 стоить это переуступка так еще раз можете рассказать об этой квартире так квартира которая еще в строительном саду не находится да все верно вы говорите полтора года у вас же помоему то что сейчас в продаже крайний срок сдачи это 24 второй квартал да нет срок сдачи второй квартал все верно но по договору для его участия ключи максимальный срок до конца 24 хорошо хотя этот корпус уже построен поэтому я думаю что здесь ключи могут даже уже через год отдать квартира 44 метра 17800 да а какой этаж так у нее 6 этаж из 14 хорошо из 14 6 этаж 17800 полпереуступки так я понял а куда смотрят окна а вы знакомы с нашим комплексом знаком так сейчас посмотрю квартира выходит с окнами на прогулочный променад на пешеходный бульвар это уже внутри жилого комплекса пешеходный променад да да да да внутри комплекса грубо говоря во двор так хорошо нет это будет внешний двор это не внутренний двор а там дорога нет там не будет дорог там будет продумовая территория и немного там будет знаете какая дорога не то что такая проезжая а гостевые может места будут находятся понял понял амара наверное на кадр далеко да да достаточно далеко квартира у  спасибо подогрейте прочнее приведите здесь примерно  документы документы да очень кумово там часами до дотора я вас очень плохо слышу да я и очень както кипишу по сторонам угу сейчас еду 18 на 744 и следующая 2300 за 41 да 2300 да так хорошо я понял спасибо вам вопросов больше нет попробую предложить вот это запишите пожалуйста мой номер телефона если сохранить у вас какието будут вопросы или решить к нам в господаж приехать познакомиться с проектом пожалуйста звоните ладно да хорошо давайте 89265790208 дарья вы менеджер из отдела продаж кодлайнера да да да да застрочек так все спасибо вам дарья все до свидания хорошо звоните да благодарю до свидания до свидания'}]

# %%
# Запрос
import requests
response = requests.post('http://127.0.0.1:8000/predict', json=item_list)
print(response.text)
# Out:
# [{"text":"безответа"},{"text":"здравствуйте"},{"text":"здравствуйте вы позвонили в компанию эмргрупп пожалуйста дождитесь ответа нашего специалиста обращаем ваше внимание что в целях улучшения качества обслуживания клиентов все разговоры записываются продолжая разговор вы соглашаетесь на обработку ваших персональных данных"},{"text":"здравствуйте"},{"text":"здравствуйте вы позвонили в группу компании картрофт благодарим вас за звонок пожалуйста дождитесь ответа оператора группа компании картрофт меня зовут елена здравствуйте здравствуйте меня интересует спедлайнер я вас сейчас соединю с одним упрадашником он жестко консультирует как вас зовут ирина александровна благодарю оставайтесь на линии здравствуйте меня зовут дарья какие вопросы по проекту ходланд слушаю вас добрый день смотрите интересует одна квартира 41 квадрат за 20 пейсов у нас есть вариант какая там площадь 4099 помоему да есть такая квартира есть интересующийся покупатель на подобную квартиру но мы не укладываемся под цену совсем немного причем хотел у вас узнать у вас вообще возможно ли есть какиенибудь сады цены еще чтонибудь чтобы я ему смог это все объяснить я скажу так что это у нас квартира от инвестора проекта и цена финальная скидки на эту квартиру не будет а сколько не хватает примерная цена 18519 они готовы уже на эту цену к сожалению у нас просто это не наш бюджет 2300 будет самый минимум и это будет такая финальная цена также у нас есть квартира от нашего отдела  на этапе строительства он в корпусе уже возведен ключи через полтора года однокомнатная будет 17800 стоить это переуступка так еще раз можете рассказать об этой квартире так квартира которая еще в строительном саду не находится да все верно вы говорите полтора года у вас же помоему то что сейчас в продаже крайний срок сдачи это 24 второй квартал да нет срок сдачи второй квартал все верно но по договору для его участия ключи максимальный срок до конца 24 хорошо хотя этот корпус уже построен поэтому я думаю что здесь ключи могут даже уже через год отдать квартира 44 метра 17800 да а какой этаж так у нее 6 этаж из 14 хорошо из 14 6 этаж 17800 полпереуступки так я понял а куда смотрят окна а вы знакомы с нашим комплексом знаком так сейчас посмотрю квартира выходит с окнами на прогулочный променад на пешеходный бульвар это уже внутри жилого комплекса пешеходный променад да да да да внутри комплекса грубо говоря во двор так хорошо нет это будет внешний двор это не внутренний двор а там дорога нет там не будет дорог там будет продумовая территория и немного там будет знаете какая дорога не то что такая проезжая а гостевые может места будут находятся понял понял амара наверное на кадр далеко да да достаточно далеко квартира у  спасибо подогрейте прочнее приведите здесь примерно  документы документы да очень кумово там часами до дотора я вас очень плохо слышу да я и очень както кипишу по сторонам угу сейчас еду 18 на 744 и следующая 2300 за 41 да 2300 да так хорошо я понял спасибо вам вопросов больше нет попробую предложить вот это запишите пожалуйста мой номер телефона если сохранить у вас какието будут вопросы или решить к нам в господаж приехать познакомиться с проектом пожалуйста звоните ладно да хорошо давайте 89265790208 дарья вы менеджер из отдела продаж кодлайнера да да да да застрочек так все спасибо вам дарья все до свидания хорошо звоните да благодарю до свидания до свидания"}]

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1401] using StatReload
# INFO:     Started server process [1403]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:41956 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### API (`bert`) GPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка transformers
# !pip -q install transformers

# %%
# Установка fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import torch
import numpy as np
import torch.nn as nn
from fastapi import FastAPI
from typing import List
from transformers import AutoModel, BertTokenizer

app = FastAPI()

@app.post('/predict')
async def predict(data: List[str]):
  bert      = AutoModel.from_pretrained('DeepPavlov/rubert-base-cased-sentence')
  tokenizer = BertTokenizer.from_pretrained('DeepPavlov/rubert-base-cased-sentence')
  class BERT_Arch(nn.Module):
    def __init__(self, bert):
      super(BERT_Arch, self).__init__()
      self.bert = bert
      self.dropout = nn.Dropout(0.1)
      self.relu = nn.ReLU()
      self.fc1 = nn.Linear(768,512)
      self.fc2 = nn.Linear(512,2)
      self.softmax = nn.LogSoftmax(dim = 1)
    def forward(self, sent_id, mask):
      _, cls_hs = self.bert(sent_id, attention_mask = mask, return_dict = False)
      x = self.fc1(cls_hs)
      x = self.relu(x)
      x = self.dropout(x)
      x = self.fc2(x)
      x = self.softmax(x)
      return x
  device = torch.device('cuda')
  model  = BERT_Arch(bert)
  model  = model.to(device)
  model.load_state_dict(torch.load('/content/drive/MyDrive/media108.ru/Модели/bert_saved_weights.pt'))
  option = lambda x: 1 if x > 0.95 else 0
  tokens_test = tokenizer.batch_encode_plus(data, max_length=512, padding='max_length', truncation=True)
  test_seq    = torch.tensor(tokens_test['input_ids'])
  test_mask   = torch.tensor(tokens_test['attention_mask'])
  preds = model(test_seq.to(device), test_mask.to(device))
  flat_preds = [item[1] for item in preds.detach().cpu().numpy()]
  flat_preds = (flat_preds - min(flat_preds)) / (max(flat_preds) - min(flat_preds))
  return {'result': str(list(np.vectorize(option)(flat_preds)))}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1100] using StatReload

# %%
# Загрузка датафрейма с данными
import pandas as pd
df_good_pred = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/df_good_pred.csv')
df_good_pred.shape
# Out:
# (6921, 35)

# %%
# Тестовые данные
item_list = df_good_pred['whisper'].head().astype('str').values.tolist()
item_list
# Out:
# ['безответа',
#  'здравствуйте',
#  'здравствуйте вы позвонили в компанию эмргрупп пожалуйста дождитесь ответа нашего специалиста обращаем ваше внимание что в целях улучшения качества обслуживания клиентов все разговоры записываются продолжая разговор вы соглашаетесь на обработку ваших персональных данных',
#  'здравствуйте',
#  'здравствуйте вы позвонили в группу компании картрофт благодарим вас за звонок пожалуйста дождитесь ответа оператора группа компании картрофт меня зовут елена здравствуйте здравствуйте меня интересует спедлайнер я вас сейчас соединю с одним упрадашником он жестко консультирует как вас зовут ирина александровна благодарю оставайтесь на линии здравствуйте меня зовут дарья какие вопросы по проекту ходланд слушаю вас добрый день смотрите интересует одна квартира 41 квадрат за 20 пейсов у нас есть вариант какая там площадь 4099 помоему да есть такая квартира есть интересующийся покупатель на подобную квартиру но мы не укладываемся под цену совсем немного причем хотел у вас узнать у вас вообще возможно ли есть какиенибудь сады цены еще чтонибудь чтобы я ему смог это все объяснить я скажу так что это у нас квартира от инвестора проекта и цена финальная скидки на эту квартиру не будет а сколько не хватает примерная цена 18519 они готовы уже на эту цену к сожалению у нас просто это не наш бюджет 2300 будет самый минимум и это будет такая финальная цена также у нас есть квартира от нашего отдела  на этапе строительства он в корпусе уже возведен ключи через полтора года однокомнатная будет 17800 стоить это переуступка так еще раз можете рассказать об этой квартире так квартира которая еще в строительном саду не находится да все верно вы говорите полтора года у вас же помоему то что сейчас в продаже крайний срок сдачи это 24 второй квартал да нет срок сдачи второй квартал все верно но по договору для его участия ключи максимальный срок до конца 24 хорошо хотя этот корпус уже построен поэтому я думаю что здесь ключи могут даже уже через год отдать квартира 44 метра 17800 да а какой этаж так у нее 6 этаж из 14 хорошо из 14 6 этаж 17800 полпереуступки так я понял а куда смотрят окна а вы знакомы с нашим комплексом знаком так сейчас посмотрю квартира выходит с окнами на прогулочный променад на пешеходный бульвар это уже внутри жилого комплекса пешеходный променад да да да да внутри комплекса грубо говоря во двор так хорошо нет это будет внешний двор это не внутренний двор а там дорога нет там не будет дорог там будет продумовая территория и немного там будет знаете какая дорога не то что такая проезжая а гостевые может места будут находятся понял понял амара наверное на кадр далеко да да достаточно далеко квартира у  спасибо подогрейте прочнее приведите здесь примерно  документы документы да очень кумово там часами до дотора я вас очень плохо слышу да я и очень както кипишу по сторонам угу сейчас еду 18 на 744 и следующая 2300 за 41 да 2300 да так хорошо я понял спасибо вам вопросов больше нет попробую предложить вот это запишите пожалуйста мой номер телефона если сохранить у вас какието будут вопросы или решить к нам в господаж приехать познакомиться с проектом пожалуйста звоните ладно да хорошо давайте 89265790208 дарья вы менеджер из отдела продаж кодлайнера да да да да застрочек так все спасибо вам дарья все до свидания хорошо звоните да благодарю до свидания до свидания']

# %%
# Запрос на предсказание
import requests
response = requests.post('http://127.0.0.1:8000/predict', json=item_list)
print(response.text)
# Out:
# {"result":"[0, 0, 0, 0, 1]"}

# %%
# Верные данные
df_good_pred['target'].head().values
# Out:
# array([0, 0, 0, 0, 1])

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1100] using StatReload
# INFO:     Started server process [1106]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# config.json: 100%|██████████| 642/642 [00:00<00:00, 3.03MB/s]
# pytorch_model.bin: 100%|██████████| 711M/711M [00:02<00:00, 251MB/s]
# tokenizer_config.json: 100%|██████████| 24.0/24.0 [00:00<00:00, 171kB/s]
# vocab.txt: 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.41MB/s]
# special_tokens_map.json: 100%|██████████| 112/112 [00:00<00:00, 864kB/s]
# INFO:     127.0.0.1:35416 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### API (`whisper` + `item_list`) GPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 26.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-otqq9gmx
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-otqq9gmx
#   Resolved https://github.com/openai/whisper.git to commit e58f28804528831904c3b6f2c0e473f346223433
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231117) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231117) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801358 sha256=fccabd33ee67ecae65fa224c3d2e57d034c2fd55ca3efc3419073fcec8844d1e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sds4hwku/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20231117

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 4.7 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
from fastapi import FastAPI
from typing import List
import whisper

app = FastAPI()

@app.post('/predict')
async def predict(data: List[str]):
  whisper_model = whisper.load_model('large')
  result = []
  for item in data:
    result.append(whisper_model.transcribe(item, language='ru')['text'])
  return {'result': str(result)}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1104] using StatReload

# %%
# Загрузка датафрейма с данными
import pickle as pkl
import pandas as pd
with open('/content/drive/MyDrive/media108.ru/Датафреймы/total_work_df.pkl', 'rb') as f:
  total_work_df = pkl.load(f)
total_work_df.shape
# Out:
# (7968, 79)

# %%
# Файлы для транскрибации
item_list = total_work_df['Файл записи звонка'].head().apply(lambda x: '/content/drive/MyDrive/media108.ru/Датасет/' + x).values.tolist()
item_list
# Out:
# ['/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-05-08_16-14-10.247769_from_74955199580_to_74997552563_session_2918538922_talk.mp3',
#  '/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-05-09_11-53-48.291185_from_79910665524_to_74997552563_session_2919161802_talk.mp3',
#  '/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-05-09_17-51-30.193682_from_79670165153_to_0188880_session_2919520238_talk.mp3',
#  '/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-05-09_18-34-04.371381_from_79274431546_to_74997552563_session_2919550530_talk.mp3',
#  '/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-05-09_20-19-21.050197_from_79274432048_to_74997552563_session_2919615074_talk.mp3']

# %%
# Запрос на транскрибацию
import requests
response = requests.post('http://127.0.0.1:8000/predict', json=item_list)
print(response.text)
# Out:
# {"result":"[' Светлана, здравствуйте. Здравствуйте. Скажите, пожалуйста, фотоаппарат КНН А-603. Ой, это расшипаетесь. Нет-нет, вы позвонили в другую компанию, перезвоните.', ' А, Вика, звонок по объявлению. Разговор может быть записан. Вам интересно? Позвольте, я продолжу, а потом, если что, зададите вопросы, хорошо?', ' Здравствуйте! Вы позвонили в группу компании «Картрос». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Добрый вечер. Группа компании «Картрос». Меня зовут Любовь. Любовь, добрый день. Виктория рассматривает жилой комплекс «Хедлайнер». Рассматривает трехкомнатную квартиру. Бюджет 40 миллионов. Спасибо. Здравствуйте. Я хотела узнать по поводу вашего проекта. Есть ли квартиры готовые по планировкам, по ремонту, без ремонта, с ремонтом? Что есть вообще? Вы знакомы с нашим проектом? Нет, не совсем. А локацию хотя бы знаете, где мы находимся? Локацию, да. Локацию смотрела уже. Проект «Хедлайнер» находится в станции метро «Шелепиха». Школы рядом есть. Муниципальная, романовская школа в 300 метрах. Детский сад, также романовский. Также на территории комплекса есть два частных детских сада. Сейчас он в стадии ремонтных работ. Проект «Три очереди». Готовые квартиры во второй очереди есть. Сдача была в декабре 2022 года. Прям очень громко мне в трубку ребенок кричит. Ага. И есть третья очередь, которая сдается в второй квартал 2024 года. Квартира без отделки. Без отделки там, да? Да, если мы говорим без отделки, то есть свободная планировка, стяжка, штукатурка. Угу, все, я поняла. То есть, а свайдбоксов всегда нет в квартирах? Нет, предчистовой отделки нет. Без отделки квартиры. Угу, угу. Так, хорошо. Так, так, так. Какой бюджет приобретения у вас? И какой способ это? Ипотека, рассрочка? Это, скорее всего, будет ипотека. Угу. Вот, по бюджету это до 40. 35-37, то есть, вот в этом диапазоне. Ну, вы можете попробовать тогда приобрести у нас трехкомнатные форматы «Евро». Это две спальни, кухня-гостиная. Порядка 67 миллиметров есть. Да, да, да. И это будет, по-моему, в таком бюджете, если мы говорим с вами, до 40. И есть варианты точечные, до 40, но это прям единичные квартиры. Просто они будут на низких этажах, не с видовыми характеристиками, а скорее во внутренний двор. Там, возможно, порядка 85 метров, там уже будет большая площадь, но все те же две спальни и кухня-гостиная. Угу, все, я поняла. Так, то есть, а если рассмотреть побольше, то не будет? То есть, а если рассмотреть побольше планировку, побольше квадратуру, то там уже какой будет ценник? Ну, есть в третьей очереди вариант за 36,5 миллионов, но я образно 36 точно не помню, если ты 700, 36, 700. То есть, есть вариант просто на невидовом этаже с дачи второй квартал 25 года. Там можно посмотреть три спальни и кухня-гостиная. Да, да, да. И кухня-гостиная. Ой, 25, то есть, 24 года, то есть, следующего. Ага, все. Второй квартал, да, вы сказали? Да, второй квартал, да, второй квартал 24 года. Это сдача финальная уже в третьей очереди, последней. То есть, у нас всего три очереди. И сейчас третья достраивается уже. Угу, угу. Так, так, так, по готовым вы что сказали еще раз напомните. Ну, в готовом мы с вами в такой бюджет не войдем, наверное. Ну, войдем только три спальни и кухня-гостиная, да. Ага, а три спальни, а если три спальни мы рассмотрим хорошо, то по стоимости что получится? Ну, от 40 все-таки, я думаю, надо рассчитывать, от 40-45. Ага, угу. И какая там будет примерная площадь? Ну, можно посмотреть до 90 метров. Ага, так, хорошо, я поняла. Приходите к нам в офис, познакомитесь с проектом, посмотрите макет и можете посмотреть уже планировки, либо на сайте все также изучить. Угу, хорошо, ладно, я так и сделаю. Хорошо, спасибо большое. Сейчас до свидания, доктор. До свидания.', ' Субтитры создавал DimaTorzok', ' Живой комплекс «Федлайнер» Наталья, здравствуйте.']"}

# %% [markdown]
# Транскрибация пяти файлов записей звонков на `GPU` осуществилась в течение трёх минут.

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1104] using StatReload
# INFO:     Started server process [1106]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:42<00:00, 72.8MiB/s]
# INFO:     127.0.0.1:47336 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### `model9_21` GPU

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Библиотеки и переменные

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.5/220.5 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-3wecq4xp
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-3wecq4xp
#   Resolved https://github.com/openai/whisper.git to commit e58f28804528831904c3b6f2c0e473f346223433
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231117) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231117) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801358 sha256=af3c41b0f5cf8b121ddc4860b7f0119b94197b169e7db4233aca0042cd36fd98
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rdemewwu/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20231117

# %%
import os
import shutil
import pandas as pd
import re
import numpy as np
import pickle as pkl
import time
import tensorflow as tf
import random
import matplotlib.pyplot as plt
import whisper

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.saving             import load_model
from tensorflow.keras                    import utils
from sklearn.metrics                     import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.preprocessing               import LabelEncoder, OneHotEncoder, MinMaxScaler
from tqdm                                import trange, tqdm

from google.colab                        import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# #### Функции

# %%
def df_to_ohe(df, collist, lst_encoders = {}):

  '''
 Процедура поочерёдного преобразования колонок из списка через OneHotEncoder в ОНЕ
 с последующей сборкой в единый массив. Параметры:
 df - датафрейм,
 collist - список колонок.

 Возвращает собранный массив и список энкодеров.
  '''

  create_encode = True if len(lst_encoders) == 0 else False
  list_code = []
  for i in range(len(collist)):
    if create_encode:
      print(f'Формирование OneHotEncoder и кодировка колонки {collist[i]}', end='')
      encoder = OneHotEncoder(handle_unknown='infrequent_if_exist', sparse_output=False)
      encoder.fit(np.array(df[collist[i]].values).reshape(-1, 1))
      lst_encoders[collist[i]] = encoder
      list_code.append(encoder.transform(np.array(df[collist[i]].values).reshape(-1, 1)))
      print(' - Успешно')
    else:
      encoder = lst_encoders[collist[i]]
      list_code.append(encoder.transform(np.array(df[collist[i]].values).reshape(-1, 1)))

  x_data = np.hstack(list_code)

  return x_data, lst_encoders

# %%
def whisper_sr(df, model='medium', path_audio=''):

  sp_model = whisper.load_model(model)
  options = dict(language='Russian', beam_size=5, best_of=5)
  transcribe_options = dict(task="transcribe", **options)
  for i in trange(len(df), desc='Транскрибация аудиофайлов'):
    filename = df['audiofile'][i]
    if filename == 'Аудиофайл_не_найден':
      rezalt = 'безответа'
    else:
      rezalt = sp_model.transcribe(path_audio+filename,**transcribe_options)['text']
    df.loc[i,['whisper']] = rezalt

  return df

# %%
def file_to_df(df, path_audio='Non'):

  '''
 Функция добавляет к датафрейму поле "audiofile",
 в котором содержатся имена файлов записей звонков:
 df - датафрейм,
 path_audio - путь к записям звонков.

 Возвращает изменённый датафрейм.
  '''

  if path_audio == 'Non':
    raise KeyError('Не указан каталог с аудио данными.')

  dict_fls = {}
  for files in os.listdir(path_audio):
    session_in_file = re.findall(r'session_(\d*)_talk',files)
    dict_fls[session_in_file[0]] = files

  df.insert(1,'audiofile',value=np.NaN)
  for k in range(len(df)):
    session = str(df['Идентификатор сессии звонка'][k])
    df.loc[k,['audiofile']] = dict_fls[session]

  df.audiofile = df.audiofile.fillna('Аудиофайл_не_найден')

  return df

# %%
def model_pred(df_path, path_audio='', proces=True):

  '''
 Функция для получения предсказания модели по переданным данным:
 df_path    - путь к csv-файлу,
 path_audio - путь к записям звонков,
 proces     - флаг предобработки.

 Возвращает список с предсказаниями для всего csv-файла и сам датафрейм.
  '''

  # Загрузка предобученной модели
  model = load_model('/content/drive/MyDrive/media108.ru/Модели/model9_21.h5')

  # Загрузка датафрейма
  df = pd.read_csv(df_path)

  # Загрузка токенайзера и энкодеров, необходимых для подготовки данных
  with open('/content/drive/MyDrive/media108.ru/Модели/token_encoders.pkl', 'rb') as f:
    encoders,tokenizer_txt = pkl.load(f)

  # Вызов функции транскрибации аудиозаписей
  if path_audio != '':
    df = file_to_df(df,path_audio=path_audio)
    df.insert(2,'whisper',value='безответа')                 # добавление колонки для транскрибированного текста
    df = whisper_sr(df,model='medium',path_audio=path_audio) # типы моделей по усложнению: 'tiny','base','small','medium','large', под вопросом: 'large-v2','large-v3'

  # Очистка текстовой колонки
  df['whisper'] = df['whisper'].fillna('безответа')
  df['whisper'] = df['whisper'].apply(lambda s: re.sub('[^А-Яа-я0-9 ]', '', s.lower()))

  # Очистка тех строк, где после предыдущей операции остались одни пробелы
  df['whisper'] = df['whisper'].apply(lambda s: s.strip())

  # Заменим опустевшие ячейки текстом 'безответа'
  df['whisper'] = np.where(df['whisper'].str.len() < 5, 'безответа', df['whisper'])

  # Заменим буквы 'ё' на 'е'
  df['whisper'] = df['whisper'].str.replace('ё', 'е', regex=False)

  # Получение матрицы BOW для колонки с расшифровками
  txt_list = df['whisper'].tolist()
  txt_bow = tokenizer_txt.texts_to_matrix(txt_list)

  # Очистка колонок для ОНЕ
  if proces:
    tp_of_ab = df['Тип посетителя'].to_list()
    for i in range(len(tp_of_ab)):
      tp_of_ab[i] = tp_of_ab[i].replace('{','').replace('}','')
    df['Тип посетителя'] = tp_of_ab
  if proces:
    prk = df['Первая рекламная кампания'].to_list()
    for i in range(len(prk)):
      prk[i] = prk[i].replace('{','').replace('}','')
    df['Первая рекламная кампания'] = prk

  # Получение матрицы ОНЕ
  col_to_ohe = ['Статус', 'Тип', 'Сайт', 'Тип посетителя', 'Сценарий', 'Операции', 'Тип устройства', 'Первая рекламная кампания']
  df[col_to_ohe] = df[col_to_ohe].fillna('Нет данных')
  OHE_data, encoders = df_to_ohe(df, col_to_ohe, lst_encoders = encoders)
  OHE_data = OHE_data.astype('float32')

  # Подготовка числовых колонок
  if proces:
    df['Чистая длительность разговора'] = df['Чистая длительность разговора'].fillna('00-00-00')
    length_talk = df['Чистая длительность разговора'].to_list()
    len_sec = list()
    for lnt in length_talk:
      match_tlk = re.findall(r'(\d\d)', lnt)
      len_sec.append(int(match_tlk[0])*3600+int(match_tlk[1])*60+int(match_tlk[2]))
    df['Чистая длительность разговора'] = len_sec
    length_talk = df['Длительность звонка'].to_list()
    len_sec = list()
    for lnt in length_talk:
       match_tlk = re.findall(r'(\d\d)', lnt)
       len_sec.append(int(match_tlk[0])*3600+int(match_tlk[1])*60+int(match_tlk[2]))
    df['Длительность звонка'] = len_sec

  # Массив из числовых колонок
  digit_col = ['Чистая длительность разговора', 'Номер обращения', 'ID посетителя']
  df[digit_col] = df[digit_col].fillna(0)
  df['ID посетителя'] = df['ID посетителя']/100000000 # понижение разрядноси колонки для более плавной нормализации
  x_data = np.array(df[digit_col].values)
  x_data = x_data.astype('float32')

  # Нормализация массива
  max_val = x_data.max()
  x_data = x_data / max_val

  y_pred = model.predict({'input_x1':txt_bow,'input_x2':OHE_data,'input_x3':x_data}, batch_size=txt_bow.shape[0])

  df.insert(3,'y_pred',value = np.rint(y_pred))

  df['predict'] = np.where(df.y_pred==1.0, 'Целевой', 'Не целевой')

  return df

# %% [markdown]
# #### Подготовка тестовых данных

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/df_no_teg.csv')
df_2 = df_1[:50].copy()
df_2.drop(columns=['Имя файла','whisper'], axis=1, inplace=True)
df_2.to_csv('df_to_test.csv', index=False)

# %% [markdown]
# #### Проверка работы модели на подготовленных данных

# %%
s_time = time.time()
df = model_pred('df_to_test.csv', path_audio='/content/drive/MyDrive/media108.ru/Датасет/Записи звонков без тегов/', proces=True)
time_all = int(time.time()-s_time)
print(f'Выполнение завершено. Длительность: {int(time_all//60)} мин и {int(time_all%60)} сек.')
# Out:
# Транскрибация аудиофайлов: 100%|██████████| 50/50 [41:24<00:00, 49.69s/it]
# 1/1 [==============================] - 1s 1s/step
# Выполнение завершено. Длительность: 41 мин и 46 сек.

# %%
df.predict.value_counts()
# Out:
# Целевой       30
# Не целевой    20
# Name: predict, dtype: int64

# %%
df[['y_pred','predict','whisper']]
# Out:
#     y_pred     predict                                            whisper
# 0      0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 1      1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 2      0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 3      0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 4      1.0     Целевой  здравствуйте вы позвонили компании   пожалуйст...
# 5      1.0     Целевой  здравствуйте вы позвонили компанию   пожалуйст...
# 6      1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 7      1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 8      0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 9      0.0  Не целевой  алло здравствуйте компания мэргрупп меня зовут...
# 10     0.0  Не целевой  алло здравствуйте компания моргроб меня зовут ...
# 11     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 12     1.0     Целевой  здравствуйте здравствуйте компания мэргрупп ме...
# 13     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 14     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 15     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 16     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 17     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 18     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 19     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 20     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 21     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 22     0.0  Не целевой                            алло секретарьер слушаю
# 23     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 24     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 25     0.0  Не целевой  алло алло компания маргрупп татьяна здравствуй...
# 26     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 27     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 28     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 29     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 30     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 31     0.0  Не целевой                             алло секрет ева слушаю
# 32     0.0  Не целевой  вам одобрена кредитная карта с линитом до 1 ми...
# 33     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 34     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 35     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 36     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 37     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 38     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 39     0.0  Не целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 40     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 41     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 42     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 43     0.0  Не целевой                       сейчас вам не могут ответить
# 44     0.0  Не целевой  здравствуйте обратите внимание к компанию   по...
# 45     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 46     1.0     Целевой  здравствуйте вы позвонили в компанию   пожалуй...
# 47     1.0     Целевой  здравствуйте вы поднялись в компанию эмергрупп...
# 48     1.0     Целевой  вы интересовались жилым комплексом по билетско...
# 49     0.0  Не целевой  добрый день компания маргроб меня зовут елена ...

# %%
df[['predict','Статус','Тип','Сайт','Тип посетителя','Сценарий','Операции','Тип устройства','Первая рекламная кампания','Чистая длительность разговора','Длительность звонка']]
# Out:
#        predict    Статус                        Тип                Сайт  \
# 0   Не целевой  Принятый   Динамический коллтрекинг  pavcity.turbo.site
# 1      Целевой  Принятый                  Аналитика  pavcity.turbo.site
# 2   Не целевой  Принятый   Динамический коллтрекинг  pavcity.turbo.site
# 3   Не целевой  Принятый   Динамический коллтрекинг  pavcity.turbo.site
# 4      Целевой  Принятый                  Аналитика          pavcity.ru
# 5      Целевой  Принятый                  Аналитика          pavcity.ru
# 6      Целевой  Принятый                  Аналитика          pavcity.ru
# 7      Целевой  Принятый                  Аналитика          pavcity.ru
# 8   Не целевой  Принятый  Сохранённая переадресация          pavcity.ru
# 9   Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 10  Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 11     Целевой  Принятый                  Аналитика          pavcity.ru
# 12     Целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 13     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 14     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 15  Не целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 16     Целевой  Принятый                  Аналитика          pavcity.ru
# 17  Не целевой  Принятый  Сохранённая переадресация          pavcity.ru
# 18  Не целевой  Принятый                  Аналитика          pavcity.ru
# 19     Целевой  Принятый                  Аналитика          pavcity.ru
# 20  Не целевой  Принятый                  Аналитика          pavcity.ru
# 21     Целевой  Принятый                  Аналитика          pavcity.ru
# 22  Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 23     Целевой  Принятый                  Аналитика          pavcity.ru
# 24     Целевой  Принятый                  Аналитика          pavcity.ru
# 25  Не целевой  Принятый           Звонки из VK Ads          pavcity.ru
# 26  Не целевой  Принятый  Сохранённая переадресация          pavcity.ru
# 27     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 28     Целевой  Принятый                  Аналитика          pavcity.ru
# 29     Целевой  Принятый                  Аналитика          pavcity.ru
# 30     Целевой  Принятый                  Аналитика          pavcity.ru
# 31  Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 32  Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 33     Целевой  Принятый                  Аналитика          pavcity.ru
# 34  Не целевой  Принятый                  Аналитика          pavcity.ru
# 35     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 36     Целевой  Принятый                  Аналитика          pavcity.ru
# 37     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 38     Целевой  Принятый   Динамический коллтрекинг          pavcity.ru
# 39  Не целевой  Принятый                  Аналитика          pavcity.ru
# 40     Целевой  Принятый                  Аналитика          pavcity.ru
# 41     Целевой  Принятый                  Аналитика          pavcity.ru
# 42     Целевой  Принятый                  Аналитика          pavcity.ru
# 43  Не целевой  Принятый    Автоперезвон по заявкам          pavcity.ru
# 44  Не целевой  Принятый                  Аналитика          pavcity.ru
# 45     Целевой  Принятый                  Аналитика          pavcity.ru
# 46     Целевой  Принятый  Сохранённая переадресация          pavcity.ru
# 47     Целевой  Принятый                  Аналитика          pavcity.ru
# 48     Целевой  Принятый           Звонки из VK Ads          pavcity.ru
# 49  Не целевой  Принятый           Звонки из VK Ads          pavcity.ru
#
#      Тип посетителя     Сценарий                       Операции  \
# 0       Вернувшийся  74955141111                  Переадресация
# 1       Не заполнен  74955141111                  Переадресация
# 2       Вернувшийся  74955141111                  Переадресация
# 3       Вернувшийся  74955141111                  Переадресация
# 4       Не заполнен  74955141111                  Переадресация
# 5       Не заполнен      SIP URI  Переадресация на сотрудника 1
# 6       Не заполнен      SIP URI  Переадресация на сотрудника 1
# 7       Не заполнен  74955141111                  Переадресация
# 8       Не заполнен  74955141111                  Переадресация
# 9             Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 10            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 11      Не заполнен  74955141111                  Переадресация
# 12      Вернувшийся   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 13            Новый  74955141111                  Переадресация
# 14            Новый  74955141111                  Переадресация
# 15            Новый  74955141111                  Переадресация
# 16      Не заполнен  74955141111                  Переадресация
# 17      Не заполнен  74955141111                  Переадресация
# 18      Не заполнен  74955141111                  Переадресация
# 19      Не заполнен  74955141111                  Переадресация
# 20      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 21      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 22      Вернувшийся   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 23      Не заполнен  74955141111                  Переадресация
# 24      Не заполнен  74955141111                  Переадресация
# 25            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 26      Не заполнен  74955141111                  Переадресация
# 27  Санкт-Петербург  74955141111                  Переадресация
# 28      Не заполнен  74955141111                  Переадресация
# 29      Не заполнен  74955141111                  Переадресация
# 30      Не заполнен  74955141111                  Переадресация
# 31      Вернувшийся   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 32            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 33      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 34      Не заполнен  74955141111                  Переадресация
# 35      Вернувшийся  74955141111                  Переадресация
# 36      Не заполнен  74955141111                  Переадресация
# 37            Новый  74955141111                  Переадресация
# 38            Новый  74955141111                  Переадресация
# 39      Не заполнен  74955141111                  Переадресация
# 40      Не заполнен  74955141111                  Переадресация
# 41      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 42      Не заполнен  74955141111                  Переадресация
# 43            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 44      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 45      Не заполнен  74955141111                  Переадресация
# 46      Не заполнен  74955141111                  Переадресация
# 47      Не заполнен      SIP URI  Переадресация на сотрудника 1
# 48            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
# 49            Новый   ОЗ (SIP<1)  Переадресация на сотрудника 1
#
#    Тип устройства                          Первая рекламная кампания  \
# 0        Смартфон  Artics | Павелецкая Сити | direct | Яндекс.Дир...
# 1          Прочее                  Посетители без рекламной кампании
# 2        Смартфон  Artics | Павелецкая Сити | direct | Яндекс.Дир...
# 3        Смартфон  Artics | Павелецкая Сити | direct | Яндекс.Дир...
# 4          Прочее                  Посетители без рекламной кампании
# 5          Прочее                  Посетители без рекламной кампании
# 6          Прочее                  Посетители без рекламной кампании
# 7          Прочее                  Посетители без рекламной кампании
# 8          Прочее                  Посетители без рекламной кампании
# 9              ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 10             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 11         Прочее  Artics | Павелецкая Сити | direct | Яндекс.Дир...
# 12       Смартфон  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 13       Смартфон  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 14       Смартфон  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 15       Смартфон  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 16         Прочее                  Посетители без рекламной кампании
# 17         Прочее                  Посетители без рекламной кампании
# 18         Прочее                  Посетители без рекламной кампании
# 19         Прочее                  Посетители без рекламной кампании
# 20         Прочее                  Посетители без рекламной кампании
# 21         Прочее                  Посетители без рекламной кампании
# 22             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 23         Прочее                  Посетители без рекламной кампании
# 24         Прочее                  Посетители без рекламной кампании
# 25         Прочее       Media108 | Павелецкая Сити | social | VK Ads
# 26         Прочее                  Посетители без рекламной кампании
# 27             ПК  &text=&etext=2202.ycg_YJT159Dzsk0trNFG6P3Y0MuK...
# 28         Прочее     MRGroup | Павелецкая Сити | seo | Google Поиск
# 29         Прочее     MRGroup | Павелецкая Сити | seo | Google Поиск
# 30         Прочее                  Посетители без рекламной кампании
# 31             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 32             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 33         Прочее                  Посетители без рекламной кампании
# 34         Прочее                  Посетители без рекламной кампании
# 35             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 36         Прочее                  Посетители без рекламной кампании
# 37             ПК  Artics | Павелецкая Сити | direct | Яндекс.Дир...
# 38             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 39         Прочее                  Посетители без рекламной кампании
# 40         Прочее                  Посетители без рекламной кампании
# 41         Прочее                  Посетители без рекламной кампании
# 42         Прочее                  Посетители без рекламной кампании
# 43             ПК  Media108 | Павелецкая Сити | direct | Яндекс.Д...
# 44         Прочее                  Посетители без рекламной кампании
# 45         Прочее                  Посетители без рекламной кампании
# 46         Прочее                  Посетители без рекламной кампании
# 47         Прочее                  Посетители без рекламной кампании
# 48         Прочее       Media108 | Павелецкая Сити | social | VK Ads
# 49         Прочее       Media108 | Павелецкая Сити | social | VK Ads
#
#     Чистая длительность разговора  Длительность звонка
# 0                              59                   60
# 1                              67                   69
# 2                              49                   50
# 3                              33                   34
# 4                             128                  130
# 5                              80                   81
# 6                              37                   38
# 7                             230                  231
# 8                              41                   42
# 9                               8                   65
# 10                             14                   49
# 11                            142                  144
# 12                            590                  637
# 13                            161                  163
# 14                            135                  137
# 15                            153                  155
# 16                            151                  152
# 17                             31                   32
# 18                             54                   55
# 19                            534                  535
# 20                             45                   46
# 21                             71                   73
# 22                              6                   38
# 23                            796                  797
# 24                            112                  113
# 25                             22                   65
# 26                             49                   50
# 27                              0                  612
# 28                            198                  199
# 29                            220                  222
# 30                            193                  194
# 31                              3                   36
# 32                              5                   37
# 33                             47                   48
# 34                             48                   50
# 35                            321                  323
# 36                            275                  276
# 37                            697                  698
# 38                            154                  156
# 39                             55                   57
# 40                            475                  477
# 41                             43                   44
# 42                            238                  239
# 43                              3                   46
# 44                             33                   34
# 45                            833                  835
# 46                             46                   48
# 47                             56                   57
# 48                             20                   65
# 49                             14                   55

# %%
x_time = np.array(df['Чистая длительность разговора'].values)

# %%
print(f'Общая длительность: {int(x_time.sum()//60)} мин и {int(x_time.sum()%60)} сек.')
# Out:
# Общая длительность: 129 мин и 35 сек.

# %% [markdown]
# ### Создание датафрейма с тестовыми данными

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка сводного датафрейма
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/rookie_total_df.csv')
df.shape
# Out:
# (23386, 77)

# %%
# Выбор необходимых столбцов
df = df[['Статус',
         'Тип',
         'Сайт',
         'Тип посетителя',
         'Сценарий',
         'Операции',
         'Тип устройства',
         'Первая рекламная кампания',
         'Чистая длительность разговора',
         'Номер обращения',
         'ID посетителя',
         'Идентификатор сессии звонка',
         'Файл записи звонка',
         'Класс',
         'Проект']][df['Файл записи звонка'] != 'нет файла'].sample(5)
df.shape
# Out:
# (5, 15)

# %%
df
# Out:
#          Статус               Тип              Сайт Тип посетителя  \
# 3763   Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21030  Принятый         Аналитика  primavera.moscow    Не заполнен
# 20109  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21952  Принятый  Звонки из VK Ads        pavcity.ru          Новый
# 7322   Принятый       Звонок ВАТС  primavera.moscow    Не заполнен
#
#                     Сценарий  \
# 3763                 Кортрос
# 21030  Обработка вызова 2023
# 20109                Кортрос
# 21952             ОЗ (SIP<1)
# 7322   Обработка вызова 2023
#
#                                                 Операции Тип устройства  \
# 3763                                     Переадресация 1         Прочее
# 21030                   Интерактивная обработка вызова 1         Прочее
# 20109                                    Переадресация 1         Прочее
# 21952                      Переадресация на сотрудника 1         Прочее
# 7322   Интерактивная обработка вызова 1, Интерактивна...         Прочее
#
#                           Первая рекламная кампания  \
# 3763              Посетители без рекламной кампании
# 21030             Посетители без рекламной кампании
# 20109             Посетители без рекламной кампании
# 21952  Media108 | Павелецкая Сити | social | VK Ads
# 7322              Посетители без рекламной кампании
#
#       Чистая длительность разговора  Номер обращения  ID посетителя  \
# 3763                       00:14:15                1              0
# 21030                      00:00:34                1              0
# 20109                      00:01:05                1              0
# 21952                      00:00:17                2     7558036959
# 7322                       00:02:16                1              0
#
#        Идентификатор сессии звонка  \
# 3763                    3083061142
# 21030                   3230957576
# 20109                   3251357547
# 21952                   3160197614
# 7322                    3075218173
#
#                                       Файл записи звонка       Класс  \
# 3763   Записи звонков/Записи звонков_хедлайнер/2023-0...     Целевой
# 21030  Новые записи звонков/Записи Primavera/2023-09-...     Целевой
# 20109  Новые записи звонков/Записи Headliner/2023-09-...  Нецелевой
# 21952  Новые записи звонков/Записи Павелецкая сити/20...  Нецелевой
# 7322   Записи звонков/Записи звонков_primavera/2023-0...  Нецелевой
#
#                   Проект
# 3763           Headliner
# 21030          Primavera
# 20109          Headliner
# 21952  Paveletskaya_city
# 7322           Primavera

# %%
# Добавление столбца 'ID проекта'
df['ID проекта'] = 0
df.loc[df[df['Проект'] == 'Headliner'].index, 'ID проекта'] = 1
df.loc[df[df['Проект'] == 'Primavera'].index, 'ID проекта'] = 2

# %%
# Очистка от '{}' значений столбца 'Тип посетителя'
df['Тип посетителя'] = df['Тип посетителя'].apply(lambda x: x.strip('{}'))

# %%
# Очистка от '{}' значений столбца 'Первая рекламная кампания'
df['Первая рекламная кампания'] = df['Первая рекламная кампания'].apply(lambda x: x.strip('{}'))

# %%
# Переводим значения столбца 'Чистая длительность разговора' в количество секунд
df['Чистая длительность разговора'] = pd.to_datetime(df['Чистая длительность разговора']).dt.time
df['Чистая длительность разговора'] = df['Чистая длительность разговора'].apply(lambda x: x.hour*60*60 + x.minute*60 + x.second)

# %%
# Типы данных
df.dtypes
# Out:
# Статус                           object
# Тип                              object
# Сайт                             object
# Тип посетителя                   object
# Сценарий                         object
# Операции                         object
# Тип устройства                   object
# Первая рекламная кампания        object
# Чистая длительность разговора     int64
# Номер обращения                   int64
# ID посетителя                     int64
# Идентификатор сессии звонка       int64
# Файл записи звонка               object
# Класс                            object
# Проект                           object
# ID проекта                        int64
# dtype: object

# %%
df
# Out:
#          Статус               Тип              Сайт Тип посетителя  \
# 3763   Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21030  Принятый         Аналитика  primavera.moscow    Не заполнен
# 20109  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21952  Принятый  Звонки из VK Ads        pavcity.ru          Новый
# 7322   Принятый       Звонок ВАТС  primavera.moscow    Не заполнен
#
#                     Сценарий  \
# 3763                 Кортрос
# 21030  Обработка вызова 2023
# 20109                Кортрос
# 21952             ОЗ (SIP<1)
# 7322   Обработка вызова 2023
#
#                                                 Операции Тип устройства  \
# 3763                                     Переадресация 1         Прочее
# 21030                   Интерактивная обработка вызова 1         Прочее
# 20109                                    Переадресация 1         Прочее
# 21952                      Переадресация на сотрудника 1         Прочее
# 7322   Интерактивная обработка вызова 1, Интерактивна...         Прочее
#
#                           Первая рекламная кампания  \
# 3763              Посетители без рекламной кампании
# 21030             Посетители без рекламной кампании
# 20109             Посетители без рекламной кампании
# 21952  Media108 | Павелецкая Сити | social | VK Ads
# 7322              Посетители без рекламной кампании
#
#        Чистая длительность разговора  Номер обращения  ID посетителя  \
# 3763                             855                1              0
# 21030                             34                1              0
# 20109                             65                1              0
# 21952                             17                2     7558036959
# 7322                             136                1              0
#
#        Идентификатор сессии звонка  \
# 3763                    3083061142
# 21030                   3230957576
# 20109                   3251357547
# 21952                   3160197614
# 7322                    3075218173
#
#                                       Файл записи звонка       Класс  \
# 3763   Записи звонков/Записи звонков_хедлайнер/2023-0...     Целевой
# 21030  Новые записи звонков/Записи Primavera/2023-09-...     Целевой
# 20109  Новые записи звонков/Записи Headliner/2023-09-...  Нецелевой
# 21952  Новые записи звонков/Записи Павелецкая сити/20...  Нецелевой
# 7322   Записи звонков/Записи звонков_primavera/2023-0...  Нецелевой
#
#                   Проект  ID проекта
# 3763           Headliner           1
# 21030          Primavera           2
# 20109          Headliner           1
# 21952  Paveletskaya_city           0
# 7322           Primavera           2

# %%
# Сохранение датафрейма с тестовыми данными
df.to_csv('/content/drive/MyDrive/media108.ru/Датафреймы/test_data_df.csv', index=False)

# %% [markdown]
# ### Создание тестового входного `json-файла`

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка датафрейма с тестовыми данными
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/test_data_df.csv')
df.shape
# Out:
# (5, 16)

# %%
df
# Out:
#      Статус               Тип              Сайт Тип посетителя  \
# 0  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 1  Принятый         Аналитика  primavera.moscow    Не заполнен
# 2  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 3  Принятый  Звонки из VK Ads        pavcity.ru          Новый
# 4  Принятый       Звонок ВАТС  primavera.moscow    Не заполнен
#
#                 Сценарий                                           Операции  \
# 0                Кортрос                                    Переадресация 1
# 1  Обработка вызова 2023                   Интерактивная обработка вызова 1
# 2                Кортрос                                    Переадресация 1
# 3             ОЗ (SIP<1)                      Переадресация на сотрудника 1
# 4  Обработка вызова 2023  Интерактивная обработка вызова 1, Интерактивна...
#
#   Тип устройства                     Первая рекламная кампания  \
# 0         Прочее             Посетители без рекламной кампании
# 1         Прочее             Посетители без рекламной кампании
# 2         Прочее             Посетители без рекламной кампании
# 3         Прочее  Media108 | Павелецкая Сити | social | VK Ads
# 4         Прочее             Посетители без рекламной кампании
#
#    Чистая длительность разговора  Номер обращения  ID посетителя  \
# 0                            855                1              0
# 1                             34                1              0
# 2                             65                1              0
# 3                             17                2     7558036959
# 4                            136                1              0
#
#    Идентификатор сессии звонка  \
# 0                   3083061142
# 1                   3230957576
# 2                   3251357547
# 3                   3160197614
# 4                   3075218173
#
#                                   Файл записи звонка       Класс  \
# 0  Записи звонков/Записи звонков_хедлайнер/2023-0...     Целевой
# 1  Новые записи звонков/Записи Primavera/2023-09-...     Целевой
# 2  Новые записи звонков/Записи Headliner/2023-09-...  Нецелевой
# 3  Новые записи звонков/Записи Павелецкая сити/20...  Нецелевой
# 4  Записи звонков/Записи звонков_primavera/2023-0...  Нецелевой
#
#               Проект  ID проекта
# 0          Headliner           1
# 1          Primavera           2
# 2          Headliner           1
# 3  Paveletskaya_city           0
# 4          Primavera           2

# %%
# Сохранение тестовых данных в json
df.to_json('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json', orient='records', force_ascii=False)

# %%
# !cat /content/drive/MyDrive/media108.ru/Датафреймы/test_data.json
# Out:
# [{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":855,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3083061142,"Файл записи звонка":"Записи звонков\/Записи звонков_хедлайнер\/2023-07-11_16-18-51.610373_from_79263731436_to_0188880_session_3083061142_talk.mp3","Класс":"Целевой","Проект":"Headliner","ID проекта":1},{"Статус":"Принятый","Тип":"Аналитика","Сайт":"primavera.moscow","Тип посетителя":"Не заполнен","Сценарий":"Обработка вызова 2023","Операции":"Интерактивная обработка вызова 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":34,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3230957576,"Файл записи звонка":"Новые записи звонков\/Записи Primavera\/2023-09-17_11-31-57.762274_from_79165225772_to_0150113_session_3230957576_talk.mp3","Класс":"Целевой","Проект":"Primavera","ID проекта":2},{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":65,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3251357547,"Файл записи звонка":"Новые записи звонков\/Записи Headliner\/2023-09-23_11-26-10.992586_from_79657535970_to_0188880_session_3251357547_talk.mp3","Класс":"Нецелевой","Проект":"Headliner","ID проекта":1},{"Статус":"Принятый","Тип":"Звонки из VK Ads","Сайт":"pavcity.ru","Тип посетителя":"Новый","Сценарий":"ОЗ (SIP<1)","Операции":"Переадресация на сотрудника 1","Тип устройства":"Прочее","Первая рекламная кампания":"Media108 | Павелецкая Сити | social | VK Ads","Чистая длительность разговора":17,"Номер обращения":2,"ID посетителя":7558036959,"Идентификатор сессии звонка":3160197614,"Файл записи звонка":"Новые записи звонков\/Записи Павелецкая сити\/2023-08-17_09-06-57.786310_from_74950326372_to_00288_session_3160197614_talk.mp3","Класс":"Нецелевой","Проект":"Paveletskaya_city","ID проекта":0},{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"primavera.moscow","Тип посетителя":"Не заполнен","Сценарий":"Обработка вызова 2023","Операции":"Интерактивная обработка вызова 1, Интерактивная обработка вызова 2","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":136,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3075218173,"Файл записи звонка":"Записи звонков\/Записи звонков_primavera\/2023-07-08_17-45-47.596023_from_79778947224_to_0111639_session_3075218173_talk.mp3","Класс":"Нецелевой","Проект":"Primavera","ID проекта":2}]
