# %% [markdown]
# # Техническое задание

# %% [markdown]
# **Проект:** Классификация аудиозвонков на целевые и нецелевые.

# %% [markdown]
# **Цель проекта:** Разработать нейронную сеть, способную классифицировать аудиозвонки на целевые и нецелевые на основе предоставленной базы данных и csv-таблицы с описаниями и метками классов.

# %% [markdown]
# **Введение:**
#
# Входной набор данных представляет из себя два набора файлов:
#
# > a)	[Первый набор файлов](https://drive.google.com/drive/folders/1cQWMpQkscZJbbOTxiJNy0o3nuaeIiB1P?usp=sharing) - это выгрузки в формате `CSV` с информацией по звонкам, а так же с проставленным статусом `“целевой/нецелевой”` в отдельном столбце (обратите внимание, что по проекту `“Павелецкая сити”` две выгрузки - эти наборы данных отличаются и относятся к разным наборам клиентов внутри одного и того же проекта).
#
# > b)	[Второй набор файлов](https://drive.google.com/drive/folders/1K3jGCH60uzFcsI3aj89VIXOOFEXvZxD6?usp=sharing) - аудиозаписи звонков. Они хранятся в корневом каталоге в одноимённых папках. К примеру, в папке `“Записи звонков_павелецкая сити”` лежат записи звонков по проекту `“Павелецкая Сити”`.

# %% [markdown]
# **Требования:**
#
# 1.   Нейронная сеть должна быть спроектирована и обучена для точной классификации аудиозвонков на два класса: целевые и нецелевые (с точностью `90+%`).
# 2.   Необходимо обеспечить интеграцию модели через `API`.
# 3.   Модель должна быть оптимизирована для обработки большого объёма данных.
# 4.   Код должен быть написан с соблюдением стандартов кодирования, и должна быть составлена подробная техническая документация.
# 5.   Код должен включать в себя систему журналирования для фиксации ошибок.
# 6.   Код должен принимать на вход регулярное выражение, по которому будет осуществляться проверка столбца `“теги”` в выгрузках `CSV` для определения статуса звонка `“целевой/нецелевой”`:
#
# >> a)	по проектам `“Примавера”` и `“Павелецкая сити”` наличие в столбце с тегами подстроки `“Целевой_М108“` будет равняться тому, что данный звонок целевой (пример регулярного выражения: `.*Целевой_М108.*`);
#
# >> b)	по проекту `“Хедлайнер”` - наличие в столбце с тегами подстроки `“первичный целевой“` будет равняться тому, что данный звонок целевой.
#
# 7.   После реализации необходимо иметь возможность получения поддержки по предоставленному решению в течение `2 месяцев`.

# %% [markdown]
# Список рекомендуемых параметров для звуковой записи (данный список носит информационный характер и не является обязательным):
#
# *   Эмоция (базовые 11: радость; печаль; гнев; отвращение; удивление; страдание (горе); волнение (интерес); презрение; смущение; стыд; вина).
# *   Пол.
# *   Возраст.
# *   Семантический анализ диалога (по конкретным ключевым словам и/или по тематикам диалогов).
# *   Характеристики, присутствующие в `CSV`/`XLSX` таблицах.

# %% [markdown]
# # Критерии классификации

# %% [markdown]
# Критерии `уникально-целевого` обращения:
# 1. Длительность звонка должна быть не менее `75 секунд`;
# 2. Телефонный номер абонента должен быть `уникальным`, т. е. его не должно быть в `CRM` заказчика. Либо, по нему не должно быть активности за последние `90 дней`. Исключение составляют `топовые площадки`, работающие по своим критериям (`ЦИАН`, `Яндекс.Недвижимость`, `Авито`, и т. д.);
# 3. Клиент должен знать минимальную информацию об объекте (понимать, куда он звонит): название `ЖК`, расположение, ценовую политику;
# 4. Номер абонента должен быть доступен в течение `15 дней` после совершённого звонка (при этом со стороны заказчика должно быть обеспечено `2 попытки` исходящего звонка в течение указанного срока);
# 5. Клиент должен быть `«адекватным»`. Не общаться на повышенных тонах, не употреблять ненормативную лексику и т. д.;
# 6. Клиент не должен быть повторным. Например, клиент `уже` купил квартиру и через `90 дней` решил купить машиноместо;
# 7. Заявка. В заявке должен быть указан номер телефона, а абонент при контакте с менеджером должен соответствовать всем критериям `уникально-целевого` обращения, перечисленным выше;
# 8. Озвученный общий бюджет покупки не должен быть `ниже 90%` от стоимости квартиры или коммерческого помещения, соответствующих площади/комнатности на момент обращения;
# 9. В случае, если клиент является уникальным, интересуется покупкой недвижимости, не является представителем партнёров или исполнителей и изъявил желание посетить офис продаж. При этом не обязательна фиксация уровня знания клиента об объекте в диалоге. При этом источник не должен относиться к каналам `«лидогенерация»` или `«тематические площадки»`;
# 10. Основной целью звонка клиента не должна являться покупка/аренда исключительно нежилого помещения, если это не являлось целью проводимой рекламной кампании.
#
# Критерии НЕ `уникально-целевого` (вторичного) обращения:
# 1. Клиент позвонил повторно менее чем через `3 месяца` (`90 дней`) с момента последнего обращения;
# 2. Клиент, либо члены его семьи, уже купил (купили) `квартиру`/`машиноместо`/`кладовое помещение`, и хочет (хотят) совершить ещё одну покупку. В данном случае клиент относится к показателю `LTV` (показатель прибыли, которую компания получает от одного клиента за всё время работы с ним).

# %% [markdown]
# # 12 неделя

# %% [markdown]
# ## Тесты по интеграции в `prod`

# %% [markdown]
# ### API (`whisper`-транскрибация `sample_file.mp3`)

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 68.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 9.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import whisper

def transcribe(file_path):
    whisper_model = whisper.load_model('medium')
    print(whisper_model.transcribe(file_path, language='ru')['text'])

transcribe('sample_file.mp3')
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:13<00:00, 110MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Здравствуйте, вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании Cartros, Татьяна, здравствуйте. Алло, Татьяна, здравствуйте. Как мне с вами из вашего отдела продаж что-то поговорить? Что-то у вас квартиру купить, право надо еще заслужить, я так понял, да? Я вас соединю тогда с менеджером. Минута осталось 15 минут. Андрей, здравствуйте, мне тут Антон слушает вас. Всем могу помочь? Да, Антон, здравствуйте. А мне бы на самом деле посмотреть квартиру. И наверное, по крайней мере, она нам нравится. Пару вопросов по ней задать. Да, какая квартира, Андрей? Сейчас скажу. Вот смотрите, я в фильтрах выбираю двухкомнатную она. На 51 этаже. Сейчас скажу ее номер. Номер. Да, либо номер. 341, 67 метров которая. Так, сейчас секундочку, Андрей. Поправится 39,309, правильно? Да, да, да. Андрей, смотрите. Вы мне подскажите пожалуйста, можно я вам сразу вопросы, которые вот входит? Да, конечно. Чем отличается вид на реку от ВАУ? Сейчас, секунду. ВАУ, вид на реку. Сейчас, секунду. ВАУ, вид на реку. ВАУ, вид на реку. Сейчас, секунду. Задний за мной. Алло. Да, да. Я говорю, у вас какие-то характеристики, красные написаны. Вот на ней написано, вид на реку. А допустим рядом есть какая-то ВАУ, вид на воду. Это что такое? Ну, что бы я скажу, никакой разницы нет. Я не знаю, что такое написано на сайте. ВАУ, вид на воду. Вау, вид на реку. Вит на город. Очень высокие этажи. Вид на все абсолютно. Даже если рассмотреть так уже квартиру ниже этажами, есть такие варианты. А эти этажи будут ничем не хуже. Потому что перед единым домом они не будут. И они будут не очень красивыми. А вот это я говорю. Вау, вид на реку. А вот это я говорю. А вот это я говорю. А вот это я говорю. И здесь ниже, ниже. Потому что все дома, они все гораздо ниже. И там никто и никогда не построит. А вот этот вопрос. Если смотреть на день плана. Я вчера проезжал. Такое ощущение, что перед этим корпусом в первую очередь тоже стоит 51-этажный дом. Он не закрывается. Там стоит 51-этажный дом. Совершенно верно. Но он стоит, скажем, правее. То есть если вы подходите к окну этой квартиры вашей и смотрите вправо, В основном, 90% вида – это панорама. – Ты к окну подходишь и не смотришь в окна соседнего дома. – Нет. – Вы сказали, что хотели бы посмотреть квартиру. – В этом корпусе монолитная работа завершена. – В этом корпусе не завершено. – Я могу уточнить, что проход на стройку запрещен. Турецкие подрядчики достаточно строго к этому относятся. – У нас есть один день в неделе, это воскресенье. Мы собираем группу людей, кто хочет купить квартиру, и показываем какие-то квартиры. Не всегда это квартиры, которые клиент желает. Но чаще всего нам удается показать квартиры, которые клиент хочет посмотреть. – Давай, если завтра подъедем. – Там есть строительный лифт, который может поднять на 51-й этаж. Возможно, чуть ниже посмотрим. – Я понял. Я вам сейчас прислаю свою визитку. Примем с моим именем. Завтра вам нужно будет приехать к нам в 12 часов ровно. – Скажем так, наш коллега на стройку уже клиентов уволит. – Да, я не знаю. С женой, наверное, вдвоем приедем. – Мне нужно будет для того, чтобы заказать для вас пропуск для прохода на стройку ваших фамилий и имя, учитывая тех, кто будет на объекте. – Котов Андрей Владимирович? – Сейчас, секунду. – И соответственно, Котова, Наталья Крустантиновна. – Я вам сейчас на вотап на крыльях. – А можно я вас вовсе помучаю? – Да, конечно. – Вот, допустим, эта квартира 341. Она у нее метр стоит 496 400 рублей. А даже нет, не так прошло. Вот эта квартира 341 со слипкой стоит 33 миллиона 412 тысяч. А вот соседняя 341… – Так, соседняя 341, да. – А соседняя 341… А, я понял, она больше площади. – Там площадь больше, да. – Понял, с чем тогда дело. Ну, Кит, давайте мы ее… – Подскажите, у вас по оплате чено и так возможно? – Возможно, ипотека. – Мне бы знаете, как было максимально комфортно. Я бы там, грубо говоря, миллионов 20-25 заплатил сейчас. – А остальная 20-ка, да? – Остаток. Ну, там до нового  ...

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.1 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
from fastapi import FastAPI
from pydantic import BaseModel
import whisper

class Item(BaseModel):
  file: str

app = FastAPI()

@app.post('/predict')
async def predict(item: Item):
  whisper_model = whisper.load_model('medium')
  sample_file = whisper_model.transcribe(item.file, language='ru')
  return {'result': sample_file}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [10921] using StatReload

# %%
import requests
response = requests.post('http://127.0.0.1:8000/predict', json={'file': 'sample_file.mp3'})
print(response.text)
# Out:
# {"result":{"text":" Здравствуйте, вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании Cartros, Татьяна, здравствуйте. Алло, Татьяна, здравствуйте. Как мне с вами из вашего отдела продаж что-то поговорить? Что-то у вас квартиру купить, право надо еще заслужить, я так понял, да? Я вас соединю тогда с менеджером. Минута осталось 15 минут. Андрей, здравствуйте, мне тут Антон слушает вас. Всем могу помочь? Да, Антон, здравствуйте. А мне бы на самом деле посмотреть квартиру. И наверное, по крайней мере, она нам нравится. Пару вопросов по ней задать. Да, какая квартира, Андрей? Сейчас скажу. Вот смотрите, я в фильтрах выбираю двухкомнатную она. На 51 этаже. Сейчас скажу ее номер. Номер. Да, либо номер. 341, 67 метров которая. Так, сейчас секундочку, Андрей. Поправится 39,309, правильно? Да, да, да. Андрей, смотрите. Вы мне подскажите пожалуйста, можно я вам сразу вопросы, которые вот входит? Да, конечно. Чем отличается вид на реку от ВАУ? Сейчас, секунду. ВАУ, вид на реку. Сейчас, секунду. ВАУ, вид на реку. ВАУ, вид на реку. Сейчас, секунду. Задний за мной. Алло. Да, да. Я говорю, у вас какие-то характеристики, красные написаны. Вот на ней написано, вид на реку. А допустим рядом есть какая-то ВАУ, вид на воду. Это что такое? Ну, что бы я скажу, никакой разницы нет. Я не знаю, что такое написано на сайте. ВАУ, вид на воду. Вау, вид на реку. Вит на город. Очень высокие этажи. Вид на все абсолютно. Даже если рассмотреть так уже квартиру, чуть ниже этажами, они там есть такие варианты. Если я не ошибаюсь, там 40 какой-то этаж есть. Эти этажи будут ничем не хуже. Потому что впереди дома они не будут. И это не будет нехорошо. И вот, в общем, я не знаю, что вы думаете. А эти этажи будут тоже ничем не хуже. Потому что впереди дома они все гораздо ниже. И там никто и никогда не построит уже дома. А вот этот очень важный вопрос. Конкретно, если смотришь на «Генфлайны», я вчера проезжал, вот такое ощущение, что перед этим корпусом в первую очередь тоже стоит 51-этажный дом. Он не закрывается? Там стоит 51-этажный дом, совершенно верно. Но он стоит, скажем так, правее. То есть если вы подходите к окну этой квартиры вашей, и смотрите прямо вправо, то конечно, какую-то часть этот дом загородит. Но в основном, то есть 90% вида, это полный панорам откуда. Да тут даже, знаете, вид, ладно, он применюхается. Основной вопрос такой, что ты к окну подходишь, и ты не смотришь в окна соседнего дома, правильно? Нет, нет, нет, там такого нет. Ну, вы знаете, сейчас в Человиннике строят. Ну, я тебя понимаю, что вы говорите, да. Вы сначала разговора сказали, что вы хотели бы квартиру посмотреть. А вы, конечно, не хотели бы. Ну, как посмотреть, да. Но я так понимаю, что корпус еще не построен же, правильно? В этом корпусе уже монолитная работа практически полностью завершена. 51-этажный дом уже полностью построен. Там сейчас идут работы по фасадам, по инженерии, внутри корпуса, вон деревья ставятся, так далее. Вот. Курицы же не запутаны, мы же не пойдем с вами не со первого этажа. Ну, вот. Знаете, какая ситуация у нас? Вообще, в принципе, проход на стройку, он пока для клиентов, для нас самих он тоже запрещен. Там турецкие подрядщики, они достаточно строго к этому относятся, там с работы ведутся, это опасно. Но у нас есть один день в неделе, это воскресенье в 12-6-го дня ровно. Мы, скажем так, собираем группу людей, клиентов, кто хочет купить, кто-то уже купил квартиру и показываем там какие-то определенные квартиры. Не всегда это квартиры те, которые именно клиент желает, но чаще всего нам удается показать квартиры те, которые клиент сам точно хочет посмотреть. Ну, давайте, мы же завтра подъедем. Да, там есть строительный лифт, который можно поднять на 51-й этаж. Ну, возможно, чуть ниже посмотрим, вид будет тот же самый, вы особо не почувствуете. Ну, непонятно. Там остановили, на самом деле, чтобы глаза в этот дом не упирались в первый ход. Я понял, да, у вас это главный вопрос. Я вам сейчас н ...

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [10921] using StatReload
# INFO:     Started server process [10923]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# INFO:     127.0.0.1:33864 - "POST /predict HTTP/1.1" 200 OK

# %%
def transcribe(file_path):
    whisper_model = whisper.load_model('medium')
    print(whisper_model.transcribe(file_path, language='ru', verbose=True)['text'])

transcribe('sample_file.mp3')
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:03.640]  Здравствуйте, вы позвонили в группу компании Cartros.
# [00:03.640 --> 00:05.520]  Благодарим вас за звонок.
# [00:05.520 --> 00:08.000]  Пожалуйста, дождитесь ответа оператора.
# [00:16.720 --> 00:20.080]  Группа компании Cartros, Татьяна, здравствуйте.
# [00:20.080 --> 00:21.880]  Алло, Татьяна, здравствуйте.
# [00:21.880 --> 00:24.640]  Как мне с вами из вашего отдела продаж что-то поговорить?
# [00:24.640 --> 00:28.320]  Что-то у вас квартиру купить, право надо еще заслужить, я так понял, да?
# [00:30.480 --> 00:32.480]  Я вас соединю тогда с менеджером.
# [00:32.480 --> 00:34.480]  Минута осталось 15 минут.
# [00:56.080 --> 00:58.080]  Андрей, здравствуйте, мне тут Антон слушает вас.
# [00:58.160 --> 01:00.160]  Всем могу помочь?
# [01:00.160 --> 01:02.160]  Да, Антон, здравствуйте.
# [01:02.160 --> 01:04.160]  А мне бы на самом деле посмотреть квартиру.
# [01:04.160 --> 01:08.160]  И наверное, по крайней мере, она нам нравится.
# [01:08.160 --> 01:10.160]  Пару вопросов по ней задать.
# [01:12.160 --> 01:14.160]  Да, какая квартира, Андрей?
# [01:14.160 --> 01:16.160]  Сейчас скажу.
# [01:16.160 --> 01:18.160]  Вот смотрите, я в фильтрах выбираю двухкомнатную она.
# [01:18.160 --> 01:20.160]  На 51 этаже.
# [01:22.160 --> 01:24.160]  Сейчас скажу ее номер.
# [01:24.240 --> 01:26.240]  Номер.
# [01:26.240 --> 01:28.240]  Да, либо номер.
# [01:28.240 --> 01:30.240]  341, 67 метров которая.
# [01:34.240 --> 01:36.240]  Так, сейчас секундочку, Андрей.
# [01:54.240 --> 01:56.240]  Поправится 39,309, правильно?
# [02:00.240 --> 02:02.240]  Да, да, да.
# [02:02.240 --> 02:04.240]  Андрей, смотрите.
# [02:04.240 --> 02:08.240]  Вы мне подскажите пожалуйста, можно я вам сразу вопросы, которые вот входит?
# [02:08.240 --> 02:10.240]  Да, конечно.
# [02:10.240 --> 02:12.240]  Чем отличается вид на реку от ВАУ?
# [02:12.240 --> 02:14.240]  Сейчас, секунду.
# [02:14.240 --> 02:16.240]  ВАУ, вид на реку.
# [02:16.240 --> 02:18.240]  Сейчас, секунду.
# [02:18.240 --> 02:20.240]  ВАУ, вид на реку.
# [02:20.240 --> 02:22.240]  ВАУ, вид на реку.
# [02:22.320 --> 02:24.320]  Сейчас, секунду.
# [02:24.320 --> 02:26.320]  Задний за мной.
# [02:26.320 --> 02:28.320]  Алло.
# [02:28.320 --> 02:30.320]  Да, да.
# [02:30.320 --> 02:34.320]  Я говорю, у вас какие-то характеристики, красные написаны.
# [02:34.320 --> 02:36.320]  Вот на ней написано, вид на реку.
# [02:36.320 --> 02:40.320]  А допустим рядом есть какая-то ВАУ, вид на воду.
# [02:40.320 --> 02:42.320]  Это что такое?
# [02:42.320 --> 02:46.320]  Ну, что бы я скажу, никакой разницы нет.
# [02:46.320 --> 02:48.320]  Я не знаю, что такое написано на сайте.
# [02:48.320 --> 02:50.320]  ВАУ, вид на воду.
# [02:50.400 --> 02:52.400]  Вау, вид на реку.
# [02:52.400 --> 02:54.400]  Вит на город.
# [02:54.400 --> 02:56.400]  Очень высокие этажи.
# [02:56.400 --> 02:58.400]  Вид на все абсолютно.
# [02:58.400 --> 03:02.400]  Даже если рассмотреть так уже квартиру, чуть ниже этажами,
# [03:02.400 --> 03:04.400]  они есть такие варианты.
# [03:04.400 --> 03:08.400]  А эти этажи будут ничем не хуже, потому что впереди дома
# [03:08.400 --> 03:10.400]  они не будут.
# [03:10.400 --> 03:12.400]  И вон там есть, наверное, ванная квартира.
# [03:12.400 --> 03:14.400]  Но это не так.
# [03:14.400 --> 03:16.400]  Ванная квартира, вон там есть.
# [03:16.480 --> 03:20.480]  А эти этажи будут ничем не хуже, потому что впереди дома
# [03:20.480 --> 03:22.480]  они все гораздо ниже.
# [03:22.480 --> 03:24.480]  И никто и никогда не построит уже дома.
# [03:24.480 --> 03:26.480]  А вот этот очень важный вопрос.
# [03:26.480 --> 03:30.480]  Если смотришь на Генклайна, я вчера проезжал, вот такое
# [03:30.480 --> 03:32.480]  ощущение, что перед этим корпусом в первую очередь
# [03:32.480 --> 03:34.480]  тоже стоит 51-этажный дом.
# [03:34.480 --> 03:36.480]  Он не закрывается?
# [03:36.480 --> 03:38.480]  Там стоит 51-этажный дом, совершенно верно.
# [03:38.480 --> 03:40.480]  Но он стоит, скажем так, правее.
# [03:40.480 --> 03:44.480]  Если вы подходите к окну этой квартиры вашей и смотрите
# [03:44.560 --> 03:48.560]  вверх, то конечно, какую-то часть этого дома загородится.
# [03:48.560 --> 03:54.560]  Но в основном, 90% вида – это полный панорам откуда.
# [03:54.560 --> 03:58.560]  Да тут даже вид, ладно, он применюхается.
# [03:58.560 --> 04:00.560]  Основной вопрос такой, что ты к окну подходишь и не
# [04:00.560 --> 04:02.560]  смотришь в окна соседнего дома, правильно?
# [04:02.560 --> 04:04.560]  Нет, нет, нет, такого нет.
# [04:04.560 --> 04:08.560]  Знаете, сейчас в Человиннике строятся.
# [04:08.560 --> 04:10.560]  Я понимаю, что вы говорите.
# [04:10.560 --> 04:12.560]  Вы сначала разговоры сказали, что хотели бы квартиру
# [04:12.640 --> 04:14.640]  посмотреть.
# [04:14.640 --> 04:16.640]  Ну как посмотреть?
# [04:16.640 --> 04:20.640]  Я так понимаю, что корпус еще не построен?
# [04:20.640 --> 04:26.640]  В этом корпусе уже монолитная работа практически полностью завершена.
# [04:26.640 --> 04:28.640]  51-этажный дом уже полностью построен.
# [04:28.640 --> 04:32.640]  Сейчас идут работы по фасадам, по инженерии, внутри корпуса.
# [04:32.640 --> 04:34.640]  Деревь ставят и так далее.
# [04:34.640 --> 04:38.640]  Курицы же не запутаны, мы же не пойдем с вами на 1 этаж.
# [04:38.720 --> 04:42.720]  А я могу уточнить, какая ситуация.
# [04:42.720 --> 04:48.720]  Проход на стройку для клиентов и для нас самих запрещен.
# [04:48.720 --> 04:52.720]  Турецкие подрядчики достаточно строго к этому относятся.
# [04:52.720 --> 04:56.720]  Но у нас есть один день в неделе, это воскресенье.
# [04:56.720 --> 05:02.720]  В 12-го дня ровно мы собираем группу людей, клиентов,
# [05:02.720 --> 05:04.720]  кто хочет купить, кто-то уже купил квартиру и показываем
# [05:04.720 --> 05:06.720]  какие-то определенные квартиры.
# [05:06.800 --> 05:10.800]  Не всегда это квартиры, которые клиент желает.
# [05:10.800 --> 05:12.800]  Но чаще всего нам дается показать квартиры, которые
# [05:12.800 --> 05:14.800]  клиент хочет посмотреть.
# [05:14.800 --> 05:20.800]  Там есть строительный лифт, который может поднять
# [05:20.800 --> 05:22.800]  на 51-й этаж.
# [05:22.800 --> 05:24.800]  Возможно чуть ниже посмотрим.
# [05:24.800 --> 05:26.800]  В вид будет не по чему.
# [05:26.800 --> 05:30.800]  Там остановили, чтобы глаза в этот дом не упирались.
# [05:30.800 --> 05:34.800]  Я понял, что это главный вопрос.
# [05:34.880 --> 05:36.880]  Я сейчас пришлю свою визитку.
# [05:36.880 --> 05:38.880]  Примем имя и имя.
# [05:38.880 --> 05:42.880]  Завтра нужно будет приехать к нам в 12-ти часах.
# [05:42.880 --> 05:48.880]  В 12-05 наш коллега на стройку уже клиентов уволит.
# [05:48.880 --> 05:52.880]  Сколько человек будет?
# [05:52.880 --> 05:54.880]  Я не знаю.
# [05:54.880 --> 05:56.880]  Женой вдвоем приедем.
# [05:56.880 --> 06:00.880]  Мне нужно будет для того, чтобы заказать для вас
# [06:00.880 --> 06:02.880]  пропуск для прохода на стройку ваших фамилий и имени.
# [06:02.960 --> 06:06.960]  Которые будут на объекте.
# [06:06.960 --> 06:08.960]  Котов Андрей Владимирович.
# [06:08.960 --> 06:10.960]  Сейчас.
# [06:10.960 --> 06:12.960]  Секунду.
# [06:20.960 --> 06:22.960]  Котов Андрей Владимирович.
# [06:22.960 --> 06:24.960]  Да.
# [06:24.960 --> 06:28.960]  И соответственно Котова Наталья Крустантиновна.
# [06:29.040 --> 06:33.040]  Я сейчас на WhatsApp напишу.
# [06:33.040 --> 06:35.040]  Завтра.
# [06:35.040 --> 06:39.040]  А можно я вас в общий помучаю?
# [06:39.040 --> 06:41.040]  Да.
# [06:41.040 --> 06:43.040]  Вот смотрите.
# [06:43.040 --> 06:45.040]  Эта квартира 341.
# [06:45.040 --> 06:49.040]  Она у нее стоит 496 400 рублей.
# [06:49.040 --> 06:51.040]  А даже нет.
# [06:51.040 --> 06:53.040]  Не так прошло.
# [06:53.120 --> 06:55.120]  Эта квартира 341.
# [06:55.120 --> 06:59.120]  С отчисткой стоит 33412 000.
# [06:59.120 --> 07:03.120]  А вот соседняя 341.
# [07:03.120 --> 07:07.120]  Соседняя 341.
# [07:07.120 --> 07:11.120]  Она больше площади.
# [07:11.120 --> 07:15.120]  Там площадь больше.
# [07:15.120 --> 07:17.120]  Там 2 метра.
# [07:17.120 --> 07:21.120]  А вот эта квартира.
# [07:21.200 --> 07:23.200]  Там 2 метра.
# [07:23.200 --> 07:25.200]  Понял.
# [07:25.200 --> 07:29.200]  Ну, давайте мы ее.
# [07:29.200 --> 07:33.200]  Подскажите, по оплате.
# [07:33.200 --> 07:37.200]  Возможно ипотека.
# [07:37.200 --> 07:39.200]  У нас есть свой.
# [07:39.200 --> 07:43.200]  Мне бы было максимально комфортно.
# [07:43.200 --> 07:47.200]  Я бы миллионов 20-25 заплатил сейчас.
# [07:47.280 --> 07:51.280]  Основная рассрочка.
# [07:51.280 --> 07:55.280]  До Нового года я бы внес.
# [07:55.280 --> 07:59.280]  Могу в течение месяца полутора.
# [07:59.280 --> 08:03.280]  По рассрочке мы особо не даем.
# [08:03.280 --> 08:07.280]  Если даем, то минимальный.
# [08:07.280 --> 08:11.280]  Но в чём не того, какие вы цифры озвучиваете.
# [08:11.280 --> 08:15.280]  Я думаю, что мы согласуем полный дискон.
# [08:15.360 --> 08:19.360]  Я могу вам подизнало заплатить компанию.
# [08:19.360 --> 08:23.360]  Но вы сами отходите.
# [08:23.360 --> 08:25.360]  Понял.
# [08:25.360 --> 08:29.360]  Давайте будем обсудать в члене рассрочки.
# [08:29.360 --> 08:33.360]  Последний вопрос.
# [08:33.360 --> 08:37.360]  Не совсем понимаю.
# [08:37.360 --> 08:41.360]  Плохое у меня пространственное мышление.
# [08:41.360 --> 08:43.360]  Под этим домом паркинг есть?
# [08:43.440 --> 08:45.440]  Да.
# [08:45.440 --> 08:49.440]  На лифте можно будет спуститься.
# [08:49.440 --> 08:53.440]  Но у нас будет мобильный парк.
# [08:53.440 --> 08:57.440]  Давайте хорошо.
# [08:57.440 --> 08:59.440]  У вас проблем нет?
# [08:59.440 --> 09:01.440]  Вы на машине приедете?
# [09:01.440 --> 09:03.440]  Конечно.
# [09:03.440 --> 09:07.440]  Я вам скину адрес продажи.
# [09:07.440 --> 09:11.440]  Вы не подъедете к шагбауму.
# [09:11.520 --> 09:15.520]  Я позвоню охранникам.
# [09:15.520 --> 09:17.520]  Они вам откроют.
# [09:17.520 --> 09:19.520]  А дальше я вам объясню, куда поставить машину.
# [09:19.520 --> 09:21.520]  Хорошо договорились.
# [09:21.520 --> 09:23.520]  Спасибо.
# [09:23.520 --> 09:25.520]  До связи.
#  Здравствуйте, вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании Cartros, Татьяна, здравствуйте. Алло, Татьяна, здравствуйте. Как мне с вами из вашего отдела продаж что-то поговорить? Что-то у вас квартиру купить, право надо еще заслужить, я так понял, да? Я вас соединю тогда с менеджером. Минута осталось 15 минут. Андрей, здравствуйте, мне тут Антон слушает вас. Всем могу помочь? Да, Антон, здравствуйте. А мне бы на самом деле посмотреть квартиру. И наверное, по крайней мере, она нам нравится. Пару вопросов по ней задать. Да, какая квартира, Андрей? Сейчас скажу. Вот смотрите, я в фильтрах выбираю двухкомнатную она. На 51 этаже. Сейчас скажу ее номер. Номер. Да, либо номер. 341, 67 метров которая. Так, сейчас секундочку, Андрей. Поправится 39,309, правильно? Да, да, да. Андрей, смотрите. Вы мне подскажите пожалуйста, можно я вам сразу вопросы, которые вот входит? Да, конечно. Чем отличается вид на реку от ВАУ? Сейчас, секунду. ВАУ, вид на реку. Сейчас, секунду. ВАУ, вид на реку. ВАУ, вид на реку. Сейчас, секунду. Задний за мной. Алло. Да, да. Я говорю, у вас какие-то характеристики, красные написаны. Вот на ней написано, вид на реку. А допустим рядом есть какая-то ВАУ, вид на воду. Это что такое? Ну, что бы я скажу, никакой разницы нет. Я не знаю, что такое написано на сайте. ВАУ, вид на воду. Вау, вид на реку. Вит на город. Очень высокие этажи. Вид на все абсолютно. Даже если рассмотреть так уже квартиру, чуть ниже этажами, они есть такие варианты. А эти этажи будут ничем не хуже, потому что впереди дома они не будут. И вон там есть, наверное, ванная квартира. Но это не так. Ванная квартира, вон там есть. А эти этажи будут ничем не хуже, потому что впереди дома они все гораздо ниже. И никто и никогда не построит уже дома. А вот этот очень важный вопрос. Если смотришь на Генклайна, я вчера проезжал, вот такое ощущение, что перед этим корпусом в первую очередь тоже стоит 51-этажный дом. Он не закрывается? Там стоит 51-этажный дом, совершенно верно. Но он стоит, скажем так, правее. Если вы подходите к окну этой квартиры вашей и смотрите вверх, то конечно, какую-то часть этого дома загородится. Но в основном, 90% вида – это полный панорам откуда. Да тут даже вид, ладно, он применюхается. Основной вопрос такой, что ты к окну подходишь и не смотришь в окна соседнего дома, правильно? Нет, нет, нет, такого нет. Знаете, сейчас в Человиннике строятся. Я понимаю, что вы говорите. Вы сначала разговоры сказали, что хотели бы квартиру посмотреть. Ну как посмотреть? Я так понимаю, что корпус еще не построен? В этом корпусе уже монолитная работа практически полностью завершена. 51-этажный дом уже полностью построен. Сейчас идут работы по фасадам, по инженерии, внутри корпуса. Деревь ставят и так далее. Курицы же не запутаны, мы же не пойдем с вами на 1 этаж. А я могу уточнить, какая ситуация. Проход на стройку для клиентов и для нас самих запрещен. Турецкие подрядчики достаточно строго к этому относятся. Но у нас есть один день в неделе, это воскресенье. В 12-го дня ровно мы собираем группу людей, клиентов, кто хочет купить, кто-то уже купил квартиру и показываем какие-то определенные квартиры. Не всегда это квартиры, которые клиент желает. Но чаще всего нам дается показать квартиры, которые клиент хочет посмотреть. Там есть строительный лифт, который может поднять на 51-й этаж. Возможно чуть ниже посмотрим. В вид будет не по чему. Там остановили, чтобы глаза в этот дом не упирались. Я понял, что это главный вопрос. Я сейчас пришлю свою визитку. Примем имя и имя. Завтра нужно будет приехать к нам в 12-ти часах. В 12-05 наш коллега на стройку уже клиентов уволит. Сколько человек будет? Я не знаю. Женой вдвоем приедем. Мне нужно будет для того, чтобы заказать для вас пропуск для прохода на стройку ваших фамилий и имени. Которые будут на объекте. Котов Андрей Владимирович. Сейчас. Секунду. Котов Андрей Владимирович. Да. И соответственно Котова Наталья Крустантиновна. Я сей ...

# %% [markdown]
# ### Семплированная выборка из датасета

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка сводного датафрейма
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/media108.ru/Датафреймы/rookie_total_df.csv')
df.shape
# Out:
# (23386, 77)

# %%
# Выбор необходимых столбцов
df = df[['Статус',
         'Тип',
         'Сайт',
         'Тип посетителя',
         'Сценарий',
         'Операции',
         'Тип устройства',
         'Первая рекламная кампания',
         'Чистая длительность разговора',
         'Номер обращения',
         'ID посетителя',
         'Идентификатор сессии звонка',
         'Файл записи звонка',
         'Класс',
         'Проект']][df['Файл записи звонка'] != 'нет файла'].sample(5)
df.shape
# Out:
# (5, 15)

# %%
df
# Out:
#          Статус               Тип              Сайт Тип посетителя  \
# 3763   Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21030  Принятый         Аналитика  primavera.moscow    Не заполнен
# 20109  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21952  Принятый  Звонки из VK Ads        pavcity.ru          Новый
# 7322   Принятый       Звонок ВАТС  primavera.moscow    Не заполнен
#
#                     Сценарий  \
# 3763                 Кортрос
# 21030  Обработка вызова 2023
# 20109                Кортрос
# 21952             ОЗ (SIP<1)
# 7322   Обработка вызова 2023
#
#                                                 Операции Тип устройства  \
# 3763                                     Переадресация 1         Прочее
# 21030                   Интерактивная обработка вызова 1         Прочее
# 20109                                    Переадресация 1         Прочее
# 21952                      Переадресация на сотрудника 1         Прочее
# 7322   Интерактивная обработка вызова 1, Интерактивна...         Прочее
#
#                           Первая рекламная кампания  \
# 3763              Посетители без рекламной кампании
# 21030             Посетители без рекламной кампании
# 20109             Посетители без рекламной кампании
# 21952  Media108 | Павелецкая Сити | social | VK Ads
# 7322              Посетители без рекламной кампании
#
#       Чистая длительность разговора  Номер обращения  ID посетителя  \
# 3763                       00:14:15                1              0
# 21030                      00:00:34                1              0
# 20109                      00:01:05                1              0
# 21952                      00:00:17                2     7558036959
# 7322                       00:02:16                1              0
#
#        Идентификатор сессии звонка  \
# 3763                    3083061142
# 21030                   3230957576
# 20109                   3251357547
# 21952                   3160197614
# 7322                    3075218173
#
#                                       Файл записи звонка       Класс  \
# 3763   Записи звонков/Записи звонков_хедлайнер/2023-0...     Целевой
# 21030  Новые записи звонков/Записи Primavera/2023-09-...     Целевой
# 20109  Новые записи звонков/Записи Headliner/2023-09-...  Нецелевой
# 21952  Новые записи звонков/Записи Павелецкая сити/20...  Нецелевой
# 7322   Записи звонков/Записи звонков_primavera/2023-0...  Нецелевой
#
#                   Проект
# 3763           Headliner
# 21030          Primavera
# 20109          Headliner
# 21952  Paveletskaya_city
# 7322           Primavera

# %%
# Добавление столбца 'ID проекта'
df['ID проекта'] = 0
df.loc[df[df['Проект'] == 'Headliner'].index, 'ID проекта'] = 1
df.loc[df[df['Проект'] == 'Primavera'].index, 'ID проекта'] = 2

# %%
# Очистка от '{}' значений столбца 'Тип посетителя'
df['Тип посетителя'] = df['Тип посетителя'].apply(lambda x: x.strip('{}'))

# %%
# Очистка от '{}' значений столбца 'Первая рекламная кампания'
df['Первая рекламная кампания'] = df['Первая рекламная кампания'].apply(lambda x: x.strip('{}'))

# %%
# Переводим значения столбца 'Чистая длительность разговора' в количество секунд
df['Чистая длительность разговора'] = pd.to_datetime(df['Чистая длительность разговора']).dt.time
df['Чистая длительность разговора'] = df['Чистая длительность разговора'].apply(lambda x: x.hour*60*60 + x.minute*60 + x.second)

# %%
# Типы данных
df.dtypes
# Out:
# Статус                           object
# Тип                              object
# Сайт                             object
# Тип посетителя                   object
# Сценарий                         object
# Операции                         object
# Тип устройства                   object
# Первая рекламная кампания        object
# Чистая длительность разговора     int64
# Номер обращения                   int64
# ID посетителя                     int64
# Идентификатор сессии звонка       int64
# Файл записи звонка               object
# Класс                            object
# Проект                           object
# ID проекта                        int64
# dtype: object

# %%
df
# Out:
#          Статус               Тип              Сайт Тип посетителя  \
# 3763   Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21030  Принятый         Аналитика  primavera.moscow    Не заполнен
# 20109  Принятый       Звонок ВАТС     head-liner.ru    Не заполнен
# 21952  Принятый  Звонки из VK Ads        pavcity.ru          Новый
# 7322   Принятый       Звонок ВАТС  primavera.moscow    Не заполнен
#
#                     Сценарий  \
# 3763                 Кортрос
# 21030  Обработка вызова 2023
# 20109                Кортрос
# 21952             ОЗ (SIP<1)
# 7322   Обработка вызова 2023
#
#                                                 Операции Тип устройства  \
# 3763                                     Переадресация 1         Прочее
# 21030                   Интерактивная обработка вызова 1         Прочее
# 20109                                    Переадресация 1         Прочее
# 21952                      Переадресация на сотрудника 1         Прочее
# 7322   Интерактивная обработка вызова 1, Интерактивна...         Прочее
#
#                           Первая рекламная кампания  \
# 3763              Посетители без рекламной кампании
# 21030             Посетители без рекламной кампании
# 20109             Посетители без рекламной кампании
# 21952  Media108 | Павелецкая Сити | social | VK Ads
# 7322              Посетители без рекламной кампании
#
#        Чистая длительность разговора  Номер обращения  ID посетителя  \
# 3763                             855                1              0
# 21030                             34                1              0
# 20109                             65                1              0
# 21952                             17                2     7558036959
# 7322                             136                1              0
#
#        Идентификатор сессии звонка  \
# 3763                    3083061142
# 21030                   3230957576
# 20109                   3251357547
# 21952                   3160197614
# 7322                    3075218173
#
#                                       Файл записи звонка       Класс  \
# 3763   Записи звонков/Записи звонков_хедлайнер/2023-0...     Целевой
# 21030  Новые записи звонков/Записи Primavera/2023-09-...     Целевой
# 20109  Новые записи звонков/Записи Headliner/2023-09-...  Нецелевой
# 21952  Новые записи звонков/Записи Павелецкая сити/20...  Нецелевой
# 7322   Записи звонков/Записи звонков_primavera/2023-0...  Нецелевой
#
#                   Проект  ID проекта
# 3763           Headliner           1
# 21030          Primavera           2
# 20109          Headliner           1
# 21952  Paveletskaya_city           0
# 7322           Primavera           2

# %%
# Сохранение датафрейма
df.to_csv('/content/drive/MyDrive/media108.ru/Датафреймы/test_data_df.csv', index=False)

# %%
# Сохранение в json
df.to_json('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json', orient='records', force_ascii=False)

# %%
# !cat /content/drive/MyDrive/media108.ru/Датафреймы/test_data.json
# Out:
# [{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":855,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3083061142,"Файл записи звонка":"Записи звонков\/Записи звонков_хедлайнер\/2023-07-11_16-18-51.610373_from_79263731436_to_0188880_session_3083061142_talk.mp3","Класс":"Целевой","Проект":"Headliner","ID проекта":1},{"Статус":"Принятый","Тип":"Аналитика","Сайт":"primavera.moscow","Тип посетителя":"Не заполнен","Сценарий":"Обработка вызова 2023","Операции":"Интерактивная обработка вызова 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":34,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3230957576,"Файл записи звонка":"Новые записи звонков\/Записи Primavera\/2023-09-17_11-31-57.762274_from_79165225772_to_0150113_session_3230957576_talk.mp3","Класс":"Целевой","Проект":"Primavera","ID проекта":2},{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":65,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3251357547,"Файл записи звонка":"Новые записи звонков\/Записи Headliner\/2023-09-23_11-26-10.992586_from_79657535970_to_0188880_session_3251357547_talk.mp3","Класс":"Нецелевой","Проект":"Headliner","ID проекта":1},{"Статус":"Принятый","Тип":"Звонки из VK Ads","Сайт":"pavcity.ru","Тип посетителя":"Новый","Сценарий":"ОЗ (SIP<1)","Операции":"Переадресация на сотрудника 1","Тип устройства":"Прочее","Первая рекламная кампания":"Media108 | Павелецкая Сити | social | VK Ads","Чистая длительность разговора":17,"Номер обращения":2,"ID посетителя":7558036959,"Идентификатор сессии звонка":3160197614,"Файл записи звонка":"Новые записи звонков\/Записи Павелецкая сити\/2023-08-17_09-06-57.786310_from_74950326372_to_00288_session_3160197614_talk.mp3","Класс":"Нецелевой","Проект":"Paveletskaya_city","ID проекта":0},{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"primavera.moscow","Тип посетителя":"Не заполнен","Сценарий":"Обработка вызова 2023","Операции":"Интерактивная обработка вызова 1, Интерактивная обработка вызова 2","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":136,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3075218173,"Файл записи звонка":"Записи звонков\/Записи звонков_primavera\/2023-07-08_17-45-47.596023_from_79778947224_to_0111639_session_3075218173_talk.mp3","Класс":"Нецелевой","Проект":"Primavera","ID проекта":2}]

# %% [markdown]
# ### API (`upload` `json`)

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import pandas as pd
from io import BytesIO
from fastapi import FastAPI, File

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):
  df = pd.read_json(BytesIO(json_file))
  return {'result': str(df.shape)}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2480] using StatReload
# INFO:     Started server process [2482]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import requests
files = {'json_file': open('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
# Out:
# {"result":"(5, 16)"}

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2480] using StatReload
# INFO:     Started server process [2482]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:35698 - "POST /predict HTTP/1.1" 200 OK

# %% [markdown]
# ### `Whisper`-транскрибация записей звонков из `json`-файла

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 103.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 16.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import pandas as pd
df = pd.read_json('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json')
df.shape
# Out:
# (5, 16)

# %%
import whisper
whisper_model = whisper.load_model('medium')
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:20<00:00, 75.6MiB/s]

# %%
'/content/drive/MyDrive/media108.ru/Датасет/' + df.loc[0,'Файл записи звонка']
# Out:
# '/content/drive/MyDrive/media108.ru/Датасет/Записи звонков/Записи звонков_хедлайнер/2023-07-11_16-18-51.610373_from_79263731436_to_0188880_session_3083061142_talk.mp3'

# %%
for i in range(df.shape[0]):
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe('/content/drive/MyDrive/media108.ru/Датасет/' + df.loc[i,'Файл записи звонка'], language='ru')['text']

# %%
df['Транскрибация файла записи звонка']
# Out:
# 0     Здравствуйте, вы позвонили в группу компании ...
# 1     Я пришла к вам в МАР и меня зовут Люля. Добры...
# 2     Здравствуйте, вы позвонили в группу компании ...
# 3     – Здравствуйте, это компания «Мэргрупп». Меня...
# 4     Здравствуйте. Кловный город на реке Примаверо...
# Name: Транскрибация файла записи звонка, dtype: object

# %%
df.to_json('/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json', orient='records', force_ascii=False)

# %%
# !cat '/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json'
# Out:
# [{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":855,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3083061142,"Файл записи звонка":"Записи звонков\/Записи звонков_хедлайнер\/2023-07-11_16-18-51.610373_from_79263731436_to_0188880_session_3083061142_talk.mp3","Класс":"Целевой","Проект":"Headliner","ID проекта":1,"Транскрибация файла записи звонка":" Здравствуйте, вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании Cartros, Тащиану, здравствуйте. Тащиан, а добрый день. На линии клиент Анна, хедлайнер 4-комнатная, бюджет 47 максимум. Возьмите звоночек. Да, спасибо, сахиба, ты, Тащиан. Алло, Анна, здравствуйте, меня зовут Влада, менеджер отдела продаж, что я могу помочь вам? Меня интересует квартира в жк хедлайнер Кросс. Кросс, или как правильно? Кортрос. Да, Нитрос или Пиха. Да, на вознагонном положении. Да, это я уже посмотрела, для меня это все понятно. У меня такие вопросы. Смотрите, квартиру я вижу в мой бюджет до 47 миллионов. Я купить хочу ее быстрее, чем быстрее, тем лучше, потому что деньги надо вложить. Естественно, хочется переехать тоже побыстрее. Сейчас я разговаривала с менеджером, не знаю, кто она, с кем является, но говорят, там будет только вторая квартира в 2024 году. Нет, у нас в таком бюджете есть квартира уже в данном доме по 100 метров. Да, я это увидела, здесь она есть, 14 этаж, 99,48, квартира 32. Да, вы даже можете приехать в нее зайти, посмотреть, она готовая. Она готовая, я могу туда ехать, я приобретаю, я могу туда заселяться, правильно? Конечно. Не, не, не, дома у вас там был кассе прошлого года. Просто мне так говорят, что этого делать не могу. Ага, ну может быть, до новенький оператор не могу вам точно сказать, почему так сообщили вам. Нет, дом там, квартира готова, приезжайте в офис, посмотрите ее вживую. Это я приеду посмотрю. Дело в том, что меня интересует такой вопрос. Что-то посмотрела, там идет еще стройка за стройка. У меня два маленьких ребенка. Два и четыре года. Получается, мне нужен сад и сейчас уже в ближайшее время, там, к течение двух лет, нужен будет уже первый класс. Поэтому меня интересует, что там имеется в этом комплексе вообще, в самом комплексе. Как он там располагается, не располагается, не будет ли это, что у меня дети там бесходные, по площадке бегают, а в тройку где-то идет? Смотрите, у нас в рамках нашего комплекса построена частная школа. Детский сад тоже построен, но пока что не эксплуатируется. Это будет частный детский сад. В следующем году его планируют ввести уже в эксплуатацию. А пока, если говорить о детском саде, буквально в двух минутах есть муниципальный детский сад. Государственный. А частный, это получается, в чем это будет заключаться в частности? Муниципальный, я бы хотела для своего района, хотела бы свой сад, чтобы не стоять ни в каком очереди, ничего не бегать, ничего не бегать. Просто частный, там, ну, как правило, стоимость внестися подороже, чем в государственные. Ну, это я в курсе, что это я в курсе. Не получится так, чтобы государственные сейчас народ поплывет, и внестись не останется. Ну, здесь детский сад, если мы говорим про именную шаговую доступность, он один. Но, я не знаю, если вы на автомобиле готовы перебегаться тут, 5 минут максимум езды, 5-10 минут, много детских садов в округе. Просто наш частный детский сад, он будет готов только в следующем году. Поэтому я вас не хочу вводить в воздушные. Да, да, да. А нам уже хочется выпускаться от мамы с детей. Я вас туда хочу более актуальную информацию все-таки предоставлять. Поэтому либо муниципальный, либо дождаться детский сад, который будет у нас готов, либо нужно будет проехаться на машине все-таки. Так, какая-то кое-что вопрос. По поводу стройки, что там? По поводу стройки у нас высокая сте ...

# %% [markdown]
# ### API (`whisper`-транскрибация записей звонков из `json`-файла)

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 75.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 8.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Установка дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 6.9 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import whisper
import pandas as pd
from io import BytesIO
from fastapi import FastAPI, File

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):
  df = pd.read_json(BytesIO(json_file))
  whisper_model = whisper.load_model('medium')
  for i in range(df.shape[0]):
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe('/content/drive/MyDrive/media108.ru/Датасет/' + df.loc[i,'Файл записи звонка'], language='ru')['text']
  df.to_json('/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json', orient='records', force_ascii=False)
  return {'result': '/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json'}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1860] using StatReload

# %%
import requests
files = {'json_file': open('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
# Out:
# {"result":"/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json"}

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1860] using StatReload
# INFO:     Started server process [1862]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 93.2MiB/s]
# INFO:     127.0.0.1:37834 - "POST /predict HTTP/1.1" 200 OK

# %%
# !cat '/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json'
# Out:
# [{"Статус":"Принятый","Тип":"Звонок ВАТС","Сайт":"head-liner.ru","Тип посетителя":"Не заполнен","Сценарий":"Кортрос","Операции":"Переадресация 1","Тип устройства":"Прочее","Первая рекламная кампания":"Посетители без рекламной кампании","Чистая длительность разговора":855,"Номер обращения":1,"ID посетителя":0,"Идентификатор сессии звонка":3083061142,"Файл записи звонка":"Записи звонков\/Записи звонков_хедлайнер\/2023-07-11_16-18-51.610373_from_79263731436_to_0188880_session_3083061142_talk.mp3","Класс":"Целевой","Проект":"Headliner","ID проекта":1,"Транскрибация файла записи звонка":" Здравствуйте, вы позвонили в группу компании Cartros. Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании Cartros, Тащиану, здравствуйте. Тащиан, а добрый день. На линии клиент Анна, хедлайнер 4-комнатная, бюджет 47 максимум. Возьмите звоночек. Да, спасибо, сахиба, ты, Тащиан. Алло, Анна, здравствуйте, меня зовут Влада, менеджер отдела продаж, что я могу помочь вам? Меня интересует квартира в жк хедлайнер Кросс. Кросс, или как правильно? Кортрос. Да, Нитрос или Пиха. Да, на вознагонном положении. Да, это я уже посмотрела, для меня это все понятно. У меня такие вопросы. Смотрите, квартиру я вижу в мой бюджет до 47 миллионов. Я купить хочу ее быстрее, чем быстрее, тем лучше, потому что деньги надо вложить. Естественно, хочется переехать тоже побыстрее. Сейчас я разговаривала с менеджером, не знаю, кто она, с кем является, но говорят, там будет только вторая квартира в 2024 году. Нет, у нас в таком бюджете есть квартира уже в данном доме по 100 метров. Да, я это увидела, здесь она есть, 14 этаж, 99,48, квартира 32. Да, вы даже можете приехать в нее зайти, посмотреть, она готовая. Она готовая, я могу туда ехать, я приобретаю, я могу туда заселяться, правильно? Конечно. Не, не, не, дома у вас там был кассе прошлого года. Просто мне так говорят, что этого делать не могу. Ага, ну может быть, до новенький оператор не могу вам точно сказать, почему так сообщили вам. Нет, дом там, квартира готова, приезжайте в офис, посмотрите ее вживую. Это я приеду посмотрю, дело в том, что меня интересует такой вопрос. Потому что я посмотрела, там идет еще стройка за стройка. У меня два маленьких ребенка, два и четыре года. Получается, мне нужен сад и сейчас уже в ближайшее время, там, в течение двух лет, нужен будет уже первый класс. Поэтому меня интересует, что там имеется в этом комплексе вообще, в самом комплексе. Как он там располагается, не располагается, не будет ли это, что у меня дети там бесходные, по площадке бегают, а в тройку где-то идет? Смотрите, у нас в рамках нашего комплекса построена частная школа. Детский сад тоже построен, но пока что не эксплуатируется. Это будет частный детский сад. В следующем году его планируют ввести уже в эксплуатацию. Пока, если говорить о детском саде, буквально в двух минутах есть муниципальный детский сад, государственный. А частный, это получается, в чем это будет заключаться в частности? Муниципальный, муниципальный, я бы хотела для своего района, хотела бы свой сад, чтобы у меня не стоять ни в какой очереди, ничего не бегать, ничего не бегать. Просто частный там, ну как правило, стоимость в месяц подороже, чем в государственных. Ну это я в курсе, что это я в курсе. Не получится так просто государственные, сейчас народ поплывет, и мест не останется. Ну здесь детский сад, если мы говорим про именную шаговую доступность, он один. Ну, если вы на автомобиле готовы перебегаться тут в пять минут максимум езды, пять-десять минут, много детских садов в округе. Просто наш частный детский сад будет готов только в следующем году. Не в этом сентябре, а в воздушные. Да, да, да. Да нам уже хочется выпускаться от мамой с детей. Нет, я вас туда хочу более актуальную информацию все-таки предоставлять. Поэтому либо муниципально, либо дождаться детский сад, который будет у нас готов, ну либо да, нужно будет проехаться на машине все-таки. Так, какая такое еще вопрос? По поводу стройки, что там? По поводу стройки ...

# %% [markdown]
# ### Классификация звонков из семплированной выборки (`medium`)

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 42.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 104.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 12.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Загрузка информации о звонках
import pandas as pd
df = pd.read_json('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json')
df.shape
# Out:
# (5, 16)

# %%
# Загрузка транскрибатора
import whisper
whisper_model = whisper.load_model('medium')
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:14<00:00, 103MiB/s]

# %%
# Транскрибация записей звонков
for i in range(df.shape[0]):
  df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe('/content/drive/MyDrive/media108.ru/Датасет/' + df.loc[i,'Файл записи звонка'], language='ru', beam_size=5, best_of=5)['text']

# %%
# Обработка транскрибации
import re
import numpy as np
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].fillna('безответа')
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: re.sub('[^А-Яа-я0-9 ]', '', s.lower()))
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: s.strip())
df['Транскрибация файла записи звонка'] = np.where(df['Транскрибация файла записи звонка'].str.len() < 5, 'безответа', df['Транскрибация файла записи звонка'])
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.replace('ё', 'е', regex=False)
df['Транскрибация файла записи звонка']
# Out:
# 0    здравствуйте вы позвонили в группу компании  б...
# 1    добрый день юлия я нахожусь рядом с вашим авиа...
# 2    здравствуйте вы позвонили в группу компании  б...
# 3    алло  здравствуйте я с компанией мэргрупп меня...
# 4    здравствуйте кловный город на реке примаверо м...
# Name: Транскрибация файла записи звонка, dtype: object

# %%
# Загрузка токенайзера
import pickle as pkl
with open('/content/drive/MyDrive/media108.ru/Модели/model9_2_tokenizer_txt.pkl', 'rb') as f:
  tokenizer_txt = pkl.load(f)

# %%
# Получение матрицы BOW
txt_list = df['Транскрибация файла записи звонка'].tolist()
txt_bow = tokenizer_txt.texts_to_matrix(txt_list)
txt_bow.shape
# Out:
# (5, 35000)

# %%
# Загрузка энкодеров
with open('/content/drive/MyDrive/media108.ru/Модели/model9_2_encoders.pkl', 'rb') as f:
  encoders = pkl.load(f)

# %%
# Получение матрицы ОНЕ
from tensorflow.keras import utils
col_to_ohe = ['Статус', 'Тип', 'Сайт', 'Тип посетителя', 'Сценарий', 'Операции', 'Тип устройства', 'Первая рекламная кампания']
df[col_to_ohe] = df[col_to_ohe].fillna('Нет данных')
list_code = []
for i in range(len(col_to_ohe)):
  encoder = encoders[col_to_ohe[i]]
  list_code.append(utils.to_categorical(encoder.transform(df[col_to_ohe[i]].tolist()), len(encoder.classes_)))
OHE_data = np.hstack(list_code)
OHE_data = OHE_data.astype('float32')
OHE_data.shape
# Out:
# (5, 175)

# %%
# Получение массива числовых данных
digit_col = ['Чистая длительность разговора', 'Номер обращения', 'ID посетителя']
df[digit_col] = df[digit_col].fillna(0)
df['ID посетителя'] = df['ID посетителя']/100000000 # понижение разрядности для более плавной нормализации
x_data = np.array(df[digit_col].values)
x_data = x_data.astype('float32')
max_val = x_data.max()
x_data = x_data/max_val
x_data.shape
# Out:
# (5, 3)

# %%
# Загрузка модели нейронной сети
from tensorflow.keras.saving import load_model
model = load_model('/content/drive/MyDrive/media108.ru/Модели/model9_2.h5')

# %%
# Предсказание классификации звонков
y_pred = model.predict({'input_x1':txt_bow,'input_x2':OHE_data,'input_x3':x_data}, batch_size=txt_bow.shape[0])
y_pred
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[0.88860464],
#        [0.15365793],
#        [0.3085338 ],
#        [0.01800289],
#        [0.56672794]], dtype=float32)

# %%
# Добавление в датафрейм столбца 'Предсказание класса'
for i in range(df.shape[0]):
  df.loc[i,'Предсказание класса'] = 'Целевой' if round(y_pred[i][0]) else 'Нецелевой'
df[['ID проекта', 'Проект', 'Класс', 'Предсказание класса']]
# Out:
#    ID проекта             Проект       Класс Предсказание класса
# 0           1          Headliner     Целевой             Целевой
# 1           2          Primavera     Целевой           Нецелевой
# 2           1          Headliner  Нецелевой           Нецелевой
# 3           0  Paveletskaya_city  Нецелевой           Нецелевой
# 4           2          Primavera  Нецелевой             Целевой

# %%
# Запись json-файла с предсказанием класса
df[['ID проекта', 'Проект', 'Класс', 'Предсказание класса']].to_json('/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json', orient='records', force_ascii=False)

# %%
# !cat '/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json'
# Out:
# [{"ID проекта":1,"Проект":"Headliner","Класс":"Целевой","Предсказание класса":"Целевой"},{"ID проекта":2,"Проект":"Primavera","Класс":"Целевой","Предсказание класса":"Нецелевой"},{"ID проекта":1,"Проект":"Headliner","Класс":"Нецелевой","Предсказание класса":"Нецелевой"},{"ID проекта":0,"Проект":"Paveletskaya_city","Класс":"Нецелевой","Предсказание класса":"Нецелевой"},{"ID проекта":2,"Проект":"Primavera","Класс":"Нецелевой","Предсказание класса":"Целевой"}]

# %% [markdown]
# ### Классификация звонков из семплированной выборки (`large`)

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Установка cohere openai tiktoken
# !pip -q install cohere openai tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 71.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 15.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Загрузка информации о звонках
import pandas as pd
df = pd.read_json('/content/drive/MyDrive/media108.ru/Датафреймы/test_data.json')
df.shape
# Out:
# (5, 16)

# %%
# Загрузка транскрибатора
import whisper
whisper_model = whisper.load_model('large')
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:36<00:00, 84.2MiB/s]

# %%
# Транскрибация записей звонков
for i in range(df.shape[0]):
  df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe('/content/drive/MyDrive/media108.ru/Датасет/' + df.loc[i,'Файл записи звонка'], language='ru', beam_size=5, best_of=5)['text']

# %%
# Обработка транскрибации
import re
import numpy as np
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].fillna('безответа')
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: re.sub('[^А-Яа-я0-9 ]', '', s.lower()))
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: s.strip())
df['Транскрибация файла записи звонка'] = np.where(df['Транскрибация файла записи звонка'].str.len() < 5, 'безответа', df['Транскрибация файла записи звонка'])
df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.replace('ё', 'е', regex=False)
df['Транскрибация файла записи звонка']
# Out:
# 0    здравствуйте вы позвонили в группу компании ка...
# 1                     субтитры сделал  субтитры сделал
# 2    здравствуйте вы позвонили в группу компании ка...
# 3    алло здравствуйте это компания мэр групп меня ...
# 4    здравствуйте клубный город на реке примавера м...
# Name: Транскрибация файла записи звонка, dtype: object

# %%
# Загрузка токенайзера
import pickle as pkl
with open('/content/drive/MyDrive/media108.ru/Модели/model9_2_tokenizer_txt.pkl', 'rb') as f:
  tokenizer_txt = pkl.load(f)

# %%
# Получение матрицы BOW
txt_list = df['Транскрибация файла записи звонка'].tolist()
txt_bow = tokenizer_txt.texts_to_matrix(txt_list)
txt_bow.shape
# Out:
# (5, 35000)

# %%
# Загрузка энкодеров
with open('/content/drive/MyDrive/media108.ru/Модели/model9_2_encoders.pkl', 'rb') as f:
  encoders = pkl.load(f)

# %%
# Получение матрицы ОНЕ
from tensorflow.keras import utils
col_to_ohe = ['Статус', 'Тип', 'Сайт', 'Тип посетителя', 'Сценарий', 'Операции', 'Тип устройства', 'Первая рекламная кампания']
df[col_to_ohe] = df[col_to_ohe].fillna('Нет данных')
list_code = []
for i in range(len(col_to_ohe)):
  encoder = encoders[col_to_ohe[i]]
  list_code.append(utils.to_categorical(encoder.transform(df[col_to_ohe[i]].tolist()), len(encoder.classes_)))
OHE_data = np.hstack(list_code)
OHE_data = OHE_data.astype('float32')
OHE_data.shape
# Out:
# (5, 175)

# %%
# Получение массива числовых данных
digit_col = ['Чистая длительность разговора', 'Номер обращения', 'ID посетителя']
df[digit_col] = df[digit_col].fillna(0)
df['ID посетителя'] = df['ID посетителя']/100000000 # понижение разрядности для более плавной нормализации
x_data = np.array(df[digit_col].values)
x_data = x_data.astype('float32')
max_val = x_data.max()
x_data = x_data/max_val
x_data.shape
# Out:
# (5, 3)

# %%
# Загрузка модели нейронной сети
from tensorflow.keras.saving import load_model
model = load_model('/content/drive/MyDrive/media108.ru/Модели/model9_2.h5')

# %%
# Предсказание классификации звонков
y_pred = model.predict({'input_x1':txt_bow,'input_x2':OHE_data,'input_x3':x_data}, batch_size=txt_bow.shape[0])
y_pred
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[0.9190417 ],
#        [0.06179652],
#        [0.0580783 ],
#        [0.05579747],
#        [0.60567665]], dtype=float32)

# %%
# Добавление в датафрейм столбца 'Предсказание класса'
for i in range(df.shape[0]):
  df.loc[i,'Предсказание класса'] = 'Целевой' if round(y_pred[i][0]) else 'Нецелевой'
df[['ID проекта', 'Проект', 'Класс', 'Предсказание класса']]
# Out:
#    ID проекта             Проект       Класс Предсказание класса
# 0           1          Headliner     Целевой             Целевой
# 1           2          Primavera     Целевой           Нецелевой
# 2           1          Headliner  Нецелевой           Нецелевой
# 3           0  Paveletskaya_city  Нецелевой           Нецелевой
# 4           2          Primavera  Нецелевой             Целевой

# %%
# Запись json-файла с предсказанием класса
df[['ID проекта', 'Проект', 'Класс', 'Предсказание класса']].to_json('/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json', orient='records', force_ascii=False)

# %%
# !cat '/content/drive/MyDrive/media108.ru/Датафреймы/predict_test_data.json'
# Out:
# [{"ID проекта":1,"Проект":"Headliner","Класс":"Целевой","Предсказание класса":"Целевой"},{"ID проекта":2,"Проект":"Primavera","Класс":"Целевой","Предсказание класса":"Нецелевой"},{"ID проекта":1,"Проект":"Headliner","Класс":"Нецелевой","Предсказание класса":"Нецелевой"},{"ID проекта":0,"Проект":"Paveletskaya_city","Класс":"Нецелевой","Предсказание класса":"Нецелевой"},{"ID проекта":2,"Проект":"Primavera","Класс":"Нецелевой","Предсказание класса":"Целевой"}]

# %% [markdown]
# ## Демонстрация интеграции в `prod`

# %% [markdown]
# ### head-liner.ru

# %%
# Загрузка токенайзера
import gdown
url = 'https://drive.google.com/file/d/1Pjsm9ozkoouo_znt--4J4t_bJW9ZJoMe/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2_tokenizer_txt.pkl'

# %%
# Загрузка энкодеров
url = 'https://drive.google.com/file/d/1-3KOQpN1gtKmaNcwCvAHdK6NtMVxPOKu/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2_encoders.pkl'

# %%
# Загрузка модели нейронной сети
url = 'https://drive.google.com/file/d/10PbDY-XLNV7CM-xRu5fvN3ziD0s3Qs1p/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2.h5'

# %%
# Загрузка информации о звонках
import pandas as pd
url = 'https://drive.google.com/file/d/1A3iuMNcDI_J7BlNvERDlmj90WMvMcPcR/view?usp=drive_link'
df = pd.read_csv('https://drive.google.com/uc?id=' + url.split('/')[-2],
                 skiprows=4,
                 sep=';',
                 on_bad_lines='skip')
df.shape
# Out:
# (4752, 72)

# %%
# Загрузка записей звонков
url = 'https://drive.google.com/drive/folders/1ynAu-3i0f1tS6UGqapmPGDFcJZLoCrAQ?usp=drive_link'
gdown.download_folder(url, quiet=True, remaining_ok=True)
# Out:
# ['/content/Записи звонков_хедлайнер/2023-05-08_10-41-56.911054_from_79250817178_to_74959339929_session_2928050751_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_11-43-52.513973_from_79827693228_to_0188880_session_2937971588_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_12-34-46.730988_from_79622801999_to_0188880_session_2928807121_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_12-35-55.567230_from_79622801999_to_0188880_session_2938080128_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_12-51-38.868213_from_74997040921_to_0188880_session_2928283255_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_13-50-28.475837_from_79279152761_to_79191089861_session_2928935657_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_13-52-16.157543_from_79279152761_to_79191089861_session_2928938049_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_14-16-30.536713_from_79261116646_to_0188880_session_2928975097_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_14-47-04.517454_from_79282143214_to_0188880_session_2938333136_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_16-14-10.247769_from_74955199580_to_74997552563_session_2918538922_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-08_18-50-13.838052_from_74954174271_to_0188880_session_2929370545_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_10-32-18.366336_from_79508730557_to_0188880_session_2939148092_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_11-53-48.291185_from_79910665524_to_74997552563_session_2919161802_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_12-17-32.617113_from_79064011000_to_74959339902_session_2929311247_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_13-10-50.367190_from_74992419775_to_0188880_session_2929372379_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_13-58-58.773808_from_79823830002_to_74997552563_session_2939439048_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_14-30-38.161392_from_79096321475_to_74957898990_session_2929465891_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_14-50-18.968938_from_79777980969_to_74957898990_session_2939506208_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_16-37-17.090565_from_79274430921_to_0188880_session_2939644136_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_16-55-59.935127_from_79274430921_to_0188880_session_2929623235_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_17-03-41.886158_from_79258813188_to_0188880_session_2930211973_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_17-37-05.805616_from_79274431194_to_0188880_session_2939712644_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_17-39-02.495114_from_79031412453_to_74997552563_session_2930249245_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_17-51-30.193682_from_79670165153_to_0188880_session_2919520238_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_18-34-04.371381_from_79274431546_to_74997552563_session_2919550530_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-09_20-19-21.050197_from_79274432048_to_74997552563_session_2919615074_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_09-46-49.632110_from_79115639000_to_0188880_session_2930217007_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_10-09-17.271771_from_79663447052_to_0188880_session_2920087786_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_10-45-26.907399_from_79639641553_to_0188880_session_2920207590_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_10-57-09.082275_from_79633409369_to_74957898990_session_2920243890_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_10-58-13.824596_from_79336668096_to_74957898990_session_2931066829_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_11-35-13.054375_from_79167542257_to_74997552563_session_2931126469_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_11-56-49.809252_from_79639641553_to_0188880_session_2940892544_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_12-04-01.602916_from_79264597706_to_0188880_session_2930744767_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_12-18-13.490067_from_79268458847_to_0188880_session_2931380841_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_12-29-50.389904_from_79160640610_to_74959339902_session_2930835239_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_12-30-44.828361_from_79261991702_to_0188880_session_2930842543_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_12-45-52.597185_from_79262946005_to_74959339929_session_2931495869_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_13-33-11.389371_from_79857216036_to_79154084359_session_2931067143_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_13-36-53.604277_from_79857216036_to_79191089861_session_2941298624_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_14-39-40.846623_from_79256261275_to_0188880_session_2920974222_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_14-41-41.751866_from_79035679376_to_79191089861_session_2941565172_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_14-45-40.026570_from_79823830002_to_74997552563_session_2920990562_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_14-54-56.479785_from_79264597706_to_0188880_session_2931941177_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_15-00-19.626284_from_79263608103_to_0188880_session_2931953205_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_15-00-57.316539_from_79263608103_to_0188880_session_2931957661_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_15-02-35.118332_from_79852613834_to_0188880_session_2931384623_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_15-41-10.970727_from_79255890397_to_0188880_session_2921167086_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_15-58-20.766372_from_79091597661_to_0188880_session_2941752812_talk.mp3',
#  '/content/Записи звонков_хедлайнер/2023-05-10_16-05-49.015072_from_79851934089_to_0188880_session_2932192025_talk.mp3']

# %%
# Добавление в датафрейм с информацией о звонках столбцов 'Файл записи звонка' и 'Проект'
import os
df = df.astype({'Идентификатор сессии звонка': int})
for sample_file in os.listdir('Записи звонков_хедлайнер'):
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Файл записи звонка'] = 'Записи звонков_хедлайнер/' + sample_file
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Проект'] = 'head-liner.ru'

# %%
df.loc[df[df['Проект'] == 'head-liner.ru'].index, ['Идентификатор сессии звонка', 'Файл записи звонка', 'Проект']].head()
# Out:
#       Идентификатор сессии звонка  \
# 4296                   2932192025
# 4297                   2941752812
# 4298                   2921167086
# 4301                   2931384623
# 4302                   2931957661
#
#                                      Файл записи звонка         Проект
# 4296  Записи звонков_хедлайнер/2023-05-10_16-05-49.0...  head-liner.ru
# 4297  Записи звонков_хедлайнер/2023-05-10_15-58-20.7...  head-liner.ru
# 4298  Записи звонков_хедлайнер/2023-05-10_15-41-10.9...  head-liner.ru
# 4301  Записи звонков_хедлайнер/2023-05-10_15-02-35.1...  head-liner.ru
# 4302  Записи звонков_хедлайнер/2023-05-10_15-00-57.3...  head-liner.ru

# %%
# Выбор столбцов, необходимых для инференса модели нейронной сети и оценки
df = df[['Статус',
         'Тип',
         'Сайт',
         'Тип посетителя',
         'Сценарий',
         'Операции',
         'Тип устройства',
         'Первая рекламная кампания',
         'Чистая длительность разговора',
         'Номер обращения',
         'ID посетителя',
         'Идентификатор сессии звонка',
         'Файл записи звонка',
         'Проект',
         'Теги']][df['Проект'] == 'head-liner.ru']
df.shape
# Out:
# (50, 15)

# %%
df.head()
# Out:
#         Статус          Тип           Сайт Тип посетителя  \
# 4296  Принятый  Звонок ВАТС  head-liner.ru    Не заполнен
# 4297  Принятый  Звонок ВАТС  head-liner.ru    Не заполнен
# 4298  Принятый  Звонок ВАТС  head-liner.ru    Не заполнен
# 4301  Принятый  Звонок ВАТС  head-liner.ru    Не заполнен
# 4302  Принятый  Звонок ВАТС  head-liner.ru    Не заполнен
#
#                       Сценарий  \
# 4296  .Последовательный обзвон
# 4297                   Кортрос
# 4298                   Кортрос
# 4301                   Кортрос
# 4302  .Последовательный обзвон
#
#                                                Операции Тип устройства  \
# 4296  Переадресация на последнего менеджера 1, Переа...         Прочее
# 4297                                    Переадресация 1         Прочее
# 4298                                    Переадресация 1         Прочее
# 4301                                    Переадресация 1         Прочее
# 4302            Переадресация на последнего менеджера 1         Прочее
#
#               Первая рекламная кампания Чистая длительность разговора  \
# 4296  Посетители без рекламной кампании                      00:00:21
# 4297  Посетители без рекламной кампании                      00:00:10
# 4298  Посетители без рекламной кампании                      00:00:03
# 4301  Посетители без рекламной кампании                      00:02:07
# 4302  Посетители без рекламной кампании                      00:00:53
#
#       Номер обращения  ID посетителя  Идентификатор сессии звонка  \
# 4296                1            NaN                   2932192025
# 4297                1            NaN                   2941752812
# 4298                1            NaN                   2921167086
# 4301                9            NaN                   2931384623
# 4302                2            NaN                   2931957661
#
#                                      Файл записи звонка         Проект  \
# 4296  Записи звонков_хедлайнер/2023-05-10_16-05-49.0...  head-liner.ru
# 4297  Записи звонков_хедлайнер/2023-05-10_15-58-20.7...  head-liner.ru
# 4298  Записи звонков_хедлайнер/2023-05-10_15-41-10.9...  head-liner.ru
# 4301  Записи звонков_хедлайнер/2023-05-10_15-02-35.1...  head-liner.ru
# 4302  Записи звонков_хедлайнер/2023-05-10_15-00-57.3...  head-liner.ru
#
#                                            Теги
# 4296                   спорный - нет соединения
# 4297                                       Спам
# 4298                   спорный - нет соединения
# 4301  Лид - 3 очередь - 2-ком - Условно целевой
# 4302                  Нецелевой звонок - ошибка

# %%
# Сохранение в json
df.to_json('input.json', orient='records', force_ascii=False)

# %%
# Установка cohere, openai и tiktoken
# !pip -q install cohere openai==1.2.3 tiktoken==0.5.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 849.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Установка fastapi и дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 4.5 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import re
import whisper
import numpy as np
import pandas as pd
import pickle as pkl
from io import BytesIO
from fastapi import FastAPI, File
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.saving import load_model

whisper_model = whisper.load_model('medium')
model = load_model('model9_2.h5')

with open('model9_2_tokenizer_txt.pkl', 'rb') as f:
  tokenizer = pkl.load(f)

with open('model9_2_encoders.pkl', 'rb') as f:
  encoders = pkl.load(f)

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):

  df = pd.read_json(BytesIO(json_file))

  for i in df.index:
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe(df.loc[i,'Файл записи звонка'], language='ru')['text']
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].fillna('безответа')
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: re.sub('[^А-Яа-я0-9 ]', '', s.lower()))
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.strip()
  df['Транскрибация файла записи звонка'] = np.where(df['Транскрибация файла записи звонка'].str.len() < 5, 'безответа', df['Транскрибация файла записи звонка'])
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.replace('ё', 'е', regex=False)
  x_textdata_01 = tokenizer.texts_to_matrix(df['Транскрибация файла записи звонка'].tolist())

  ohedata = []
  for column in ['Статус', 'Тип', 'Сайт', 'Тип посетителя', 'Сценарий', 'Операции', 'Тип устройства', 'Первая рекламная кампания']:
    df[column] = df[column].fillna('Нет данных')
    df[column] = df[column].apply(lambda s: 'Нет данных' if s == '' else str(s))
    df[column] = df[column].apply(lambda s: s.strip('{}'))
    encoder = encoders[column]
    ohedata.append(to_categorical(encoder.transform(df[column].tolist()), len((encoder.classes_))))
  x_ohedata = np.hstack(ohedata).astype('float32')

  df['Чистая длительность разговора'] = pd.to_datetime(df['Чистая длительность разговора']).dt.time
  df['Чистая длительность разговора'] = df['Чистая длительность разговора'].apply(lambda x: x.hour*60*60 + x.minute*60 + x.second)
  df['ID посетителя'] = df['ID посетителя'].fillna('0').astype('float')/1e8
  x_numericdata = df[['Чистая длительность разговора', 'Номер обращения', 'ID посетителя']].values.astype('float32')
  x_numericdata = x_numericdata/x_numericdata.max()

  y_predict = model.predict({'input_x1': x_textdata_01, 'input_x2': x_ohedata, 'input_x3': x_numericdata})
  for i in range(df.shape[0]):
    df.loc[i,'Предсказание класса'] = 'Целевой' if round(y_predict[i][0]) else 'Нецелевой'

  df[['Проект', 'Идентификатор сессии звонка', 'Теги', 'Предсказание класса', 'Транскрибация файла записи звонка']].to_json('output.json', orient='records', force_ascii=False)

  return {'result': 'output.json'}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1878] using StatReload
# 2023-12-29 04:38:11.503880: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 04:38:11.503939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 04:38:11.505278: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 04:38:11.512453: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 04:38:12.654240: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:14<00:00, 103MiB/s]
# 2023-12-29 04:38:45.347756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.662057: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.662351: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663067: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663294: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663493: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663852: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664056: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664217: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-12-29 04:38:45.664260: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9555 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:     Started server process [1880]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import time
import requests
start_time = time.time()
files = {'json_file': open('input.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
processing_time = int(time.time() - start_time)
print(f'\nВремя обработки запроса: {int(processing_time//60)} мин {int(processing_time%60)} сек.')
# Out:
# {"result":"output.json"}
#
# Время обработки запроса: 21 мин 36 сек.

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1878] using StatReload
# 2023-12-29 04:38:11.503880: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 04:38:11.503939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 04:38:11.505278: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 04:38:11.512453: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 04:38:12.654240: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:14<00:00, 103MiB/s]
# 2023-12-29 04:38:45.347756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.662057: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.662351: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663067: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663294: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663493: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.663852: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664056: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664217: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-12-29 04:38:45.664260: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 04:38:45.664418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9555 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:     Started server process [1880]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 2/2 [==============================] - 1s 4ms/step
# INFO:     127.0.0.1:34982 - "POST /predict HTTP/1.1" 200 OK

# %%
df = pd.read_json('output.json')
df.shape
# Out:
# (50, 5)

# %%
df
# Out:
#            Проект  Идентификатор сессии звонка  \
# 0   head-liner.ru                   2932192025
# 1   head-liner.ru                   2941752812
# 2   head-liner.ru                   2921167086
# 3   head-liner.ru                   2931384623
# 4   head-liner.ru                   2931957661
# 5   head-liner.ru                   2931953205
# 6   head-liner.ru                   2931941177
# 7   head-liner.ru                   2920990562
# 8   head-liner.ru                   2941565172
# 9   head-liner.ru                   2920974222
# 10  head-liner.ru                   2941298624
# 11  head-liner.ru                   2931067143
# 12  head-liner.ru                   2931495869
# 13  head-liner.ru                   2930842543
# 14  head-liner.ru                   2930835239
# 15  head-liner.ru                   2931380841
# 16  head-liner.ru                   2930744767
# 17  head-liner.ru                   2940892544
# 18  head-liner.ru                   2931126469
# 19  head-liner.ru                   2931066829
# 20  head-liner.ru                   2920243890
# 21  head-liner.ru                   2920207590
# 22  head-liner.ru                   2920087786
# 23  head-liner.ru                   2930217007
# 24  head-liner.ru                   2919615074
# 25  head-liner.ru                   2919550530
# 26  head-liner.ru                   2919520238
# 27  head-liner.ru                   2930249245
# 28  head-liner.ru                   2939712644
# 29  head-liner.ru                   2930211973
# 30  head-liner.ru                   2929623235
# 31  head-liner.ru                   2939644136
# 32  head-liner.ru                   2939506208
# 33  head-liner.ru                   2929465891
# 34  head-liner.ru                   2939439048
# 35  head-liner.ru                   2929372379
# 36  head-liner.ru                   2929311247
# 37  head-liner.ru                   2919161802
# 38  head-liner.ru                   2939148092
# 39  head-liner.ru                   2929370545
# 40  head-liner.ru                   2918538922
# 41  head-liner.ru                   2938333136
# 42  head-liner.ru                   2928975097
# 43  head-liner.ru                   2928938049
# 44  head-liner.ru                   2928935657
# 45  head-liner.ru                   2928283255
# 46  head-liner.ru                   2938080128
# 47  head-liner.ru                   2928807121
# 48  head-liner.ru                   2937971588
# 49  head-liner.ru                   2928050751
#
#                                                  Теги Предсказание класса  \
# 0                            спорный - нет соединения           Нецелевой
# 1                                                Спам           Нецелевой
# 2                            спорный - нет соединения           Нецелевой
# 3           Лид - 3 очередь - 2-ком - Условно целевой           Нецелевой
# 4                           Нецелевой звонок - ошибка           Нецелевой
# 5                            спорный - нет соединения           Нецелевой
# 6      постпродажное обслуживание - Вторичный целевой           Нецелевой
# 7   Лид - 2 очередь - 3 очередь - 2-ком - Условно ...             Целевой
# 8      постпродажное обслуживание - Вторичный целевой           Нецелевой
# 9                            спорный - нет соединения           Нецелевой
# 10     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 11     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 12                           спорный - нет соединения           Нецелевой
# 13                           спорный - нет соединения           Нецелевой
# 14  Первичный целевой - 2 очередь - 3 очередь - 4-...             Целевой
# 15  Первичный целевой - 3 очередь - 2-ком - 2 квар...             Целевой
# 16     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 17                  Нецелевой звонок - сотрудничество           Нецелевой
# 18                    Лид - Первичный целевой - 1-ком           Нецелевой
# 19                                               Спам           Нецелевой
# 20                           спорный - нет соединения           Нецелевой
# 21                           спорный - нет соединения           Нецелевой
# 22                          Нецелевой звонок - ошибка           Нецелевой
# 23             Вторичный целевой - поиск офиса продаж             Целевой
# 24                           спорный - нет соединения           Нецелевой
# 25                           спорный - нет соединения           Нецелевой
# 26  Лид - Вторичный целевой - 2 очередь - 3 очеред...             Целевой
# 27  Первичный целевой - запись на просмотр - не оп...             Целевой
# 28                           спорный - нет соединения           Нецелевой
# 29              Первичный целевой - 2 очередь - 3-ком             Целевой
# 30                           спорный - нет соединения           Нецелевой
# 31                           спорный - нет соединения           Нецелевой
# 32                           спорный - нет соединения           Нецелевой
# 33  Лид - Первичный целевой - интересует рассрочка...             Целевой
# 34                   Лид - спорный - связь прервалась           Нецелевой
# 35                           спорный - нет соединения           Нецелевой
# 36     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 37                                               Спам           Нецелевой
# 38     Первичный целевой - студия - 3 очередь - 1-ком             Целевой
# 39                           спорный - нет соединения           Нецелевой
# 40                          Нецелевой звонок - ошибка           Нецелевой
# 41  Лид - спорный - студия - связь прервалась - 1-ком           Нецелевой
# 42              Первичный целевой - 2 очередь - 3-ком             Целевой
# 43     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 44     постпродажное обслуживание - Вторичный целевой           Нецелевой
# 45                           спорный - нет соединения           Нецелевой
# 46  Лид - 3 очередь - Условно целевой - 3-ком - от...             Целевой
# 47                           спорный - нет соединения           Нецелевой
# 48   Первичный целевой - ипотека - студия - 3 очередь             Целевой
# 49                           спорный - нет соединения           Нецелевой
#
#                     Транскрибация файла записи звонка
# 0   здравствуйте выпуску внею группу компании карт...
# 1   здравствуйте вы позвонили в группу компании  б...
# 2                  здравствуйте вы туда не ел в грунт
# 3   здравствуйте вы позвонили в группу компании  б...
# 4   здравствуйте вы позвонили в группу компании ка...
# 5   здравствуйте вы позвонили в группу компании ка...
# 6   здравствуйте вы позвонили в группу компании ка...
# 7   взява комплекса  меня зовут наталья здравствуй...
# 8   здравствуйте скажите пожалуйста я переоформила...
# 9                         здравствуйте вы позвонили в
# 10  хэрлайнер роки заселение добрый день здравству...
# 11  хэдлайнер отчисления здравствуйте вы знаете я ...
# 12  телефонный звонок телефонный звонок телефонный...
# 13                           здравствуйте вы туганили
# 14  вы позвонили в группу компании  благодарим вас...
# 15  здравствуйте вы позвонили в группу компании ка...
# 16  здравствуйте вы позвонили в группу компании ка...
# 17  здравствуйте вы позвонили в группу компании ка...
# 18  компания анитика и клиента шот одна комната на...
# 19                                  а вот добрый день
# 20    станислав вы комплекс как бы я не разлп продашь
# 21  здравствуйте вы позвонили в группу компании ка...
# 22  здравствуйте вы позвонили в группу компании  б...
# 23  здравствуйте вы позвонили в группу компании  б...
# 24  звонок в дверь живой комплекс  наталья здравст...
# 25                                              иятся
# 26  здравствуйте вы позвонили в группу компании  б...
# 27  х  можно сегодня сделать  я вас соединю с мене...
# 28                                       здравствуйте
# 29  здравствуйте вы позвонили в группу компании  б...
# 30                                       здравствуйте
# 31                                           закроюсь
# 32  аликси звонок по объявлению разговор может быт...
# 33  день добрый здравствуйте здравствуйте портал г...
# 34  телефон звонит желаю областью звонить меня зов...
# 35  здравствуйте вы позвонили в группу компании  б...
# 36  здравствуйте вы позвонили в группу компании ка...
# 37  авика звонок по объявлению разговор может быть...
# 38  здравствуйте вы позвонили в группу компании  б...
# 39  здравствуйте вы позвонили в группу компании  б...
# 40      расскажите пожалуйста фотоаппарат кэннен а603
# 41  здравствуйте вы позвонили в группу компании  б...
# 42  здравствуйте вы позвонили в группу компании  б...
# 43  алло да да я сейчас разговаривала с девушкой д...
# 44  добрый день девушка вот скажите пожалуйста я п...
# 45  здравствуйте вы позвонили в группу компании ка...
# 46  здравствуйте вы позвонили в группу компании  б...
# 47  здравствуйте вы позвонили в группу компании  б...
# 48  здравствуйте вы позвонили в группу компании  б...
# 49  телефонный звонок телефонный звонок телефонный...

# %%
# !mv output.json head-liner.ru_output.json

# %% [markdown]
# ### pavcity.turbo.site

# %%
# Загрузка токенайзера
import gdown
url = 'https://drive.google.com/file/d/1Pjsm9ozkoouo_znt--4J4t_bJW9ZJoMe/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2_tokenizer_txt.pkl'

# %%
# Загрузка энкодеров
url = 'https://drive.google.com/file/d/1-3KOQpN1gtKmaNcwCvAHdK6NtMVxPOKu/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2_encoders.pkl'

# %%
# Загрузка модели нейронной сети
url = 'https://drive.google.com/file/d/10PbDY-XLNV7CM-xRu5fvN3ziD0s3Qs1p/view?usp=drive_link'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# 'model9_2.h5'

# %%
# Загрузка информации о звонках
import pandas as pd
url = 'https://drive.google.com/file/d/1c4jlkuw2zWdeqr5FgBfHt4KaKtoMWQi0/view?usp=drive_link'
df = pd.read_csv('https://drive.google.com/uc?id=' + url.split('/')[-2],
                 skiprows=4,
                 sep=';',
                 on_bad_lines='skip')
df.shape
# Out:
# (1211, 74)

# %%
# Загрузка записей звонков
url = 'https://drive.google.com/drive/folders/1XwaXRApFWaqBSe0PGEkaMGT-EHH7OMtj?usp=drive_link'
gdown.download_folder(url, quiet=True, remaining_ok=True)
# Out:
# ['/content/Записи звонков_павелецкая сити/2023-06-17_12-54-28.210462_from_79803286601_to_74950216267_session_3029638181_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_13-44-17.539114_from_79066743768_to_74950216267_session_3029352265_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_14-08-51.827169_from_74993205445_to_74955141111_session_3029390475_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_14-21-31.493157_from_79259041087_to_74950216267_session_3029730813_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_16-16-05.571252_from_79680303488_to_74950216267_session_3029596520_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_17-21-57.195548_from_79094690999_to_74955141111_session_3030126641_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_19-11-06.505605_from_74950326372_to_0155649_session_3030256809_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_09-01-03.303353_from_74950326372_to_0155649_session_3030549204_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_09-22-52.207865_from_79651805758_to_74955141111_session_3030554159_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-07-09.396588_from_79151900879_to_74950216267_session_3030608659_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-36-22.310087_from_79671034159_to_74955141111_session_3030649979_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-48-11.070497_from_79221093735_to_74950216267_session_3030810737_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-56-51.904109_from_79645040572_to_74955141111_session_3030623683_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_11-25-38.241315_from_79854127684_to_74955141111_session_3030870962_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-23-21.133140_from_79139127673_to_74950216267_session_3030815699_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-25-02.742799_from_79660057569_to_74955141111_session_3030846086_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-46-57.826869_from_79036235042_to_74955141111_session_3030786763_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-03-15.004666_from_79274843267_to_74950216267_session_3031027717_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-21-21.314056_from_79164825580_to_74955141111_session_3030904744_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-49-07.465157_from_79269090190_to_74955141111_session_3030853628_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_14-35-25.096497_from_79519099298_to_74955141111_session_3030974296_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-02-01.473156_from_79682079335_to_74950216267_session_3031223322_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-26-26.487296_from_79250468024_to_74950216267_session_3030567890_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-44-27.861587_from_79107482069_to_74950216267_session_3031126709_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-59-20.666700_from_79265805599_to_74955141111_session_3031073688_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_16-05-54.155297_from_79852671888_to_74955141111_session_3030619720_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_17-41-38.718386_from_79051570440_to_74950216267_session_3031456882_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_17-50-08.307656_from_79067778858_to_74955141111_session_3031466787_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_18-04-56.248883_from_79031012817_to_74955141111_session_3031316834_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_18-09-35.177730_from_79107876076_to_74955141111_session_3030767375_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_19-25-38.489238_from_79654392820_to_74950216267_session_3031429591_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_10-47-17.706090_from_79136281109_to_74950216267_session_3032022083_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_10-53-44.520624_from_79684035656_to_74955141111_session_3032341357_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-04-05.286756_from_79260084182_to_74950216267_session_3032207796_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-23-17.040128_from_79813389541_to_74950216267_session_3032271261_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-27-46.734461_from_79781935179_to_74955141111_session_3032161583_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-12-40.350431_from_79104429469_to_74955141111_session_3032677423_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-26-58.386574_from_79250189982_to_74950216267_session_3031640590_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-38-08.398862_from_79501466664_to_74950216267_session_3032483204_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-57-33.574655_from_79636865864_to_74955141111_session_3032896177_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-12-07.125542_from_79101658988_to_74950216267_session_3032179333_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-14-49.436106_from_74992700663_to_74950216267_session_3032775068_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-17-13.730161_from_79169209180_to_74955141111_session_3031875985_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-41-47.633298_from_79269260970_to_74955141111_session_3032237258_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_14-46-35.874105_from_79175826749_to_74950216267_session_3031650945_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-11-32.468224_from_79031566838_to_74950216267_session_3034046623_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-25-36.353632_from_79687067959_to_74955141111_session_3032007610_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-30-14.561778_from_79175929175_to_74955141111_session_3034442627_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-59-53.239894_from_79990352825_to_74955141111_session_3032485270_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_16-25-10.470057_from_79153673050_to_74950216267_session_3032998743_talk.mp3']

# %%
# Добавление в датафрейм с информацией о звонках столбцов 'Файл записи звонка' и 'Проект'
import os
df = df.astype({'Идентификатор сессии звонка': int})
for sample_file in os.listdir('Записи звонков_павелецкая сити'):
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Файл записи звонка'] = 'Записи звонков_павелецкая сити/' + sample_file
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Проект'] = 'pavcity.turbo.site'

# %%
df.loc[df[df['Проект'] == 'pavcity.turbo.site'].index, ['Идентификатор сессии звонка', 'Файл записи звонка', 'Проект']].head()
# Out:
#     Идентификатор сессии звонка  \
# 11                   3032161583
#
#                                    Файл записи звонка              Проект
# 11  Записи звонков_павелецкая сити/2023-06-19_11-2...  pavcity.turbo.site

# %%
# Выбор столбцов, необходимых для инференса модели нейронной сети и оценки
df = df[['Статус',
         'Тип',
         'Сайт',
         'Тип посетителя',
         'Сценарий',
         'Операции',
         'Тип устройства',
         'Первая рекламная кампания',
         'Чистая длительность разговора',
         'Номер обращения',
         'ID посетителя',
         'Идентификатор сессии звонка',
         'Файл записи звонка',
         'Проект',
         'Теги']][df['Проект'] == 'pavcity.turbo.site']
df.shape
# Out:
# (1, 15)

# %%
df.head()
# Out:
#       Статус                       Тип                Сайт Тип посетителя  \
# 11  Принятый  Динамический коллтрекинг  pavcity.turbo.site    Вернувшийся
#
#        Сценарий       Операции Тип устройства  \
# 11  74955141111  Переадресация       Смартфон
#
#                             Первая рекламная кампания  \
# 11  Artics | Павелецкая Сити | direct | Яндекс.Дир...
#
#    Чистая длительность разговора  Номер обращения  ID посетителя  \
# 11                      00:00:33                1   7.206037e+09
#
#     Идентификатор сессии звонка  \
# 11                   3032161583
#
#                                    Файл записи звонка              Проект Теги
# 11  Записи звонков_павелецкая сити/2023-06-19_11-2...  pavcity.turbo.site  NaN

# %%
# Сохранение в json
df.to_json('input.json', orient='records', force_ascii=False)

# %%
# Установка cohere, openai и tiktoken
# !pip -q install cohere openai==1.2.3 tiktoken==0.5.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.9 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Установка fastapi и дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 6.1 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import re
import whisper
import numpy as np
import pandas as pd
import pickle as pkl
from io import BytesIO
from fastapi import FastAPI, File
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.saving import load_model

whisper_model = whisper.load_model('medium')
model = load_model('model9_2.h5')

with open('model9_2_tokenizer_txt.pkl', 'rb') as f:
  tokenizer = pkl.load(f)

with open('model9_2_encoders.pkl', 'rb') as f:
  encoders = pkl.load(f)

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):

  df = pd.read_json(BytesIO(json_file))

  for i in df.index:
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe(df.loc[i,'Файл записи звонка'], language='ru')['text']
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].fillna('безответа')
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].apply(lambda s: re.sub('[^А-Яа-я0-9 ]', '', s.lower()))
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.strip()
  df['Транскрибация файла записи звонка'] = np.where(df['Транскрибация файла записи звонка'].str.len() < 5, 'безответа', df['Транскрибация файла записи звонка'])
  df['Транскрибация файла записи звонка'] = df['Транскрибация файла записи звонка'].str.replace('ё', 'е', regex=False)
  x_textdata_01 = tokenizer.texts_to_matrix(df['Транскрибация файла записи звонка'].tolist())

  ohedata = []
  for column in ['Статус', 'Тип', 'Сайт', 'Тип посетителя', 'Сценарий', 'Операции', 'Тип устройства', 'Первая рекламная кампания']:
    df[column] = df[column].fillna('Нет данных')
    df[column] = df[column].apply(lambda s: 'Нет данных' if s == '' else str(s))
    df[column] = df[column].apply(lambda s: s.strip('{}'))
    encoder = encoders[column]
    ohedata.append(to_categorical(encoder.transform(df[column].tolist()), len((encoder.classes_))))
  x_ohedata = np.hstack(ohedata).astype('float32')

  df['Чистая длительность разговора'] = pd.to_datetime(df['Чистая длительность разговора']).dt.time
  df['Чистая длительность разговора'] = df['Чистая длительность разговора'].apply(lambda x: x.hour*60*60 + x.minute*60 + x.second)
  df['ID посетителя'] = df['ID посетителя'].fillna('0').astype('float')/1e8
  x_numericdata = df[['Чистая длительность разговора', 'Номер обращения', 'ID посетителя']].values.astype('float32')
  x_numericdata = x_numericdata/x_numericdata.max()

  y_predict = model.predict({'input_x1': x_textdata_01, 'input_x2': x_ohedata, 'input_x3': x_numericdata})
  for i in range(df.shape[0]):
    df.loc[i,'Предсказание класса'] = 'Целевой' if round(y_predict[i][0]) else 'Нецелевой'

  df[['Проект', 'Идентификатор сессии звонка', 'Теги', 'Предсказание класса', 'Транскрибация файла записи звонка']].to_json('output.json', orient='records', force_ascii=False)

  return {'result': 'output.json'}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1685] using StatReload
# 2023-12-29 04:25:52.866228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 04:25:52.866311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 04:25:52.868011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 04:25:52.877857: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 04:25:54.444118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:18<00:00, 84.6MiB/s]
# INFO:     Started server process [1691]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import time
import requests
start_time = time.time()
files = {'json_file': open('input.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
processing_time = int(time.time() - start_time)
print(f'\nВремя обработки запроса: {int(processing_time//60)} мин {int(processing_time%60)} сек.')
# Out:
# {"result":"output.json"}
#
# Время обработки запроса: 1 мин 42 сек.

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1685] using StatReload
# 2023-12-29 04:25:52.866228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 04:25:52.866311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 04:25:52.868011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 04:25:52.877857: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 04:25:54.444118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:18<00:00, 84.6MiB/s]
# INFO:     Started server process [1691]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 1/1 [==============================] - 0s 303ms/step
# INFO:     127.0.0.1:48274 - "POST /predict HTTP/1.1" 200 OK

# %%
df = pd.read_json('output.json')
df.shape
# Out:
# (1, 5)

# %%
df
# Out:
#                Проект  Идентификатор сессии звонка  Теги Предсказание класса  \
# 0  pavcity.turbo.site                   3032161583   NaN           Нецелевой
#
#                    Транскрибация файла записи звонка
# 0  здравствуйте вы позвонили в компанию   пожалуй...

# %%
# !mv output.json pavcity.turbo.site_output.json

# %% [markdown]
# ### pavcity.ru

# %%
# Загрузка модели нейронной сети
import gdown
url = 'https://drive.google.com/file/d/1EaA53dXa4ZU2DZLB2su4bf8TOPTdM_CK/view?usp=sharing'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# '2023.10.15_text_model.keras'

# %%
# Загрузка информации о звонках
import pandas as pd
url = 'https://drive.google.com/file/d/1wC6aUm3Cq3G5EsQWnuVjc_-11wgJEaVl/view?usp=drive_link'
df = pd.read_csv('https://drive.google.com/uc?id=' + url.split('/')[-2],
                 skiprows=4,
                 sep=';',
                 on_bad_lines='skip')
df.shape
# Out:
# (9318, 74)

# %%
# Загрузка записей звонков
url = 'https://drive.google.com/drive/folders/1XwaXRApFWaqBSe0PGEkaMGT-EHH7OMtj?usp=drive_link'
gdown.download_folder(url, quiet=True, remaining_ok=True)
# Out:
# ['/content/Записи звонков_павелецкая сити/2023-06-17_12-54-28.210462_from_79803286601_to_74950216267_session_3029638181_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_13-44-17.539114_from_79066743768_to_74950216267_session_3029352265_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_14-08-51.827169_from_74993205445_to_74955141111_session_3029390475_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_14-21-31.493157_from_79259041087_to_74950216267_session_3029730813_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_16-16-05.571252_from_79680303488_to_74950216267_session_3029596520_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_17-21-57.195548_from_79094690999_to_74955141111_session_3030126641_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-17_19-11-06.505605_from_74950326372_to_0155649_session_3030256809_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_09-01-03.303353_from_74950326372_to_0155649_session_3030549204_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_09-22-52.207865_from_79651805758_to_74955141111_session_3030554159_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-07-09.396588_from_79151900879_to_74950216267_session_3030608659_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-36-22.310087_from_79671034159_to_74955141111_session_3030649979_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-48-11.070497_from_79221093735_to_74950216267_session_3030810737_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_10-56-51.904109_from_79645040572_to_74955141111_session_3030623683_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_11-25-38.241315_from_79854127684_to_74955141111_session_3030870962_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-23-21.133140_from_79139127673_to_74950216267_session_3030815699_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-25-02.742799_from_79660057569_to_74955141111_session_3030846086_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_12-46-57.826869_from_79036235042_to_74955141111_session_3030786763_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-03-15.004666_from_79274843267_to_74950216267_session_3031027717_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-21-21.314056_from_79164825580_to_74955141111_session_3030904744_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_13-49-07.465157_from_79269090190_to_74955141111_session_3030853628_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_14-35-25.096497_from_79519099298_to_74955141111_session_3030974296_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-02-01.473156_from_79682079335_to_74950216267_session_3031223322_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-26-26.487296_from_79250468024_to_74950216267_session_3030567890_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-44-27.861587_from_79107482069_to_74950216267_session_3031126709_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_15-59-20.666700_from_79265805599_to_74955141111_session_3031073688_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_16-05-54.155297_from_79852671888_to_74955141111_session_3030619720_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_17-41-38.718386_from_79051570440_to_74950216267_session_3031456882_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_17-50-08.307656_from_79067778858_to_74955141111_session_3031466787_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_18-04-56.248883_from_79031012817_to_74955141111_session_3031316834_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_18-09-35.177730_from_79107876076_to_74955141111_session_3030767375_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-18_19-25-38.489238_from_79654392820_to_74950216267_session_3031429591_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_10-47-17.706090_from_79136281109_to_74950216267_session_3032022083_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_10-53-44.520624_from_79684035656_to_74955141111_session_3032341357_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-04-05.286756_from_79260084182_to_74950216267_session_3032207796_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-23-17.040128_from_79813389541_to_74950216267_session_3032271261_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_11-27-46.734461_from_79781935179_to_74955141111_session_3032161583_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-12-40.350431_from_79104429469_to_74955141111_session_3032677423_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-26-58.386574_from_79250189982_to_74950216267_session_3031640590_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-38-08.398862_from_79501466664_to_74950216267_session_3032483204_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_12-57-33.574655_from_79636865864_to_74955141111_session_3032896177_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-12-07.125542_from_79101658988_to_74950216267_session_3032179333_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-14-49.436106_from_74992700663_to_74950216267_session_3032775068_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-17-13.730161_from_79169209180_to_74955141111_session_3031875985_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_13-41-47.633298_from_79269260970_to_74955141111_session_3032237258_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_14-46-35.874105_from_79175826749_to_74950216267_session_3031650945_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-11-32.468224_from_79031566838_to_74950216267_session_3034046623_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-25-36.353632_from_79687067959_to_74955141111_session_3032007610_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-30-14.561778_from_79175929175_to_74955141111_session_3034442627_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_15-59-53.239894_from_79990352825_to_74955141111_session_3032485270_talk.mp3',
#  '/content/Записи звонков_павелецкая сити/2023-06-19_16-25-10.470057_from_79153673050_to_74950216267_session_3032998743_talk.mp3']

# %%
# Добавление в датафрейм с информацией о звонках столбцов 'Файл записи звонка' и 'Проект'
import os
df = df.astype({'Идентификатор сессии звонка': int})
for sample_file in os.listdir('Записи звонков_павелецкая сити'):
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Файл записи звонка'] = 'Записи звонков_павелецкая сити/' + sample_file
  df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Проект'] = 'pavcity.ru'

# %%
df.loc[df[df['Проект'] == 'pavcity.ru'].index, ['Идентификатор сессии звонка', 'Файл записи звонка', 'Проект']].head()
# Out:
#       Идентификатор сессии звонка  \
# 1394                   3032998743
# 1395                   3032485270
# 1396                   3034442627
# 1397                   3032007610
# 1398                   3034046623
#
#                                      Файл записи звонка      Проект
# 1394  Записи звонков_павелецкая сити/2023-06-19_16-2...  pavcity.ru
# 1395  Записи звонков_павелецкая сити/2023-06-19_15-5...  pavcity.ru
# 1396  Записи звонков_павелецкая сити/2023-06-19_15-3...  pavcity.ru
# 1397  Записи звонков_павелецкая сити/2023-06-19_15-2...  pavcity.ru
# 1398  Записи звонков_павелецкая сити/2023-06-19_15-1...  pavcity.ru

# %%
# Выбор столбцов, необходимых для инференса модели нейронной сети и оценки
df = df[['Идентификатор сессии звонка',
         'Файл записи звонка',
         'Проект',
         'Теги']][df['Проект'] == 'pavcity.ru']
df.shape
# Out:
# (49, 4)

# %%
df.head()
# Out:
#       Идентификатор сессии звонка  \
# 1394                   3032998743
# 1395                   3032485270
# 1396                   3034442627
# 1397                   3032007610
# 1398                   3034046623
#
#                                      Файл записи звонка      Проект  \
# 1394  Записи звонков_павелецкая сити/2023-06-19_16-2...  pavcity.ru
# 1395  Записи звонков_павелецкая сити/2023-06-19_15-5...  pavcity.ru
# 1396  Записи звонков_павелецкая сити/2023-06-19_15-3...  pavcity.ru
# 1397  Записи звонков_павелецкая сити/2023-06-19_15-2...  pavcity.ru
# 1398  Записи звонков_павелецкая сити/2023-06-19_15-1...  pavcity.ru
#
#               Теги
# 1394  Целевой_М108
# 1395  Целевой_М108
# 1396           NaN
# 1397           NaN
# 1398           NaN

# %%
# Сохранение в json
df.to_json('input.json', orient='records', force_ascii=False)

# %%
# Установка autokeras
# !pip -q install autokeras
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.8/584.8 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 29.3 MB/s eta 0:00:00

# %%
# !pip -q install tensorflow==2.14.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 48.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.15.0 requires tensorflow<2.16,>=2.15.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.14.0 which is incompatible.

# %%
# Установка cohere, openai и tiktoken
# !pip -q install cohere openai==1.2.3 tiktoken==0.5.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 86.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Установка fastapi и дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 6.4 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import re
import whisper
import numpy as np
import pandas as pd
import pickle as pkl
import autokeras as ak
from io import BytesIO
from fastapi import FastAPI, File
from tensorflow.keras.saving import load_model

whisper_model = whisper.load_model('medium')
model = load_model('2023.10.15_text_model.keras')

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):

  df = pd.read_json(BytesIO(json_file))

  for i in df.index:
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe(df.loc[i,'Файл записи звонка'], language='ru')['text']

  y_predict = model.predict(df['Транскрибация файла записи звонка'].values)
  for i in range(df.shape[0]):
    df.loc[i,'Предсказание класса'] = 'Нецелевой' if round(y_predict[i][0]) else 'Целевой'

  df[['Проект', 'Идентификатор сессии звонка', 'Теги', 'Предсказание класса', 'Транскрибация файла записи звонка']].to_json('output.json', orient='records', force_ascii=False)

  return {'result': 'output.json'}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2482] using StatReload
# 2023-12-29 07:13:31.169166: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 07:13:31.217148: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 07:13:31.217216: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 07:13:31.217255: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 07:13:31.226937: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 07:13:31.227227: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 07:13:32.349073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:11<00:00, 135MiB/s]
# 2023-12-29 07:14:04.604703: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 07:14:04.860608: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.
# INFO:     Started server process [2488]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import time
import requests
start_time = time.time()
files = {'json_file': open('input.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
processing_time = int(time.time() - start_time)
print(f'\nВремя обработки запроса: {int(processing_time//60)} мин {int(processing_time%60)} сек.')
# Out:
# {"result":"output.json"}
#
# Время обработки запроса: 30 мин 10 сек.

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2482] using StatReload
# 2023-12-29 07:13:31.169166: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 07:13:31.217148: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 07:13:31.217216: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 07:13:31.217255: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 07:13:31.226937: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 07:13:31.227227: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 07:13:32.349073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:11<00:00, 135MiB/s]
# 2023-12-29 07:14:04.604703: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 07:14:04.860608: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.
# INFO:     Started server process [2488]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 2/2 [==============================] - 0s 17ms/step
# INFO:     127.0.0.1:47900 - "POST /predict HTTP/1.1" 200 OK

# %%
df = pd.read_json('output.json')
df.shape
# Out:
# (49, 5)

# %%
df
# Out:
#         Проект  Идентификатор сессии звонка                    Теги  \
# 0   pavcity.ru                   3032998743            Целевой_М108
# 1   pavcity.ru                   3032485270            Целевой_М108
# 2   pavcity.ru                   3034442627                    None
# 3   pavcity.ru                   3032007610                    None
# 4   pavcity.ru                   3034046623                    None
# 5   pavcity.ru                   3031650945  Коммерция_целевой_М108
# 6   pavcity.ru                   3032237258                    None
# 7   pavcity.ru                   3031875985                    None
# 8   pavcity.ru                   3032775068                    None
# 9   pavcity.ru                   3032179333            Целевой_М108
# 10  pavcity.ru                   3032896177                    None
# 11  pavcity.ru                   3032483204                    None
# 12  pavcity.ru                   3031640590            Целевой_М108
# 13  pavcity.ru                   3032677423                    None
# 14  pavcity.ru                   3032271261       Нецелевой контакт
# 15  pavcity.ru                   3032207796                    None
# 16  pavcity.ru                   3032341357                    None
# 17  pavcity.ru                   3032022083            Целевой_М108
# 18  pavcity.ru                   3031429591                    None
# 19  pavcity.ru                   3030767375                    None
# 20  pavcity.ru                   3031316834       Нецелевой контакт
# 21  pavcity.ru                   3031466787            Целевой_М108
# 22  pavcity.ru                   3031456882                    None
# 23  pavcity.ru                   3030619720            Целевой_М108
# 24  pavcity.ru                   3031073688                    None
# 25  pavcity.ru                   3031126709                    None
# 26  pavcity.ru                   3030567890            Целевой_М108
# 27  pavcity.ru                   3031223322                    None
# 28  pavcity.ru                   3030974296            Целевой_М108
# 29  pavcity.ru                   3030853628                    None
# 30  pavcity.ru                   3030904744                    None
# 31  pavcity.ru                   3031027717       Нецелевой контакт
# 32  pavcity.ru                   3030786763       Нецелевой контакт
# 33  pavcity.ru                   3030846086       Нецелевой контакт
# 34  pavcity.ru                   3030815699            Целевой_М108
# 35  pavcity.ru                   3030870962                    None
# 36  pavcity.ru                   3030623683       Нецелевой контакт
# 37  pavcity.ru                   3030810737                    None
# 38  pavcity.ru                   3030649979       Нецелевой контакт
# 39  pavcity.ru                   3030608659            Целевой_М108
# 40  pavcity.ru                   3030554159       Нецелевой контакт
# 41  pavcity.ru                   3030549204                    None
# 42  pavcity.ru                   3030256809                    None
# 43  pavcity.ru                   3030126641       Нецелевой контакт
# 44  pavcity.ru                   3029596520            Целевой_М108
# 45  pavcity.ru                   3029730813                    None
# 46  pavcity.ru                   3029390475                    None
# 47  pavcity.ru                   3029352265            Целевой_М108
# 48  pavcity.ru                   3029638181            Целевой_М108
#
#    Предсказание класса                  Транскрибация файла записи звонка
# 0              Целевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 1              Целевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 2            Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 3            Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 4            Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 5              Целевой   Здравствуйте. Вы позвонили в компанию Энерго....
# 6            Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 7            Нецелевой   Здравствуйте. Вы позвонили в компанию Emer Gr...
# 8            Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 9              Целевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 10           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 11           Нецелевой   Здравствуйте, вы позвонили в компанию Emer Gr...
# 12             Целевой   Здравствуйте. Вы позвонили в компанию Emer Gr...
# 13           Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 14           Нецелевой             Здравствуйте! Вы позвонили в компанию.
# 15           Нецелевой   улучшения качества обслуживания клиентов, все...
# 16             Целевой   Здравствуйте, вы позвонили в компанию Emer Gr...
# 17             Целевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 18           Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 19           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 20           Нецелевой                                      Здравствуйте.
# 21             Целевой   Здравствуйте, вы позвонили в компанию Emer Gr...
# 22           Нецелевой   Здравствуйте, вы звоните, разговоры может дод...
# 23             Целевой   Здравствуйте, вы позвонили в компанию Emer Gr...
# 24           Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 25           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 26             Целевой   Вам звонок в сайт-ответе. В целях улучшения о...
# 27           Нецелевой   Здравствуйте, вы позвонили в компанию Эмергру...
# 28             Целевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 29           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 30           Нецелевой   Здравствуйте. Вы позвонили в компанию Emer Gr...
# 31           Нецелевой   Обращаем внимание, что в целях выживания и ка...
# 32           Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 33           Нецелевой                                      Здравствуйте.
# 34             Целевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 35           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 36           Нецелевой                      Здравствуйте, вы позвонили...
# 37           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 38           Нецелевой                        Здравствуйте, вы позвонили.
# 39             Целевой   Здравствуйте, вы позвонили в компанию Emer Gr...
# 40           Нецелевой   Здравствуйте, я Айсель Семанкова, Компания «Э...
# 41           Нецелевой   Здравствуйте, продолжаю вызов. Не расслышала....
# 42           Нецелевой   Вызываемый абонент недоступен. Ваш звонок был...
# 43           Нецелевой   Здравствуйте. Вы позвонили в компанию Эмергру...
# 44             Целевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 45           Нецелевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 46           Нецелевой   Здравствуйте, вы позвонили в компанию MR Grou...
# 47             Целевой   Здравствуйте. Вы позвонили в компанию MR Grou...
# 48             Целевой   Здравствуйте. Вы позвонили в компанию MR Grou...

# %%
# !mv output.json pavcity.ru_output.json

# %% [markdown]
# ### primavera.moscow

# %%
# Загрузка модели нейронной сети
import gdown
url = 'https://drive.google.com/file/d/1EaA53dXa4ZU2DZLB2su4bf8TOPTdM_CK/view?usp=sharing'
gdown.download(url, quiet=True, fuzzy=True)
# Out:
# '2023.10.15_text_model.keras'

# %%
# Загрузка информации о звонках
import pandas as pd
url = 'https://drive.google.com/file/d/1_z2v1tNzn2fJgrpOPjQvNaCuZwX_xaQx/view?usp=drive_link'
df = pd.read_csv('https://drive.google.com/uc?id=' + url.split('/')[-2],
                 skiprows=4,
                 sep=';',
                 on_bad_lines='skip')
df.shape
# Out:
# (3425, 74)

# %%
# Загрузка записей звонков
url = 'https://drive.google.com/drive/folders/185a1TyrQqJn-awPRDhkSt84mrqbbh2YF?usp=drive_link'
gdown.download_folder(url, quiet=True, remaining_ok=True)
# Out:
# ['/content/Записи звонков_primavera/2023-04-07_08-37-12.159811_from_79169245539_to_0197872_session_2861446698_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_09-00-04.708382_from_79687460888_to_0111639_session_2865154265_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_09-28-27.928753_from_74950210291_to_0111639_session_2867801356_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_09-36-01.910854_from_79175728295_to_0197879_session_2864741695_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_09-43-00.262473_from_74950210291_to_0111631_session_2867843688_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_10-17-04.570643_from_79150421943_to_0150111_session_2867948972_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_11-11-00.578033_from_79168630327_to_0197872_session_2861874202_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_11-39-20.205581_from_79168630327_to_0197878_session_2861973030_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_12-51-05.562042_from_79265292224_to_0111642_session_2865503407_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_13-04-35.391727_from_74950210291_to_0150108_session_2868673264_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_13-16-04.805425_from_79017716131_to_0197878_session_2862271810_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_13-25-57.123114_from_74950210291_to_0150108_session_2868746252_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_14-10-36.794693_from_74950210291_to_0111639_session_2868915324_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_14-52-00.113170_from_79278322944_to_0197878_session_2869043896_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_15-06-47.669158_from_79251823056_to_0111642_session_2862592034_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_15-12-18.635946_from_79251823056_to_0111639_session_2862605738_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_15-14-26.286472_from_79035861746_to_0197872_session_2865992215_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_16-05-43.603671_from_79652797279_to_0150108_session_2866661097_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_16-12-36.577531_from_74842540615_to_0150111_session_2866678697_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_16-19-49.683504_from_79032729180_to_0197879_session_2866204003_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_17-56-34.584886_from_79033288548_to_0197879_session_2866973193_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_18-24-51.035785_from_79165050055_to_0111639_session_2863054758_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-07_18-25-46.218872_from_79165050055_to_0111639_session_2867030845_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_09-59-04.752058_from_79917881682_to_0197872_session_2866975791_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_10-03-59.428379_from_79104136845_to_0111639_session_2867508373_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_11-58-49.920677_from_79022897012_to_0111631_session_2867714477_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_12-04-56.068231_from_79999291973_to_0150108_session_2867721581_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_12-09-23.151390_from_79039688199_to_0111642_session_2863702930_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_12-11-54.830390_from_79165956869_to_0197872_session_2867214243_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_12-38-20.816535_from_79771397095_to_0111639_session_2867264995_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_13-03-17.904505_from_79290270757_to_0150108_session_2867310623_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_15-01-22.436993_from_420212282913_to_0111639_session_2863966934_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_18-47-53.279953_from_79675554979_to_0197872_session_2871099180_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_18-48-17.208377_from_79675554979_to_0197872_session_2867820695_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-08_18-55-12.720717_from_79061934295_to_0111639_session_2871104648_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_11-14-57.304723_from_74950210291_to_0197877_session_2871634600_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_11-23-06.783222_from_79259294806_to_0150113_session_2864677594_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_12-36-16.667809_from_79153481280_to_0197877_session_2868416035_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_13-00-34.243636_from_79030019720_to_0111652_session_2864809282_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_13-23-15.901359_from_79671795235_to_0150113_session_2868990557_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_13-44-31.486472_from_79852763432_to_0197872_session_2871850172_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_15-19-28.128262_from_79268827002_to_0197872_session_2869145377_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_15-51-24.731868_from_79259992408_to_0111652_session_2865015974_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_16-12-41.184328_from_79675622871_to_0197872_session_2869222273_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_16-40-10.513635_from_79265960289_to_0150113_session_2872111512_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_17-11-34.316265_from_79099660003_to_0111642_session_2868794503_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_17-17-38.017021_from_79162948022_to_0173695_session_2865105950_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_17-30-35.871150_from_79671795235_to_0150113_session_2869317077_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_17-33-54.186273_from_74954322480_to_0197872_session_2872204368_talk.mp3',
#  '/content/Записи звонков_primavera/2023-04-09_18-41-32.681544_from_79039686861_to_0197872_session_2868887767_talk.mp3']

# %%
# Добавление в датафрейм с информацией о звонках путей к файлам записей звонков
import os
from datetime import datetime
df = df.astype({'Идентификатор сессии звонка': int})
for sample_file in os.listdir('Записи звонков_primavera'):
  if df['Идентификатор сессии звонка'][df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].count():
    df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Файл записи звонка'] = 'Записи звонков_primavera/' + sample_file
    df.loc[df[df['Идентификатор сессии звонка'] == int(sample_file.split('_')[-2])].index, 'Проект'] = 'primavera.moscow'
  else:
    df.loc[len(df.index), ['Дата и время',
                           'Номер абонента',
                           'Номер сотрудника',
                           'Идентификатор сессии звонка',
                           'Файл записи звонка',
                           'Проект']] = [datetime.strptime(sample_file.split('_')[-9] + ' ' + sample_file.split('_')[-8], '%Y-%m-%d %H-%M-%S.%f'),
                                         int(sample_file.split('_')[-6]),
                                         int(sample_file.split('_')[-4]),
                                         int(sample_file.split('_')[-2]),
                                         'Записи звонков_primavera/' + sample_file,
                                         'primavera.moscow']
df['Дата и время'] = pd.to_datetime(df['Дата и время'])
df['Номер абонента'] = df['Номер абонента'].astype('int')
df['Номер сотрудника'] = df['Номер сотрудника'].fillna(0)
df['Номер сотрудника'] = df['Номер сотрудника'].astype('int')
df['Идентификатор сессии звонка'] = df['Идентификатор сессии звонка'].astype('int')
df['Тип посетителя'] = df['Тип посетителя'].astype('str')

# %%
df.loc[df[df['Проект'] == 'primavera.moscow'].index, ['Дата и время',
                                                      'Номер абонента',
                                                      'Номер сотрудника',
                                                      'Идентификатор сессии звонка',
                                                      'Файл записи звонка',
                                                      'Проект']].head()
# Out:
#                    Дата и время  Номер абонента  Номер сотрудника  \
# 3425 2023-04-07 13:16:04.805425     79017716131            197878
# 3426 2023-04-09 11:23:06.783222     79259294806            150113
# 3427 2023-04-09 15:19:28.128262     79268827002            197872
# 3428 2023-04-09 11:14:57.304723     74950210291            197877
# 3429 2023-04-08 12:38:20.816535     79771397095            111639
#
#       Идентификатор сессии звонка  \
# 3425                   2862271810
# 3426                   2864677594
# 3427                   2869145377
# 3428                   2871634600
# 3429                   2867264995
#
#                                      Файл записи звонка            Проект
# 3425  Записи звонков_primavera/2023-04-07_13-16-04.8...  primavera.moscow
# 3426  Записи звонков_primavera/2023-04-09_11-23-06.7...  primavera.moscow
# 3427  Записи звонков_primavera/2023-04-09_15-19-28.1...  primavera.moscow
# 3428  Записи звонков_primavera/2023-04-09_11-14-57.3...  primavera.moscow
# 3429  Записи звонков_primavera/2023-04-08_12-38-20.8...  primavera.moscow

# %%
# Выбор столбцов, необходимых для инференса модели нейронной сети и оценки
df = df[['Идентификатор сессии звонка',
         'Файл записи звонка',
         'Проект',
         'Теги']][df['Проект'] == 'primavera.moscow']
df.shape
# Out:
# (50, 4)

# %%
df.head()
# Out:
#       Идентификатор сессии звонка  \
# 3425                   2862271810
# 3426                   2864677594
# 3427                   2869145377
# 3428                   2871634600
# 3429                   2867264995
#
#                                      Файл записи звонка            Проект Теги
# 3425  Записи звонков_primavera/2023-04-07_13-16-04.8...  primavera.moscow  NaN
# 3426  Записи звонков_primavera/2023-04-09_11-23-06.7...  primavera.moscow  NaN
# 3427  Записи звонков_primavera/2023-04-09_15-19-28.1...  primavera.moscow  NaN
# 3428  Записи звонков_primavera/2023-04-09_11-14-57.3...  primavera.moscow  NaN
# 3429  Записи звонков_primavera/2023-04-08_12-38-20.8...  primavera.moscow  NaN

# %%
# Сохранение в json
df.to_json('input.json', orient='records', force_ascii=False)

# %%
# Установка autokeras
# !pip -q install autokeras
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.8/584.8 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 51.6 MB/s eta 0:00:00

# %%
# !pip -q install tensorflow==2.14.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 59.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.15.0 requires tensorflow<2.16,>=2.15.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.14.0 which is incompatible.

# %%
# Установка cohere, openai и tiktoken
# !pip -q install cohere openai==1.2.3 tiktoken==0.5.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 976.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00

# %%
# Установка openai-whisper
# !pip -q install openai-whisper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# Установка fastapi и дополнительных библиотек
# !pip -q install fastapi uvicorn python-multipart typing-extensions==4.5.0 kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.7 MB/s eta 0:00:00

# %%
# Эндпойнт
main_file = '''
import re
import whisper
import numpy as np
import pandas as pd
import pickle as pkl
import autokeras as ak
from io import BytesIO
from fastapi import FastAPI, File
from tensorflow.keras.saving import load_model

whisper_model = whisper.load_model('medium')
model = load_model('2023.10.15_text_model.keras')

app = FastAPI()

@app.post('/predict')
async def predict(json_file: bytes = File(...)):

  df = pd.read_json(BytesIO(json_file))

  for i in df.index:
    df.loc[i,'Транскрибация файла записи звонка'] = whisper_model.transcribe(df.loc[i,'Файл записи звонка'], language='ru')['text']

  y_predict = model.predict(df['Транскрибация файла записи звонка'].values)
  for i in range(df.shape[0]):
    df.loc[i,'Предсказание класса'] = 'Нецелевой' if round(y_predict[i][0]) else 'Целевой'

  df[['Проект', 'Идентификатор сессии звонка', 'Теги', 'Предсказание класса', 'Транскрибация файла записи звонка']].to_json('output.json', orient='records', force_ascii=False)

  return {'result': 'output.json'}
'''
with open('main.py', 'w') as f:
  f.write(main_file)

# %%
# Запуск uvicorn
# !nohup uvicorn main:app --reload &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1915] using StatReload
# 2023-12-29 09:46:24.899708: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 09:46:24.974783: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 09:46:24.974846: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 09:46:24.978920: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 09:46:24.991904: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 09:46:24.992297: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 09:46:26.577251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:12<00:00, 125MiB/s]
# 2023-12-29 09:46:59.093102: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 09:46:59.353381: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.
# INFO:     Started server process [1917]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
import time
import requests
start_time = time.time()
files = {'json_file': open('input.json','rb')}
response = requests.post('http://127.0.0.1:8000/predict', files=files)
print(response.text)
processing_time = int(time.time() - start_time)
print(f'\nВремя обработки запроса: {int(processing_time//60)} мин {int(processing_time%60)} сек.')
# Out:
# {"result":"output.json"}
#
# Время обработки запроса: 34 мин 1 сек.

# %%
# Лог
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1915] using StatReload
# 2023-12-29 09:46:24.899708: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 09:46:24.974783: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 09:46:24.974846: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 09:46:24.978920: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-29 09:46:24.991904: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-29 09:46:24.992297: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-29 09:46:26.577251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:12<00:00, 125MiB/s]
# 2023-12-29 09:46:59.093102: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-29 09:46:59.353381: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.
# INFO:     Started server process [1917]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 2/2 [==============================] - 0s 25ms/step
# INFO:     127.0.0.1:40120 - "POST /predict HTTP/1.1" 200 OK

# %%
df = pd.read_json('output.json')
df.shape
# Out:
# (50, 5)

# %%
df
# Out:
#               Проект  Идентификатор сессии звонка  Теги Предсказание класса  \
# 0   primavera.moscow                   2862271810   NaN           Нецелевой
# 1   primavera.moscow                   2864677594   NaN             Целевой
# 2   primavera.moscow                   2869145377   NaN             Целевой
# 3   primavera.moscow                   2871634600   NaN           Нецелевой
# 4   primavera.moscow                   2867264995   NaN             Целевой
# 5   primavera.moscow                   2866661097   NaN             Целевой
# 6   primavera.moscow                   2869222273   NaN             Целевой
# 7   primavera.moscow                   2867030845   NaN             Целевой
# 8   primavera.moscow                   2862605738   NaN             Целевой
# 9   primavera.moscow                   2871099180   NaN           Нецелевой
# 10  primavera.moscow                   2869043896   NaN             Целевой
# 11  primavera.moscow                   2863702930   NaN             Целевой
# 12  primavera.moscow                   2872111512   NaN             Целевой
# 13  primavera.moscow                   2869317077   NaN           Нецелевой
# 14  primavera.moscow                   2867843688   NaN             Целевой
# 15  primavera.moscow                   2868673264   NaN             Целевой
# 16  primavera.moscow                   2868887767   NaN             Целевой
# 17  primavera.moscow                   2868746252   NaN           Нецелевой
# 18  primavera.moscow                   2871104648   NaN           Нецелевой
# 19  primavera.moscow                   2868990557   NaN             Целевой
# 20  primavera.moscow                   2868794503   NaN             Целевой
# 21  primavera.moscow                   2872204368   NaN           Нецелевой
# 22  primavera.moscow                   2865992215   NaN             Целевой
# 23  primavera.moscow                   2863966934   NaN           Нецелевой
# 24  primavera.moscow                   2871850172   NaN             Целевой
# 25  primavera.moscow                   2867310623   NaN           Нецелевой
# 26  primavera.moscow                   2868915324   NaN             Целевой
# 27  primavera.moscow                   2867714477   NaN             Целевой
# 28  primavera.moscow                   2861874202   NaN           Нецелевой
# 29  primavera.moscow                   2865154265   NaN           Нецелевой
# 30  primavera.moscow                   2866975791   NaN           Нецелевой
# 31  primavera.moscow                   2865015974   NaN             Целевой
# 32  primavera.moscow                   2867721581   NaN           Нецелевой
# 33  primavera.moscow                   2865105950   NaN             Целевой
# 34  primavera.moscow                   2862592034   NaN             Целевой
# 35  primavera.moscow                   2867948972   NaN             Целевой
# 36  primavera.moscow                   2867214243   NaN             Целевой
# 37  primavera.moscow                   2863054758   NaN           Нецелевой
# 38  primavera.moscow                   2861446698   NaN           Нецелевой
# 39  primavera.moscow                   2866204003   NaN             Целевой
# 40  primavera.moscow                   2865503407   NaN             Целевой
# 41  primavera.moscow                   2867820695   NaN           Нецелевой
# 42  primavera.moscow                   2868416035   NaN             Целевой
# 43  primavera.moscow                   2867801356   NaN             Целевой
# 44  primavera.moscow                   2866678697   NaN           Нецелевой
# 45  primavera.moscow                   2864809282   NaN             Целевой
# 46  primavera.moscow                   2866973193   NaN           Нецелевой
# 47  primavera.moscow                   2861973030   NaN             Целевой
# 48  primavera.moscow                   2864741695   NaN             Целевой
# 49  primavera.moscow                   2867508373   NaN             Целевой
#
#                     Транскрибация файла записи звонка
# 0    Добрый день, Глубный город на рейсте Примавер...
# 1    Здравствуйте, Юлия. Нас интересует живой комп...
# 2    Клубный город на реке Примавеера. Татьяна, до...
# 3    Доброе утро, Клубный город на реке Примавера....
# 4    Клубный город на реке Примавер. Меня зовут На...
# 5    Добрый день, на линии клиент Михаил. Бюджет д...
# 6    Клубный город на реке Примоверда. Татьяна, до...
# 7    Клубный город на реке Примаверо. Меня зовут Н...
# 8    Глубный город на реке Примавер. Меня зовут На...
# 9    Добрый вечер, клубный город на реке Фрамовера...
# 10   Добрый день, Глубный город на реке Примоверга...
# 11   Крубный город на реке Примавыра. На Атаре доб...
# 12   Добрый день. Здравствуйте. Вы в Тушину находи...
# 13   – Ало. – Юля? – Да. – Добрый день. Мы с вами ...
# 14   Клубный город на реке Примоваре. Меня зовут Н...
# 15   Добрый день. Здравствуйте. Меня зовут Елена. ...
# 16   Кудный город на реке Примавеера. Татьяна, доб...
# 17   Клубногорский Примовер, Юлия, добрый день. Юл...
# 18    Меня зовут Лина, мне очень приятно перезвонить.
# 19   – Клубный город Примовер. Меня зовут Юлия. До...
# 20   Клубный город на реке Примаверми. Меня зовут ...
# 21   Пожалуйста, говорите после звукового сигнала....
# 22   Добрый день, Колобный город, я прямоверная, с...
# 23   Главный гордость СМОВР, меня зовут Наталья, з...
# 24   Главный город на реке Примавыра. Татьяна, доб...
# 25   Кузнагород на реке Примовар. Юлия, добрый ден...
# 26   – Здравствуйте, Наталья. Я изучаю варианты в ...
# 27   Клубный город на реке Примавер. Меня зовут На...
# 28   Доброе утро, клубный город на реке Примаверо....
# 29   Вам поступил звонок с сайта новострой.м. Ожид...
# 30   Доброе утро, город Тереке. Доброе утро, город...
# 31   – Здравствуйте, Анастасия. – Здравствуйте, Ан...
# 32   Вомна городной реки Примоваро, Юлия, здравств...
# 33   Главный город на реке Тримовера. Меня зовут Е...
# 34   Клубный город на реке Примавыра. Наталья, доб...
# 35   Если да, вы нажмите клавишу 1 и мы связываемс...
# 36   Добрый день, Кубный город на реке Примовера. ...
# 37   Клубный город на реке Примаверо. Меня зовут Н...
# 38   Натерпо, доброе утро. Доброе утро. Расскажите...
# 39   Глубный город на реке Примовера. Надежда, доб...
# 40   Клубный город на реке Примоверна. Наталья, до...
# 41   Добрый вечер, Клубный город на реке Промовера...
# 42   Добрый день. Клубный город на реке Примавера....
# 43   Глубный город на реке Примавер. Меня зовут На...
# 44   Добрый день. Я могу связаться с отделом закуп...
# 45   Главный город на реке Петмабыро. Здравствуйте...
# 46   Клубный город на реке Примовера. Надежда, доб...
# 47   Добрый день, Голубный город на реке Примаверо...
# 48   Клубный город на реке Примаверон, дежда от утра.
# 49   Клубный город на реке Примавер. Меня зовут На...

# %%
# !mv output.json primavera.moscow_output.json
